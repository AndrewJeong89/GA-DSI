# %% [markdown]
# # APIs and SQL Joins Lab
#
# The city of San Francisco wants to assess the quality of restaurants in the city. Their data is scattered across multiple sources and incomplete.
#
# They tasked you to help them assess it.
#
# They would like to know what the most common violations are where they happen most frequently.

# %% [markdown]
# ## 1. Initial data inspection
#
# To answer the question we will need to retrieve and merge data from multiple files.
#
# Yelp provides data on food quality, that can be found at [this address](http://www.yelp.com/healthscores/feeds). We already downloaded 4 files that you can find in the [assets folder](../../assets/datasets/yelp/).
#
# In the bonus part we will also use the Google Geocoding API and data on [Neighborhoods](https://www.google.com/fusiontables/DataSource?docid=1zNwsvTwj-dH0QxuuDrKFsyfNklajd7WwEyaZ2U9M#rows:id=1).
#
# 1. Open each of the files and inspect them visually
# - What information do they contain?

# %%
# !ls ../../assets/datasets/yelp
# Out:
# businesses.csv  inspections.csv legend.csv      violations.csv

# %% [markdown]
# ## 2. Local database
#
# The first step in our analysis is to import the data into a local PostgreSQL database.
#
# 1. Launch a local Postgres server;
# 2. Create a local database named 'inspections';
# 3. Connect to it with sqlalchemy (see starter code) and import the files to separate tables.
#
# **Note:** The files are not encoded in utf8, but in latin1. You can read more about encodings here: http://www.postgresql.org/docs/current/interactive/multibyte.html

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sqlalchemy import create_engine

engine = create_engine('postgresql://student@localhost:5432/inspections') # Replace 'winston' with your username

# %%
def load_to_sql(name):
    df = pd.read_csv('../../assets/datasets/yelp/{}.csv'.format(name), encoding='latin1')
    df.to_sql(name, engine, flavor='postgres', if_exists='replace')
    print "done", name
    
load_to_sql('businesses')
load_to_sql('inspections')
load_to_sql('legend')
load_to_sql('violations')
# Out:
# done businesses
# done inspections
# done legend
# done violations

# %% [markdown]
# ### 2.b Display the first few lines of each table

# %%
# Replace <user> with your user name

# %load_ext sql
# %sql postgresql://student@localhost:5432/inspections
# Out:
# u'Connected: student@inspections'

# %%
# %%sql
# select * from inspections limit 2;
# Out:
# 2 rows affected.
# [(0L, 10L, 94L, 20140729L, u'routine'), (1L, 10L, 92L, 20140114L, u'routine')]

# %%
# %%sql
# select * from businesses limit 2;
# Out:
# 2 rows affected.
# [(0L, 10L, u'TIRAMISU KITCHEN', u'033 BELDEN PL', u'San Francisco', u'CA', u'94104', 37.791116, -122.403816, u'+14154217044'),
#  (1L, 19L, u'NRGIZE LIFESTYLE CAFE', u'1200 VAN NESS AVE, 3RD FLOOR', u'San Francisco', u'CA', u'94109', 37.786848, -122.421547, u'+14157763262')]

# %%
# %%sql
# select * from legend limit 2;
# Out:
# 2 rows affected.
# [(0L, 0L, 70L, u'Poor'), (1L, 71L, 85L, u'Needs Improvement')]

# %%
# %%sql
# select * from violations limit 2;
# Out:
# 2 rows affected.
# [(0L, 10L, 20140729L, u'Insufficient hot water or running water  [ date violation corrected: 8/7/2014 ]'),
#  (1L, 10L, 20140729L, u'Unapproved or unmaintained equipment or utensils  [ date violation corrected: 8/7/2014 ]')]

# %%
# %%sql
# select * from information_schema.tables limit 2;
# Out:
# 2 rows affected.
# [(u'inspections', u'pg_catalog', u'pg_statistic', u'BASE TABLE', None, None, None, None, None, u'YES', u'NO', None),
#  (u'inspections', u'pg_catalog', u'pg_type', u'BASE TABLE', None, None, None, None, None, u'YES', u'NO', None)]

# %% [markdown]
# ## 2.b Investigate violations
#
# Let's focus on the violations table initially.
#
#
# Answer these questions using sql:
# 1. How many violations are there?
# - How many businesses committing violations?
# - What's the average number of violations per business?
#
# Answer these questions using python
# 1. Draw a plot of the violations count
# - Is the average number of violations meaningful?
# - Draw a plot of the normalized cumulative violation counts. Can we discard the restaurants with few violations?
# - Where would you draw a threshold if you were to keep 90% of the violations?

# %%
# %%sql
# select count(*) from violations;
# Out:
# 1 rows affected.
# [(39917L,)]

# %%
# %%sql
# select count(distinct business_id) from violations;
# Out:
# 1 rows affected.
# [(5022L,)]

# %%
# %%sql
# select avg(c) from (select distinct business_id, count(*) as c from violations
# group by business_id) as count;
# Out:
# 1 rows affected.
# [(Decimal('7.9484269215452011'),)]

# %%
v = %%sql select business_id, count(*) as count from violations group by business_id order by count desc;
# Out:
# 5022 rows affected.

# %%
v = v.DataFrame()

# %%
v['count'].mode()
# Out:
# 0    2
# dtype: int64

# %%
v['count'].plot()

# %%
import numpy as np
from scipy import stats

# %% [markdown]
# > The average is not meaningful because it doesn't reveal many companies with only 1 violation as a result of a skew in the data from outliers who have many violations. The mode would be a better aggregation of "average"

# %%
(v['count'].cumsum()/v['count'].sum()).plot()
plt.axhline(0.9, color = 'r')
plt.axvline(3350, color = 'r')

# %%
v.iloc[3350,:]
# Out:
# business_id    39052
# count              4
# Name: 3350, dtype: int64

# %% [markdown]
# > The threshold will be at 4 violations if we kept it at 90% of the violations

# %% [markdown]
# ### 2.c Investigate Inspections
#
# In the previous step we looked at violations count. However we also have an inspection score available in the inspections table. Let's have a look at that too.
#
# Answer these questions using SQL:
# 1. What's the average score for the whole city?
# 1. What's the average score per business?
# - Does the score correlate with the number of inspections?
# - Create a dataframe from a table with the following columns:
#     business_id, average_score, number_of_inspections, number_of_violations
# - Use pandas to do a scatter matrix plot of average_score, number_of_inspections, number_of_violations to check for correlations

# %%
# %%sql
# select avg(score) from inspections;
# Out:
# 1 rows affected.
# [(Decimal('91.4672412675782516'),)]

# %%
# %%sql
# select business_id, avg(score) from inspections
# group by business_id
# order by avg(score) asc;
# Out:
# 5513 rows affected.
# [(18480L, Decimal('50.5000000000000000')),
#  (60469L, Decimal('55.0000000000000000')),
#  (82134L, Decimal('55.0000000000000000')),
#  (1207L, Decimal('56.0000000000000000')),
#  (80591L, Decimal('57.0000000000000000')),
#  (83799L, Decimal('59.0000000000000000')),
#  (71071L, Decimal('59.0000000000000000')),
#  (74522L, Decimal('59.5000000000000000')),
#  (1750L, Decimal('60.0000000000000000')),
#  (69962L, Decimal('61.5000000000000000')),
#  (3151L, Decimal('62.0000000000000000')),
#  (80273L, Decimal('62.0000000000000000')),
#  (81978L, Decimal('62.0000000000000000')),
#  (82123L, Decimal('63.0000000000000000')),
#  (81866L, Decimal('63.0000000000000000')),
#  (71314L, Decimal('63.7500000000000000')),
#  (1843L, Decimal('64.0000000000000000')),
#  (75103L, Decimal('64.0000000000000000')),
#  (68916L, Decimal('64.0000000000000000')),
#  (3123L, Decimal('64.6666666666666667')),
#  (81667L, Decimal('65.0000000000000000')),
#  (39426L, Decimal('65.0000000000000000')),
#  (29610L, Decimal('65.5000000000000000')),
#  (79446L, Decimal('65.5000000000000000')),
#  (69486L, Decimal('65.6666666666666667')),
#  (64154L, Decimal('66.0000000000000000')),
#  (71416L, Decimal('66.0000000000000000')),
#  (2004L, Decimal('66.0000000000000000')),
#  (703L, Decimal('66.0000000000000000')),
#  (10102L, Decimal('66.3333333333333333')),
#  (25572L, Decimal('66.3333333333333333')),
#  (33920L, Decimal('66.5000000000000000')),
#  (7489L, Decimal('66.5000000000000000')),
#  (71994L, Decimal('67.0000000000000000')),
#  (61953L, Decimal('67.0000000000000000')),
#  (78328L, Decimal('67.0000000000000000')),
#  (34585L, Decimal('67.0000000000000000')),
#  (10332L, Decimal('67.0000000000000000')),
#  (494L, Decimal('67.0000000000000000')),
#  (71168L, Decimal('67.3333333333333333')),
#  (14577L, Decimal('67.5000000000000000')),
#  (61391L, Decimal('67.5000000000000000')),
#  (82592L, Decimal('68.0000000000000000')),
#  (63131L, Decimal('68.0000000000000000')),
#  (85955L, Decimal('68.0000000000000000')),
#  (2716L, Decimal('68.0000000000000000')),
#  (85930L, Decimal('68.0000000000000000')),
#  (80824L, Decimal('68.0000000000000000')),
#  (63121L, Decimal('68.5000000000000000')),
#  (15738L, Decimal('68.5000000000000000')),
#  (74084L, Decimal('68.5000000000000000')),
#  (69301L, Decimal('68.6666666666666667')),
#  (71176L, Decimal('68.6666666666666667')),
#  (18369L, Decimal('68.7500000000000000')),
#  (65561L, Decimal('69.0000000000000000')),
#  (86500L, Decimal('69.0000000000000000')),
#  (67262L, Decimal('69.0000000000000000')),
#  (35026L, Decimal('69.3333333333333333')),
#  (2233L, Decimal('69.3333333333333333')),
#  (3209L, Decimal('69.3333333333333333')),
#  (67371L, Decimal('69.3333333333333333')),
#  (286L, Decimal('69.5000000000000000')),
#  (36179L, Decimal('69.5000000000000000')),
#  (69234L, Decimal('69.5000000000000000')),
#  (3693L, Decimal('69.5000000000000000')),
#  (3115L, Decimal('69.6666666666666667')),
#  (83589L, Decimal('70.0000000000000000')),
#  (59828L, Decimal('70.0000000000000000')),
#  (28035L, Decimal('70.0000000000000000')),
#  (81839L, Decimal('70.0000000000000000')),
#  (81433L, Decimal('70.0000000000000000')),
#  (83570L, Decimal('70.0000000000000000')),
#  (39113L, Decimal('70.5000000000000000')),
#  (62578L, Decimal('70.6666666666666667')),
#  (33446L, Decimal('70.6666666666666667')),
#  (26340L, Decimal('71.0000000000000000')),
#  (64132L, Decimal('71.0000000000000000')),
#  (71232L, Decimal('71.0000000000000000')),
#  (67154L, Decimal('71.0000000000000000')),
#  (1833L, Decimal('71.0000000000000000')),
#  (24572L, Decimal('71.0000000000000000')),
#  (469L, Decimal('71.0000000000000000')),
#  (796L, Decimal('71.0000000000000000')),
#  (3825L, Decimal('71.0000000000000000')),
#  (75230L, Decimal('71.0000000000000000')),
#  (78963L, Decimal('71.0000000000000000')),
#  (83438L, Decimal('71.0000000000000000')),
#  (81188L, Decimal('71.0000000000000000')),
#  (4614L, Decimal('71.0000000000000000')),
#  (76930L, Decimal('71.0000000000000000')),
#  (7738L, Decimal('71.0000000000000000')),
#  (70281L, Decimal('71.2500000000000000')),
#  (1000L, Decimal('71.2500000000000000')),
#  (37879L, Decimal('71.3333333333333333')),
#  (23701L, Decimal('71.3333333333333333')),
#  (37882L, Decimal('71.5000000000000000')),
#  (79923L, Decimal('71.5000000000000000')),
#  (69392L, Decimal('71.5000000000000000')),
#  (32992L, Decimal('71.5000000000000000')),
#  (71385L, Decimal('71.6000000000000000')),
#  (62330L, Decimal('72.0000000000000000')),
#  (66711L, Decimal('72.0000000000000000')),
#  (66321L, Decimal('72.0000000000000000')),
#  (2944L, Decimal('72.0000000000000000')),
#  (71657L, Decimal('72.0000000000000000')),
#  (480L, Decimal('72.0000000000000000')),
#  (3822L, Decimal('72.0000000000000000')),
#  (67330L, Decimal('72.0000000000000000')),
#  (80643L, Decimal('72.0000000000000000')),
#  (63804L, Decimal('72.5000000000000000')),
#  (64176L, Decimal('72.5000000000000000')),
#  (77548L, Decimal('72.5000000000000000')),
#  (79565L, Decimal('72.5000000000000000')),
#  (69016L, Decimal('72.6000000000000000')),
#  (2331L, Decimal('72.6666666666666667')),
#  (66800L, Decimal('72.6666666666666667')),
#  (68433L, Decimal('72.6666666666666667')),
#  (4608L, Decimal('72.6666666666666667')),
#  (4607L, Decimal('72.7500000000000000')),
#  (58673L, Decimal('72.7500000000000000')),
#  (7479L, Decimal('73.0000000000000000')),
#  (283L, Decimal('73.0000000000000000')),
#  (62462L, Decimal('73.0000000000000000')),
#  (76950L, Decimal('73.0000000000000000')),
#  (2559L, Decimal('73.0000000000000000')),
#  (71012L, Decimal('73.0000000000000000')),
#  (880L, Decimal('73.0000000000000000')),
#  (3459L, Decimal('73.0000000000000000')),
#  (68056L, Decimal('73.0000000000000000')),
#  (3016L, Decimal('73.0000000000000000')),
#  (18870L, Decimal('73.0000000000000000')),
#  (37090L, Decimal('73.0000000000000000')),
#  (76218L, Decimal('73.3333333333333333')),
#  (37141L, Decimal('73.3333333333333333')),
#  (634L, Decimal('73.3333333333333333')),
#  (852L, Decimal('73.3333333333333333')),
#  (81460L, Decimal('73.5000000000000000')),
#  (2234L, Decimal('73.5000000000000000')),
#  (64737L, Decimal('73.5000000000000000')),
#  (77672L, Decimal('73.5000000000000000')),
#  (77681L, Decimal('73.5000000000000000')),
#  (4621L, Decimal('73.6666666666666667')),
#  (59515L, Decimal('73.6666666666666667')),
#  (3167L, Decimal('73.6666666666666667')),
#  (2544L, Decimal('73.6666666666666667')),
#  (2044L, Decimal('73.6666666666666667')),
#  (37152L, Decimal('73.6666666666666667')),
#  (63082L, Decimal('73.7500000000000000')),
#  (69205L, Decimal('74.0000000000000000')),
#  (6944L, Decimal('74.0000000000000000')),
#  (68560L, Decimal('74.0000000000000000')),
#  (72015L, Decimal('74.0000000000000000')),
#  (3895L, Decimal('74.0000000000000000')),
#  (68672L, Decimal('74.0000000000000000')),
#  (79804L, Decimal('74.0000000000000000')),
#  (3529L, Decimal('74.0000000000000000')),
#  (34743L, Decimal('74.0000000000000000')),
#  (81328L, Decimal('74.0000000000000000')),
#  (84677L, Decimal('74.0000000000000000')),
#  (77162L, Decimal('74.0000000000000000')),
#  (65531L, Decimal('74.0000000000000000')),
#  (843L, Decimal('74.0000000000000000')),
#  (84547L, Decimal('74.0000000000000000')),
#  (66874L, Decimal('74.0000000000000000')),
#  (83827L, Decimal('74.0000000000000000')),
#  (4787L, Decimal('74.0000000000000000')),
#  (7216L, Decimal('74.0000000000000000')),
#  (78275L, Decimal('74.0000000000000000')),
#  (81719L, Decimal('74.0000000000000000')),
#  (85925L, Decimal('74.0000000000000000')),
#  (34676L, Decimal('74.0000000000000000')),
#  (75139L, Decimal('74.2000000000000000')),
#  (76547L, Decimal('74.3333333333333333')),
#  (59338L, Decimal('74.3333333333333333')),
#  (903L, Decimal('74.3333333333333333')),
#  (18357L, Decimal('74.3333333333333333')),
#  (79528L, Decimal('74.5000000000000000')),
#  (81309L, Decimal('74.5000000000000000')),
#  (4588L, Decimal('74.5000000000000000')),
#  (2697L, Decimal('74.5000000000000000')),
#  (70137L, Decimal('74.5000000000000000')),
#  (68403L, Decimal('74.5000000000000000')),
#  (62769L, Decimal('74.5000000000000000')),
#  (71476L, Decimal('74.5000000000000000')),
#  (60355L, Decimal('74.5000000000000000')),
#  (2609L, Decimal('74.5000000000000000')),
#  (77745L, Decimal('74.5000000000000000')),
#  (34662L, Decimal('74.5000000000000000')),
#  (73963L, Decimal('74.6666666666666667')),
#  (69782L, Decimal('74.6666666666666667')),
#  (6654L, Decimal('74.7500000000000000')),
#  (81187L, Decimal('75.0000000000000000')),
#  (69520L, Decimal('75.0000000000000000')),
#  (68121L, Decimal('75.0000000000000000')),
#  (38580L, Decimal('75.0000000000000000')),
#  (335L, Decimal('75.0000000000000000')),
#  (81886L, Decimal('75.0000000000000000')),
#  (483L, Decimal('75.0000000000000000')),
#  (77054L, Decimal('75.0000000000000000')),
#  (3587L, Decimal('75.0000000000000000')),
#  (61161L, Decimal('75.0000000000000000')),
#  (11019L, Decimal('75.3333333333333333')),
#  (1567L, Decimal('75.3333333333333333')),
#  (1216L, Decimal('75.3333333333333333')),
#  (39396L, Decimal('75.3333333333333333')),
#  (3325L, Decimal('75.5000000000000000')),
#  (65382L, Decimal('75.5000000000000000')),
#  (38070L, Decimal('75.5000000000000000')),
#  (83808L, Decimal('75.5000000000000000')),
#  (489L, Decimal('75.6000000000000000')),
#  (73889L, Decimal('75.6000000000000000')),
#  (3819L, Decimal('75.6666666666666667')),
#  (3221L, Decimal('75.6666666666666667')),
#  (27167L, Decimal('75.6666666666666667')),
#  (72049L, Decimal('75.7500000000000000')),
#  (3237L, Decimal('75.7500000000000000')),
#  (70068L, Decimal('76.0000000000000000')),
#  (69115L, Decimal('76.0000000000000000')),
#  (80243L, Decimal('76.0000000000000000')),
#  (71310L, Decimal('76.0000000000000000')),
#  (80024L, Decimal('76.0000000000000000')),
#  (66640L, Decimal('76.0000000000000000')),
#  (68321L, Decimal('76.0000000000000000')),
#  (10238L, Decimal('76.0000000000000000')),
#  (27680L, Decimal('76.0000000000000000')),
#  (62915L, Decimal('76.0000000000000000')),
#  (61799L, Decimal('76.0000000000000000')),
#  (75835L, Decimal('76.0000000000000000')),
#  (75147L, Decimal('76.0000000000000000')),
#  (68930L, Decimal('76.0000000000000000')),
#  (78865L, Decimal('76.0000000000000000')),
#  (2941L, Decimal('76.0000000000000000')),
#  (85843L, Decimal('76.0000000000000000')),
#  (61351L, Decimal('76.0000000000000000')),
#  (78907L, Decimal('76.0000000000000000')),
#  (3613L, Decimal('76.0000000000000000')),
#  (2406L, Decimal('76.0000000000000000')),
#  (61206L, Decimal('76.0000000000000000')),
#  (2561L, Decimal('76.0000000000000000')),
#  (99L, Decimal('76.0000000000000000')),
#  (63280L, Decimal('76.0000000000000000')),
#  (76033L, Decimal('76.0000000000000000')),
#  (2325L, Decimal('76.2500000000000000')),
#  (9796L, Decimal('76.2500000000000000')),
#  (60518L, Decimal('76.3333333333333333')),
#  (69717L, Decimal('76.3333333333333333')),
#  (7119L, Decimal('76.3333333333333333')),
#  (71373L, Decimal('76.3333333333333333')),
#  (2898L, Decimal('76.3333333333333333')),
#  (77564L, Decimal('76.3333333333333333')),
#  (84656L, Decimal('76.5000000000000000')),
#  (68881L, Decimal('76.5000000000000000')),
#  (7512L, Decimal('76.5000000000000000')),
#  (59178L, Decimal('76.6666666666666667')),
#  (2700L, Decimal('76.6666666666666667')),
#  (79729L, Decimal('76.6666666666666667')),
#  (34221L, Decimal('76.6666666666666667')),
#  (68633L, Decimal('76.6666666666666667')),
#  (126L, Decimal('76.7500000000000000')),
#  (240L, Decimal('76.7500000000000000')),
#  (7643L, Decimal('76.7500000000000000')),
#  (78965L, Decimal('77.0000000000000000')),
#  (606L, Decimal('77.0000000000000000')),
#  (1754L, Decimal('77.0000000000000000')),
#  (72176L, Decimal('77.0000000000000000')),
#  (82142L, Decimal('77.0000000000000000')),
#  (58L, Decimal('77.0000000000000000')),
#  (1960L, Decimal('77.0000000000000000')),
#  (1912L, Decimal('77.0000000000000000')),
#  (3174L, Decimal('77.0000000000000000')),
#  (79272L, Decimal('77.0000000000000000')),
#  (67564L, Decimal('77.0000000000000000')),
#  (37231L, Decimal('77.0000000000000000')),
#  (68620L, Decimal('77.0000000000000000')),
#  (38564L, Decimal('77.0000000000000000')),
#  (64525L, Decimal('77.0000000000000000')),
#  (79248L, Decimal('77.0000000000000000')),
#  (81540L, Decimal('77.0000000000000000')),
#  (79414L, Decimal('77.0000000000000000')),
#  (86670L, Decimal('77.0000000000000000')),
#  (69118L, Decimal('77.0000000000000000')),
#  (2326L, Decimal('77.2000000000000000')),
#  (65066L, Decimal('77.2500000000000000')),
#  (68860L, Decimal('77.2500000000000000')),
#  (68042L, Decimal('77.2500000000000000')),
#  (65348L, Decimal('77.2500000000000000')),
#  (3217L, Decimal('77.3333333333333333')),
#  (4670L, Decimal('77.3333333333333333')),
#  (27793L, Decimal('77.3333333333333333')),
#  (7755L, Decimal('77.3333333333333333')),
#  (70434L, Decimal('77.5000000000000000')),
#  (3862L, Decimal('77.5000000000000000')),
#  (38428L, Decimal('77.5000000000000000')),
#  (78300L, Decimal('77.5000000000000000')),
#  (33641L, Decimal('77.5000000000000000')),
#  (985L, Decimal('77.5000000000000000')),
#  (2201L, Decimal('77.5000000000000000')),
#  (83351L, Decimal('77.5000000000000000')),
#  (67614L, Decimal('77.5000000000000000')),
#  (1702L, Decimal('77.5000000000000000')),
#  (2397L, Decimal('77.6666666666666667')),
#  (62943L, Decimal('77.6666666666666667')),
#  (60472L, Decimal('77.6666666666666667')),
#  (66736L, Decimal('77.6666666666666667')),
#  (36699L, Decimal('77.7500000000000000')),
#  (80304L, Decimal('78.0000000000000000')),
#  (35592L, Decimal('78.0000000000000000')),
#  (69249L, Decimal('78.0000000000000000')),
#  (86296L, Decimal('78.0000000000000000')),
#  (77703L, Decimal('78.0000000000000000')),
#  (69762L, Decimal('78.0000000000000000')),
#  (68451L, Decimal('78.0000000000000000')),
#  (77438L, Decimal('78.0000000000000000')),
#  (80763L, Decimal('78.0000000000000000')),
#  (4622L, Decimal('78.0000000000000000')),
#  (62900L, Decimal('78.0000000000000000')),
#  (79366L, Decimal('78.0000000000000000')),
#  (70838L, Decimal('78.0000000000000000')),
#  (18901L, Decimal('78.0000000000000000')),
#  (70996L, Decimal('78.0000000000000000')),
#  (835L, Decimal('78.0000000000000000')),
#  (67500L, Decimal('78.0000000000000000')),
#  (83844L, Decimal('78.0000000000000000')),
#  (61436L, Decimal('78.0000000000000000')),
#  (76676L, Decimal('78.0000000000000000')),
#  (82897L, Decimal('78.0000000000000000')),
#  (83647L, Decimal('78.0000000000000000')),
#  (66522L, Decimal('78.0000000000000000')),
#  (74922L, Decimal('78.0000000000000000')),
#  (64549L, Decimal('78.0000000000000000')),
#  (2437L, Decimal('78.0000000000000000')),
#  (82890L, Decimal('78.0000000000000000')),
#  (69752L, Decimal('78.0000000000000000')),
#  (86295L, Decimal('78.0000000000000000')),
#  (62064L, Decimal('78.0000000000000000')),
#  (4590L, Decimal('78.0000000000000000')),
#  (80479L, Decimal('78.0000000000000000')),
#  (81277L, Decimal('78.0000000000000000')),
#  (80514L, Decimal('78.0000000000000000')),
#  (69666L, Decimal('78.2500000000000000')),
#  (2401L, Decimal('78.3333333333333333')),
#  (6734L, Decimal('78.3333333333333333')),
#  (3481L, Decimal('78.3333333333333333')),
#  (7796L, Decimal('78.3333333333333333')),
#  (7482L, Decimal('78.5000000000000000')),
#  (3183L, Decimal('78.5000000000000000')),
#  (36022L, Decimal('78.5000000000000000')),
#  (9679L, Decimal('78.5000000000000000')),
#  (1850L, Decimal('78.5000000000000000')),
#  (79333L, Decimal('78.5000000000000000')),
#  (3286L, Decimal('78.5000000000000000')),
#  (32671L, Decimal('78.5000000000000000')),
#  (76896L, Decimal('78.5000000000000000')),
#  (39693L, Decimal('78.6666666666666667')),
#  (2223L, Decimal('78.6666666666666667')),
#  (62548L, Decimal('78.6666666666666667')),
#  (39047L, Decimal('78.6666666666666667')),
#  (4907L, Decimal('78.6666666666666667')),
#  (2292L, Decimal('78.6666666666666667')),
#  (2428L, Decimal('78.6666666666666667')),
#  (273L, Decimal('78.6666666666666667')),
#  (3817L, Decimal('78.7500000000000000')),
#  (2945L, Decimal('78.7500000000000000')),
#  (2421L, Decimal('78.7500000000000000')),
#  (4643L, Decimal('79.0000000000000000')),
#  (64975L, Decimal('79.0000000000000000')),
#  (5258L, Decimal('79.0000000000000000')),
#  (420L, Decimal('79.0000000000000000')),
#  (71634L, Decimal('79.0000000000000000')),
#  (35659L, Decimal('79.0000000000000000')),
#  (1244L, Decimal('79.0000000000000000')),
#  (36378L, Decimal('79.0000000000000000')),
#  (85500L, Decimal('79.0000000000000000')),
#  (230L, Decimal('79.0000000000000000')),
#  (3953L, Decimal('79.0000000000000000')),
#  (4533L, Decimal('79.0000000000000000')),
#  (3476L, Decimal('79.0000000000000000')),
#  (3659L, Decimal('79.0000000000000000')),
#  (79821L, Decimal('79.0000000000000000')),
#  (3676L, Decimal('79.0000000000000000')),
#  (75873L, Decimal('79.0000000000000000')),
#  (77031L, Decimal('79.0000000000000000')),
#  (86681L, Decimal('79.0000000000000000')),
#  (18686L, Decimal('79.0000000000000000')),
#  (69883L, Decimal('79.0000000000000000')),
#  (66988L, Decimal('79.0000000000000000')),
#  (1959L, Decimal('79.0000000000000000')),
#  (59396L, Decimal('79.0000000000000000')),
#  (1139L, Decimal('79.0000000000000000')),
#  (65194L, Decimal('79.0000000000000000')),
#  (21982L, Decimal('79.0000000000000000')),
#  (68824L, Decimal('79.0000000000000000')),
#  (34434L, Decimal('79.0000000000000000')),
#  (7856L, Decimal('79.2500000000000000')),
#  (62882L, Decimal('79.2500000000000000')),
#  (1347L, Decimal('79.2500000000000000')),
#  (69064L, Decimal('79.2500000000000000')),
#  (65872L, Decimal('79.3333333333333333')),
#  (840L, Decimal('79.3333333333333333')),
#  (1832L, Decimal('79.3333333333333333')),
#  (15184L, Decimal('79.3333333333333333')),
#  (77693L, Decimal('79.3333333333333333')),
#  (1458L, Decimal('79.4000000000000000')),
#  (1144L, Decimal('79.4000000000000000')),
#  (78102L, Decimal('79.5000000000000000')),
#  (34611L, Decimal('79.5000000000000000')),
#  (59002L, Decimal('79.5000000000000000')),
#  (65139L, Decimal('79.5000000000000000')),
#  (7589L, Decimal('79.5000000000000000')),
#  (77611L, Decimal('79.5000000000000000')),
#  (1542L, Decimal('79.5000000000000000')),
#  (66515L, Decimal('79.5000000000000000')),
#  (1950L, Decimal('79.5000000000000000')),
#  (610L, Decimal('79.5000000000000000')),
#  (62443L, Decimal('79.5000000000000000')),
#  (39176L, Decimal('79.5000000000000000')),
#  (2115L, Decimal('79.6000000000000000')),
#  (1775L, Decimal('79.6666666666666667')),
#  (64835L, Decimal('79.6666666666666667')),
#  (1949L, Decimal('79.6666666666666667')),
#  (32654L, Decimal('79.6666666666666667')),
#  (19357L, Decimal('79.6666666666666667')),
#  (68242L, Decimal('79.6666666666666667')),
#  (267L, Decimal('79.6666666666666667')),
#  (35690L, Decimal('79.6666666666666667')),
#  (1797L, Decimal('79.6666666666666667')),
#  (17411L, Decimal('79.7500000000000000')),
#  (64466L, Decimal('79.7500000000000000')),
#  (66276L, Decimal('79.7500000000000000')),
#  (19076L, Decimal('79.8000000000000000')),
#  (69799L, Decimal('79.8000000000000000')),
#  (81179L, Decimal('80.0000000000000000')),
#  (19641L, Decimal('80.0000000000000000')),
#  (77666L, Decimal('80.0000000000000000')),
#  (85221L, Decimal('80.0000000000000000')),
#  (81385L, Decimal('80.0000000000000000')),
#  (77643L, Decimal('80.0000000000000000')),
#  (78705L, Decimal('80.0000000000000000')),
#  (76886L, Decimal('80.0000000000000000')),
#  (83475L, Decimal('80.0000000000000000')),
#  (78781L, Decimal('80.0000000000000000')),
#  (10131L, Decimal('80.0000000000000000')),
#  (64854L, Decimal('80.0000000000000000')),
#  (70014L, Decimal('80.0000000000000000')),
#  (83575L, Decimal('80.0000000000000000')),
#  (69387L, Decimal('80.0000000000000000')),
#  (67276L, Decimal('80.0000000000000000')),
#  (18826L, Decimal('80.0000000000000000')),
#  (84038L, Decimal('80.0000000000000000')),
#  (68626L, Decimal('80.0000000000000000')),
#  (68320L, Decimal('80.0000000000000000')),
#  (59025L, Decimal('80.0000000000000000')),
#  (17723L, Decimal('80.0000000000000000')),
#  (2758L, Decimal('80.0000000000000000')),
#  (74010L, Decimal('80.0000000000000000')),
#  (3524L, Decimal('80.0000000000000000')),
#  (63601L, Decimal('80.0000000000000000')),
#  (79518L, Decimal('80.0000000000000000')),
#  (65529L, Decimal('80.0000000000000000')),
#  (80164L, Decimal('80.0000000000000000')),
#  (3816L, Decimal('80.0000000000000000')),
#  (2619L, Decimal('80.0000000000000000')),
#  (3021L, Decimal('80.0000000000000000')),
#  (77519L, Decimal('80.0000000000000000')),
#  (70547L, Decimal('80.0000000000000000')),
#  (75274L, Decimal('80.0000000000000000')),
#  (65857L, Decimal('80.0000000000000000')),
#  (26348L, Decimal('80.0000000000000000')),
#  (78347L, Decimal('80.0000000000000000')),
#  (86658L, Decimal('80.0000000000000000')),
#  (59727L, Decimal('80.0000000000000000')),
#  (69592L, Decimal('80.0000000000000000')),
#  (57579L, Decimal('80.0000000000000000')),
#  (69618L, Decimal('80.0000000000000000')),
#  (821L, Decimal('80.0000000000000000')),
#  (64630L, Decimal('80.2500000000000000')),
#  (17570L, Decimal('80.2500000000000000')),
#  (88L, Decimal('80.3333333333333333')),
#  (75732L, Decimal('80.3333333333333333')),
#  (5090L, Decimal('80.3333333333333333')),
#  (35447L, Decimal('80.3333333333333333')),
#  (3640L, Decimal('80.3333333333333333')),
#  (4803L, Decimal('80.3333333333333333')),
#  (61816L, Decimal('80.3333333333333333')),
#  (75560L, Decimal('80.3333333333333333')),
#  (3065L, Decimal('80.3333333333333333')),
#  (37151L, Decimal('80.3333333333333333')),
#  (36745L, Decimal('80.3333333333333333')),
#  (1398L, Decimal('80.3333333333333333')),
#  (10170L, Decimal('80.3333333333333333')),
#  (2189L, Decimal('80.3333333333333333')),
#  (59826L, Decimal('80.5000000000000000')),
#  (24279L, Decimal('80.5000000000000000')),
#  (81894L, Decimal('80.5000000000000000')),
#  (65442L, Decimal('80.5000000000000000')),
#  (4071L, Decimal('80.5000000000000000')),
#  (64524L, Decimal('80.5000000000000000')),
#  (61823L, Decimal('80.5000000000000000')),
#  (60115L, Decimal('80.5000000000000000')),
#  (77645L, Decimal('80.5000000000000000')),
#  (2798L, Decimal('80.5000000000000000')),
#  (85240L, Decimal('80.5000000000000000')),
#  (79625L, Decimal('80.5000000000000000')),
#  (27472L, Decimal('80.5000000000000000')),
#  (63150L, Decimal('80.5000000000000000')),
#  (3948L, Decimal('80.5000000000000000')),
#  (3229L, Decimal('80.6000000000000000')),
#  (509L, Decimal('80.6000000000000000')),
#  (2109L, Decimal('80.6666666666666667')),
#  (33865L, Decimal('80.6666666666666667')),
#  (3480L, Decimal('80.6666666666666667')),
#  (73978L, Decimal('80.6666666666666667')),
#  (72093L, Decimal('80.6666666666666667')),
#  (4960L, Decimal('80.6666666666666667')),
#  (65834L, Decimal('80.6666666666666667')),
#  (10235L, Decimal('80.6666666666666667')),
#  (809L, Decimal('80.6666666666666667')),
#  (9273L, Decimal('80.7500000000000000')),
#  (74374L, Decimal('80.7500000000000000')),
#  (1146L, Decimal('80.7500000000000000')),
#  (6729L, Decimal('80.7500000000000000')),
#  (18298L, Decimal('81.0000000000000000')),
#  (9727L, Decimal('81.0000000000000000')),
#  (2427L, Decimal('81.0000000000000000')),
#  (69584L, Decimal('81.0000000000000000')),
#  (69706L, Decimal('81.0000000000000000')),
#  (81135L, Decimal('81.0000000000000000')),
#  (82898L, Decimal('81.0000000000000000')),
#  (3397L, Decimal('81.0000000000000000')),
#  (3750L, Decimal('81.0000000000000000')),
#  (74593L, Decimal('81.0000000000000000')),
#  (68091L, Decimal('81.0000000000000000')),
#  (82042L, Decimal('81.0000000000000000')),
#  (63286L, Decimal('81.0000000000000000')),
#  (65901L, Decimal('81.0000000000000000')),
#  (13218L, Decimal('81.0000000000000000')),
#  (37482L, Decimal('81.0000000000000000')),
#  (1757L, Decimal('81.0000000000000000')),
#  (38258L, Decimal('81.0000000000000000')),
#  (1830L, Decimal('81.0000000000000000')),
#  (1337L, Decimal('81.0000000000000000')),
#  (76513L, Decimal('81.0000000000000000')),
#  (2807L, Decimal('81.0000000000000000')),
#  (6912L, Decimal('81.0000000000000000')),
#  (74453L, Decimal('81.0000000000000000')),
#  (62824L, Decimal('81.0000000000000000')),
#  (61789L, Decimal('81.0000000000000000')),
#  (1036L, Decimal('81.0000000000000000')),
#  (17647L, Decimal('81.0000000000000000')),
#  (66219L, Decimal('81.0000000000000000')),
#  (83424L, Decimal('81.0000000000000000')),
#  (75942L, Decimal('81.0000000000000000')),
#  (83796L, Decimal('81.0000000000000000')),
#  (80081L, Decimal('81.0000000000000000')),
#  (76425L, Decimal('81.0000000000000000')),
#  (2040L, Decimal('81.0000000000000000')),
#  (3850L, Decimal('81.0000000000000000')),
#  (74981L, Decimal('81.2500000000000000')),
#  (60354L, Decimal('81.2500000000000000')),
#  (33442L, Decimal('81.3333333333333333')),
#  (72004L, Decimal('81.3333333333333333')),
#  (68160L, Decimal('81.3333333333333333')),
#  (76992L, Decimal('81.3333333333333333')),
#  (59251L, Decimal('81.3333333333333333')),
#  (64738L, Decimal('81.3333333333333333')),
#  (59872L, Decimal('81.3333333333333333')),
#  (1583L, Decimal('81.3333333333333333')),
#  (4502L, Decimal('81.5000000000000000')),
#  (69509L, Decimal('81.5000000000000000')),
#  (6948L, Decimal('81.5000000000000000')),
#  (7771L, Decimal('81.5000000000000000')),
#  (3029L, Decimal('81.5000000000000000')),
#  (13753L, Decimal('81.5000000000000000')),
#  (57552L, Decimal('81.5000000000000000')),
#  (3770L, Decimal('81.5000000000000000')),
#  (66361L, Decimal('81.5000000000000000')),
#  (2374L, Decimal('81.5000000000000000')),
#  (2905L, Decimal('81.5000000000000000')),
#  (33747L, Decimal('81.5000000000000000')),
#  (302L, Decimal('81.5000000000000000')),
#  (3963L, Decimal('81.5000000000000000')),
#  (10886L, Decimal('81.6666666666666667')),
#  (77520L, Decimal('81.6666666666666667')),
#  (2969L, Decimal('81.6666666666666667')),
#  (3335L, Decimal('81.6666666666666667')),
#  (68351L, Decimal('81.6666666666666667')),
#  (64843L, Decimal('81.6666666666666667')),
#  (34885L, Decimal('81.6666666666666667')),
#  (66688L, Decimal('81.7500000000000000')),
#  (38201L, Decimal('81.7500000000000000')),
#  (65695L, Decimal('81.7500000000000000')),
#  (3337L, Decimal('81.8000000000000000')),
#  (32698L, Decimal('81.8000000000000000')),
#  (62765L, Decimal('81.8000000000000000')),
#  (65523L, Decimal('81.8571428571428571')),
#  (84418L, Decimal('82.0000000000000000')),
#  (82022L, Decimal('82.0000000000000000')),
#  (67741L, Decimal('82.0000000000000000')),
#  (1788L, Decimal('82.0000000000000000')),
#  (2833L, Decimal('82.0000000000000000')),
#  (709L, Decimal('82.0000000000000000')),
#  (67005L, Decimal('82.0000000000000000')),
#  (81976L, Decimal('82.0000000000000000')),
#  (68172L, Decimal('82.0000000000000000')),
#  (81509L, Decimal('82.0000000000000000')),
#  (77108L, Decimal('82.0000000000000000')),
#  (80280L, Decimal('82.0000000000000000')),
#  (2615L, Decimal('82.0000000000000000')),
#  (2104L, Decimal('82.0000000000000000')),
#  (69282L, Decimal('82.0000000000000000')),
#  (4025L, Decimal('82.0000000000000000')),
#  (29948L, Decimal('82.0000000000000000')),
#  (80127L, Decimal('82.0000000000000000')),
#  (1584L, Decimal('82.0000000000000000')),
#  (34457L, Decimal('82.0000000000000000')),
#  (2357L, Decimal('82.0000000000000000')),
#  (85310L, Decimal('82.0000000000000000')),
#  (63447L, Decimal('82.0000000000000000')),
#  (854L, Decimal('82.0000000000000000')),
#  (60484L, Decimal('82.0000000000000000')),
#  (79961L, Decimal('82.0000000000000000')),
#  (2027L, Decimal('82.0000000000000000')),
#  (83048L, Decimal('82.0000000000000000')),
#  (32702L, Decimal('82.0000000000000000')),
#  (67840L, Decimal('82.0000000000000000')),
#  (2785L, Decimal('82.0000000000000000')),
#  (85173L, Decimal('82.0000000000000000')),
#  (80744L, Decimal('82.0000000000000000')),
#  (64932L, Decimal('82.0000000000000000')),
#  (35852L, Decimal('82.0000000000000000')),
#  (82413L, Decimal('82.0000000000000000')),
#  (6864L, Decimal('82.0000000000000000')),
#  (479L, Decimal('82.0000000000000000')),
#  (59577L, Decimal('82.0000000000000000')),
#  (3528L, Decimal('82.0000000000000000')),
#  (891L, Decimal('82.0000000000000000')),
#  (81458L, Decimal('82.0000000000000000')),
#  (1978L, Decimal('82.2000000000000000')),
#  (71065L, Decimal('82.2000000000000000')),
#  (2902L, Decimal('82.2500000000000000')),
#  (69127L, Decimal('82.2500000000000000')),
#  (66642L, Decimal('82.2500000000000000')),
#  (7493L, Decimal('82.3333333333333333')),
#  (3445L, Decimal('82.3333333333333333')),
#  (64260L, Decimal('82.3333333333333333')),
#  (1880L, Decimal('82.3333333333333333')),
#  (61494L, Decimal('82.3333333333333333')),
#  (3543L, Decimal('82.3333333333333333')),
#  (234L, Decimal('82.3333333333333333')),
#  (64377L, Decimal('82.3333333333333333')),
#  (1595L, Decimal('82.3333333333333333')),
#  (2788L, Decimal('82.3333333333333333')),
#  (1931L, Decimal('82.3333333333333333')),
#  (74210L, Decimal('82.4000000000000000')),
#  (2280L, Decimal('82.4000000000000000')),
#  (10373L, Decimal('82.5000000000000000')),
#  (69750L, Decimal('82.5000000000000000')),
#  (70306L, Decimal('82.5000000000000000')),
#  (35507L, Decimal('82.5000000000000000')),
#  (38442L, Decimal('82.5000000000000000')),
#  (74674L, Decimal('82.5000000000000000')),
#  (77826L, Decimal('82.5000000000000000')),
#  (81103L, Decimal('82.5000000000000000')),
#  (966L, Decimal('82.5000000000000000')),
#  (726L, Decimal('82.5000000000000000')),
#  (69682L, Decimal('82.5000000000000000')),
#  (1571L, Decimal('82.5000000000000000')),
#  (37462L, Decimal('82.5000000000000000')),
#  (63763L, Decimal('82.5000000000000000')),
#  (2932L, Decimal('82.5000000000000000')),
#  (77778L, Decimal('82.5000000000000000')),
#  (687L, Decimal('82.5000000000000000')),
#  (4158L, Decimal('82.5000000000000000')),
#  (2070L, Decimal('82.5000000000000000')),
#  (35221L, Decimal('82.5000000000000000')),
#  (7736L, Decimal('82.5000000000000000')),
#  (80112L, Decimal('82.5000000000000000')),
#  (63757L, Decimal('82.5000000000000000')),
#  (972L, Decimal('82.6666666666666667')),
#  (62739L, Decimal('82.6666666666666667')),
#  (1942L, Decimal('82.6666666666666667')),
#  (71207L, Decimal('82.6666666666666667')),
#  (68909L, Decimal('82.6666666666666667')),
#  (68768L, Decimal('82.6666666666666667')),
#  (65228L, Decimal('82.6666666666666667')),
#  (1526L, Decimal('82.6666666666666667')),
#  (77838L, Decimal('82.6666666666666667')),
#  (68390L, Decimal('82.6666666666666667')),
#  (63429L, Decimal('82.6666666666666667')),
#  (39695L, Decimal('82.6666666666666667')),
#  (35671L, Decimal('82.7500000000000000')),
#  (38427L, Decimal('82.7500000000000000')),
#  (67167L, Decimal('82.7500000000000000')),
#  (2323L, Decimal('82.7500000000000000')),
#  (27949L, Decimal('82.8000000000000000')),
#  (36387L, Decimal('82.8000000000000000')),
#  (66212L, Decimal('82.8333333333333333')),
#  (78835L, Decimal('83.0000000000000000')),
#  (59691L, Decimal('83.0000000000000000')),
#  (35660L, Decimal('83.0000000000000000')),
#  (78521L, Decimal('83.0000000000000000')),
#  (66517L, Decimal('83.0000000000000000')),
#  (68773L, Decimal('83.0000000000000000')),
#  (1930L, Decimal('83.0000000000000000')),
#  (66384L, Decimal('83.0000000000000000')),
#  (37832L, Decimal('83.0000000000000000')),
#  (1332L, Decimal('83.0000000000000000')),
#  (37407L, Decimal('83.0000000000000000')),
#  (81116L, Decimal('83.0000000000000000')),
#  (65050L, Decimal('83.0000000000000000')),
#  (78779L, Decimal('83.0000000000000000')),
#  (468L, Decimal('83.0000000000000000')),
#  (75523L, Decimal('83.0000000000000000')),
#  (5988L, Decimal('83.0000000000000000')),
#  (59041L, Decimal('83.0000000000000000')),
#  (2085L, Decimal('83.0000000000000000')),
#  (68226L, Decimal('83.0000000000000000')),
#  (65012L, Decimal('83.0000000000000000')),
#  (3038L, Decimal('83.0000000000000000')),
#  (3121L, Decimal('83.0000000000000000')),
#  (78295L, Decimal('83.0000000000000000')),
#  (500L, Decimal('83.0000000000000000')),
#  (2732L, Decimal('83.0000000000000000')),
#  (84205L, Decimal('83.0000000000000000')),
#  (80079L, Decimal('83.0000000000000000')),
#  (77173L, Decimal('83.0000000000000000')),
#  (4746L, Decimal('83.0000000000000000')),
#  (82466L, Decimal('83.0000000000000000')),
#  (82869L, Decimal('83.0000000000000000')),
#  (74429L, Decimal('83.0000000000000000')),
#  (3639L, Decimal('83.0000000000000000')),
#  (58803L, Decimal('83.0000000000000000')),
#  (79300L, Decimal('83.0000000000000000')),
#  (78604L, Decimal('83.0000000000000000')),
#  (79626L, Decimal('83.0000000000000000')),
#  (33011L, Decimal('83.0000000000000000')),
#  (78018L, Decimal('83.0000000000000000')),
#  (84106L, Decimal('83.0000000000000000')),
#  (5010L, Decimal('83.0000000000000000')),
#  (1490L, Decimal('83.0000000000000000')),
#  (82891L, Decimal('83.0000000000000000')),
#  (6660L, Decimal('83.0000000000000000')),
#  (69501L, Decimal('83.0000000000000000')),
#  (1963L, Decimal('83.0000000000000000')),
#  (64141L, Decimal('83.0000000000000000')),
#  (68365L, Decimal('83.0000000000000000')),
#  (81704L, Decimal('83.0000000000000000')),
#  (4828L, Decimal('83.0000000000000000')),
#  (7772L, Decimal('83.0000000000000000')),
#  (77759L, Decimal('83.0000000000000000')),
#  (3393L, Decimal('83.0000000000000000')),
#  (18824L, Decimal('83.0000000000000000')),
#  (64454L, Decimal('83.0000000000000000')),
#  (73871L, Decimal('83.2500000000000000')),
#  (66961L, Decimal('83.2500000000000000')),
#  (64814L, Decimal('83.2500000000000000')),
#  (24198L, Decimal('83.3333333333333333')),
#  (74866L, Decimal('83.3333333333333333')),
#  (38091L, Decimal('83.3333333333333333')),
#  (61989L, Decimal('83.3333333333333333')),
#  (68366L, Decimal('83.3333333333333333')),
#  (2156L, Decimal('83.3333333333333333')),
#  (589L, Decimal('83.3333333333333333')),
#  (28843L, Decimal('83.3333333333333333')),
#  (3160L, Decimal('83.4000000000000000')),
#  (4638L, Decimal('83.5000000000000000')),
#  (2883L, Decimal('83.5000000000000000')),
#  (326L, Decimal('83.5000000000000000')),
#  (69759L, Decimal('83.5000000000000000')),
#  (78106L, Decimal('83.5000000000000000')),
#  (37682L, Decimal('83.5000000000000000')),
#  (3262L, Decimal('83.5000000000000000')),
#  (25301L, Decimal('83.5000000000000000')),
#  (8202L, Decimal('83.5000000000000000')),
#  (18800L, Decimal('83.5000000000000000')),
#  (75448L, Decimal('83.5000000000000000')),
#  (5607L, Decimal('83.5000000000000000')),
#  (39810L, Decimal('83.5000000000000000')),
#  (239L, Decimal('83.5000000000000000')),
#  (3241L, Decimal('83.5000000000000000')),
#  (76615L, Decimal('83.5000000000000000')),
#  (3612L, Decimal('83.5000000000000000')),
#  (67875L, Decimal('83.5000000000000000')),
#  (74869L, Decimal('83.5000000000000000')),
#  (74238L, Decimal('83.5000000000000000')),
#  (78852L, Decimal('83.5000000000000000')),
#  (24437L, Decimal('83.5000000000000000')),
#  (28318L, Decimal('83.5000000000000000')),
#  (57584L, Decimal('83.5000000000000000')),
#  (1262L, Decimal('83.6666666666666667')),
#  (70048L, Decimal('83.6666666666666667')),
#  (32170L, Decimal('83.6666666666666667')),
#  (62849L, Decimal('83.6666666666666667')),
#  (2066L, Decimal('83.6666666666666667')),
#  (2599L, Decimal('83.6666666666666667')),
#  (67356L, Decimal('83.6666666666666667')),
#  (520L, Decimal('83.6666666666666667')),
#  (1796L, Decimal('83.6666666666666667')),
#  (59044L, Decimal('83.6666666666666667')),
#  (552L, Decimal('83.6666666666666667')),
#  (7636L, Decimal('83.6666666666666667')),
#  (16513L, Decimal('83.7500000000000000')),
#  (70708L, Decimal('83.7500000000000000')),
#  (4917L, Decimal('83.7500000000000000')),
#  (62735L, Decimal('83.7500000000000000')),
#  (57698L, Decimal('83.7500000000000000')),
#  (4598L, Decimal('84.0000000000000000')),
#  (4462L, Decimal('84.0000000000000000')),
#  (78196L, Decimal('84.0000000000000000')),
#  (36589L, Decimal('84.0000000000000000')),
#  (74149L, Decimal('84.0000000000000000')),
#  (81310L, Decimal('84.0000000000000000')),
#  (78962L, Decimal('84.0000000000000000')),
#  (3682L, Decimal('84.0000000000000000')),
#  (83627L, Decimal('84.0000000000000000')),
#  (57755L, Decimal('84.0000000000000000')),
#  (62978L, Decimal('84.0000000000000000')),
#  (4914L, Decimal('84.0000000000000000')),
#  (71581L, Decimal('84.0000000000000000')),
#  (79334L, Decimal('84.0000000000000000')),
#  (2063L, Decimal('84.0000000000000000')),
#  (1304L, Decimal('84.0000000000000000')),
#  (82485L, Decimal('84.0000000000000000')),
#  (84165L, Decimal('84.0000000000000000')),
#  (61697L, Decimal('84.0000000000000000')),
#  (2107L, Decimal('84.0000000000000000')),
#  (2334L, Decimal('84.0000000000000000')),
#  (18921L, Decimal('84.0000000000000000')),
#  (79196L, Decimal('84.0000000000000000')),
#  (70970L, Decimal('84.0000000000000000')),
#  (2950L, Decimal('84.0000000000000000')),
#  (32736L, Decimal('84.0000000000000000')),
#  (59023L, Decimal('84.0000000000000000')),
#  (3488L, Decimal('84.0000000000000000')),
#  (68090L, Decimal('84.0000000000000000')),
#  (1005L, Decimal('84.0000000000000000')),
#  (75187L, Decimal('84.0000000000000000')),
#  (1747L, Decimal('84.0000000000000000')),
#  (64503L, Decimal('84.0000000000000000')),
#  (6934L, Decimal('84.0000000000000000')),
#  (3832L, Decimal('84.0000000000000000')),
#  (81303L, Decimal('84.0000000000000000')),
#  (70321L, Decimal('84.0000000000000000')),
#  (77457L, Decimal('84.0000000000000000')),
#  (34395L, Decimal('84.0000000000000000')),
#  (69419L, Decimal('84.0000000000000000')),
#  (32919L, Decimal('84.0000000000000000')),
#  (3014L, Decimal('84.0000000000000000')),
#  (24457L, Decimal('84.0000000000000000')),
#  (35828L, Decimal('84.0000000000000000')),
#  (3898L, Decimal('84.0000000000000000')),
#  (71804L, Decimal('84.0000000000000000')),
#  (4531L, Decimal('84.0000000000000000')),
#  (74800L, Decimal('84.0000000000000000')),
#  (67067L, Decimal('84.0000000000000000')),
#  (66255L, Decimal('84.0000000000000000')),
#  (75123L, Decimal('84.0000000000000000')),
#  (3951L, Decimal('84.0000000000000000')),
#  (40216L, Decimal('84.0000000000000000')),
#  (436L, Decimal('84.0000000000000000')),
#  (3536L, Decimal('84.0000000000000000')),
#  (2035L, Decimal('84.0000000000000000')),
#  (81579L, Decimal('84.0000000000000000')),
#  (76962L, Decimal('84.0000000000000000')),
#  (36014L, Decimal('84.0000000000000000')),
#  (74712L, Decimal('84.0000000000000000')),
#  (79656L, Decimal('84.0000000000000000')),
#  (36020L, Decimal('84.0000000000000000')),
#  (79345L, Decimal('84.0000000000000000')),
#  (2684L, Decimal('84.2000000000000000')),
#  (1249L, Decimal('84.2000000000000000')),
#  (75229L, Decimal('84.2000000000000000')),
#  (1566L, Decimal('84.2500000000000000')),
#  (34685L, Decimal('84.2500000000000000')),
#  (4637L, Decimal('84.2500000000000000')),
#  (2454L, Decimal('84.2500000000000000')),
#  (68037L, Decimal('84.3333333333333333')),
#  (68880L, Decimal('84.3333333333333333')),
#  (36786L, Decimal('84.3333333333333333')),
#  (71658L, Decimal('84.3333333333333333')),
#  (13426L, Decimal('84.3333333333333333')),
#  (60331L, Decimal('84.3333333333333333')),
#  (1741L, Decimal('84.3333333333333333')),
#  (64723L, Decimal('84.3333333333333333')),
#  (33117L, Decimal('84.3333333333333333')),
#  (448L, Decimal('84.3333333333333333')),
#  (63755L, Decimal('84.3333333333333333')),
#  (422L, Decimal('84.3333333333333333')),
#  (2622L, Decimal('84.3333333333333333')),
#  (69351L, Decimal('84.3333333333333333')),
#  (18148L, Decimal('84.3333333333333333')),
#  (66363L, Decimal('84.3333333333333333')),
#  (71909L, Decimal('84.4000000000000000')),
#  (64161L, Decimal('84.4000000000000000')),
#  (79145L, Decimal('84.5000000000000000')),
#  (5654L, Decimal('84.5000000000000000')),
#  (66656L, Decimal('84.5000000000000000')),
#  (1631L, Decimal('84.5000000000000000')),
#  (1836L, Decimal('84.5000000000000000')),
#  (60963L, Decimal('84.5000000000000000')),
#  (20116L, Decimal('84.5000000000000000')),
#  (1710L, Decimal('84.5000000000000000')),
#  (2764L, Decimal('84.5000000000000000')),
#  (82252L, Decimal('84.5000000000000000')),
#  (7757L, Decimal('84.5000000000000000')),
#  (4642L, Decimal('84.5000000000000000')),
#  (1596L, Decimal('84.5000000000000000')),
#  (63256L, Decimal('84.5000000000000000')),
#  (2870L, Decimal('84.5000000000000000')),
#  (62730L, Decimal('84.5000000000000000')),
#  (65833L, Decimal('84.5000000000000000')),
#  (39776L, Decimal('84.5000000000000000')),
#  (68148L, Decimal('84.5000000000000000')),
#  (74722L, Decimal('84.5000000000000000')),
#  (66732L, Decimal('84.5000000000000000')),
#  (3802L, Decimal('84.5000000000000000')),
#  (81153L, Decimal('84.5000000000000000')),
#  (10875L, Decimal('84.5000000000000000')),
#  (76411L, Decimal('84.5000000000000000')),
#  (38566L, Decimal('84.5000000000000000')),
#  (76445L, Decimal('84.5000000000000000')),
#  (729L, Decimal('84.6666666666666667')),
#  (18120L, Decimal('84.6666666666666667')),
#  (63653L, Decimal('84.6666666666666667')),
#  (3729L, Decimal('84.6666666666666667')),
#  (36201L, Decimal('84.6666666666666667')),
#  (7491L, Decimal('84.6666666666666667')),
#  (3457L, Decimal('84.6666666666666667')),
#  (36744L, Decimal('84.6666666666666667')),
#  (65614L, Decimal('84.6666666666666667')),
#  (2933L, Decimal('84.6666666666666667')),
#  (70521L, Decimal('84.6666666666666667')),
#  (30532L, Decimal('84.6666666666666667')),
#  (62710L, Decimal('84.6666666666666667')),
#  (2199L, Decimal('84.6666666666666667')),
#  (70022L, Decimal('84.7500000000000000')),
#  (325L, Decimal('84.7500000000000000')),
#  (3133L, Decimal('84.7500000000000000')),
#  (442L, Decimal('84.7500000000000000')),
#  (67448L, Decimal('84.7500000000000000')),
#  (272L, Decimal('84.7500000000000000')),
#  (4780L, Decimal('84.7500000000000000')),
#  (415L, Decimal('84.7500000000000000')),
#  (29429L, Decimal('84.7500000000000000')),
#  (39481L, Decimal('84.8000000000000000')),
#  (33448L, Decimal('85.0000000000000000')),
#  (77772L, Decimal('85.0000000000000000')),
#  (57653L, Decimal('85.0000000000000000')),
#  (74993L, Decimal('85.0000000000000000')),
#  (76876L, Decimal('85.0000000000000000')),
#  (81937L, Decimal('85.0000000000000000')),
#  (59179L, Decimal('85.0000000000000000')),
#  (84543L, Decimal('85.0000000000000000')),
#  (65902L, Decimal('85.0000000000000000')),
#  (2053L, Decimal('85.0000000000000000')),
#  (85319L, Decimal('85.0000000000000000')),
#  (4935L, Decimal('85.0000000000000000')),
#  (33891L, Decimal('85.0000000000000000')),
#  (37344L, Decimal('85.0000000000000000')),
#  (63945L, Decimal('85.0000000000000000')),
#  (5068L, Decimal('85.0000000000000000')),
#  (33911L, Decimal('85.0000000000000000')),
#  (83612L, Decimal('85.0000000000000000')),
#  (66394L, Decimal('85.0000000000000000')),
#  (79269L, Decimal('85.0000000000000000')),
#  (79390L, Decimal('85.0000000000000000')),
#  (4427L, Decimal('85.0000000000000000')),
#  (3345L, Decimal('85.0000000000000000')),
#  (2995L, Decimal('85.0000000000000000')),
#  (3072L, Decimal('85.0000000000000000')),
#  (64849L, Decimal('85.0000000000000000')),
#  (65635L, Decimal('85.0000000000000000')),
#  (84394L, Decimal('85.0000000000000000')),
#  (7361L, Decimal('85.0000000000000000')),
#  (80374L, Decimal('85.0000000000000000')),
#  (7207L, Decimal('85.0000000000000000')),
#  (79563L, Decimal('85.0000000000000000')),
#  (69191L, Decimal('85.0000000000000000')),
#  (847L, Decimal('85.0000000000000000')),
#  (37732L, Decimal('85.0000000000000000')),
#  (37405L, Decimal('85.0000000000000000')),
#  (320L, Decimal('85.0000000000000000')),
#  (79515L, Decimal('85.0000000000000000')),
#  (2418L, Decimal('85.0000000000000000')),
#  (85972L, Decimal('85.0000000000000000')),
#  (77951L, Decimal('85.0000000000000000')),
#  (83779L, Decimal('85.0000000000000000')),
#  (34126L, Decimal('85.0000000000000000')),
#  (78528L, Decimal('85.0000000000000000')),
#  (4479L, Decimal('85.0000000000000000')),
#  (63258L, Decimal('85.0000000000000000')),
#  (18874L, Decimal('85.0000000000000000')),
#  (3731L, Decimal('85.0000000000000000')),
#  (3591L, Decimal('85.0000000000000000')),
#  (78184L, Decimal('85.0000000000000000')),
#  (1396L, Decimal('85.0000000000000000')),
#  (83321L, Decimal('85.0000000000000000')),
#  (84530L, Decimal('85.0000000000000000')),
#  (84256L, Decimal('85.0000000000000000')),
#  (35565L, Decimal('85.0000000000000000')),
#  ...]

# %%
# %%sql
# select business_id, count(*) from inspections
# group by business_id order by count(*) desc;
# Out:
# 5513 rows affected.
# [(66328L, 8L),
#  (5791L, 8L),
#  (5297L, 8L),
#  (5790L, 7L),
#  (5499L, 7L),
#  (5628L, 7L),
#  (65893L, 7L),
#  (5461L, 7L),
#  (5497L, 7L),
#  (5471L, 7L),
#  (5479L, 7L),
#  (5955L, 7L),
#  (5868L, 7L),
#  (5829L, 7L),
#  (5487L, 7L),
#  (5818L, 7L),
#  (69048L, 7L),
#  (5507L, 7L),
#  (5633L, 7L),
#  (5486L, 7L),
#  (5641L, 7L),
#  (65523L, 7L),
#  (5958L, 7L),
#  (5658L, 7L),
#  (5626L, 7L),
#  (5649L, 7L),
#  (5480L, 7L),
#  (5831L, 7L),
#  (5843L, 7L),
#  (5455L, 7L),
#  (5450L, 7L),
#  (5788L, 7L),
#  (5859L, 7L),
#  (5875L, 7L),
#  (5627L, 7L),
#  (5871L, 7L),
#  (5794L, 7L),
#  (67869L, 7L),
#  (5810L, 7L),
#  (5789L, 7L),
#  (5500L, 7L),
#  (74336L, 7L),
#  (5792L, 7L),
#  (5839L, 7L),
#  (5787L, 7L),
#  (5853L, 6L),
#  (5849L, 6L),
#  (4688L, 6L),
#  (2002L, 6L),
#  (5892L, 6L),
#  (4732L, 6L),
#  (5807L, 6L),
#  (4683L, 6L),
#  (5803L, 6L),
#  (71726L, 6L),
#  (5852L, 6L),
#  (5880L, 6L),
#  (11488L, 6L),
#  (5470L, 6L),
#  (5816L, 6L),
#  (66687L, 6L),
#  (5858L, 6L),
#  (66212L, 6L),
#  (5827L, 6L),
#  (5946L, 6L),
#  (5838L, 6L),
#  (5821L, 6L),
#  (5874L, 6L),
#  (5862L, 6L),
#  (61728L, 6L),
#  (5886L, 6L),
#  (71532L, 6L),
#  (8882L, 6L),
#  (5495L, 6L),
#  (2667L, 6L),
#  (5796L, 6L),
#  (64176L, 6L),
#  (67840L, 6L),
#  (5860L, 6L),
#  (2279L, 6L),
#  (5855L, 6L),
#  (3260L, 6L),
#  (66L, 6L),
#  (78372L, 6L),
#  (5833L, 6L),
#  (5903L, 6L),
#  (1516L, 6L),
#  (1261L, 6L),
#  (5808L, 6L),
#  (5819L, 6L),
#  (71760L, 6L),
#  (2505L, 6L),
#  (5867L, 6L),
#  (67871L, 6L),
#  (5960L, 6L),
#  (69707L, 6L),
#  (5797L, 6L),
#  (5902L, 6L),
#  (5898L, 6L),
#  (5642L, 6L),
#  (68196L, 6L),
#  (61500L, 6L),
#  (5644L, 6L),
#  (3736L, 6L),
#  (62708L, 6L),
#  (5876L, 6L),
#  (5905L, 6L),
#  (5908L, 6L),
#  (5856L, 6L),
#  (547L, 6L),
#  (70849L, 6L),
#  (5657L, 6L),
#  (10377L, 6L),
#  (5851L, 6L),
#  (5634L, 6L),
#  (5866L, 6L),
#  (5815L, 6L),
#  (522L, 6L),
#  (5820L, 6L),
#  (70961L, 6L),
#  (5897L, 6L),
#  (5888L, 6L),
#  (5501L, 6L),
#  (62072L, 6L),
#  (5885L, 6L),
#  (5800L, 6L),
#  (60649L, 6L),
#  (70044L, 6L),
#  (5901L, 6L),
#  (5942L, 6L),
#  (5449L, 6L),
#  (5825L, 6L),
#  (5926L, 6L),
#  (5863L, 6L),
#  (74760L, 6L),
#  (5884L, 6L),
#  (69984L, 6L),
#  (5881L, 6L),
#  (5823L, 6L),
#  (5927L, 6L),
#  (5895L, 6L),
#  (5894L, 6L),
#  (5805L, 6L),
#  (5865L, 6L),
#  (7689L, 6L),
#  (5824L, 6L),
#  (5465L, 6L),
#  (36396L, 6L),
#  (5837L, 6L),
#  (1413L, 6L),
#  (5814L, 6L),
#  (5478L, 6L),
#  (5913L, 6L),
#  (5636L, 6L),
#  (5842L, 6L),
#  (5467L, 6L),
#  (5864L, 6L),
#  (5889L, 6L),
#  (35340L, 6L),
#  (5940L, 6L),
#  (34910L, 6L),
#  (69527L, 6L),
#  (14740L, 6L),
#  (4545L, 6L),
#  (76445L, 6L),
#  (4636L, 6L),
#  (76355L, 6L),
#  (3936L, 6L),
#  (13062L, 6L),
#  (64502L, 6L),
#  (30156L, 6L),
#  (5643L, 6L),
#  (5938L, 6L),
#  (6756L, 6L),
#  (5033L, 5L),
#  (74710L, 5L),
#  (78369L, 5L),
#  (62746L, 5L),
#  (2357L, 5L),
#  (258L, 5L),
#  (10280L, 5L),
#  (5801L, 5L),
#  (5869L, 5L),
#  (65392L, 5L),
#  (62316L, 5L),
#  (1912L, 5L),
#  (5143L, 5L),
#  (72132L, 5L),
#  (2810L, 5L),
#  (5872L, 5L),
#  (3253L, 5L),
#  (75078L, 5L),
#  (17822L, 5L),
#  (62765L, 5L),
#  (2455L, 5L),
#  (61285L, 5L),
#  (61161L, 5L),
#  (68259L, 5L),
#  (5962L, 5L),
#  (35884L, 5L),
#  (75701L, 5L),
#  (2245L, 5L),
#  (5804L, 5L),
#  (68945L, 5L),
#  (5624L, 5L),
#  (3562L, 5L),
#  (17992L, 5L),
#  (38485L, 5L),
#  (69799L, 5L),
#  (59935L, 5L),
#  (507L, 5L),
#  (68894L, 5L),
#  (70993L, 5L),
#  (73889L, 5L),
#  (64195L, 5L),
#  (75678L, 5L),
#  (4209L, 5L),
#  (68618L, 5L),
#  (68690L, 5L),
#  (5817L, 5L),
#  (69294L, 5L),
#  (1465L, 5L),
#  (32556L, 5L),
#  (10238L, 5L),
#  (4849L, 5L),
#  (5937L, 5L),
#  (3229L, 5L),
#  (71611L, 5L),
#  (68493L, 5L),
#  (68428L, 5L),
#  (5489L, 5L),
#  (68974L, 5L),
#  (1156L, 5L),
#  (1671L, 5L),
#  (13814L, 5L),
#  (2352L, 5L),
#  (11079L, 5L),
#  (7645L, 5L),
#  (7761L, 5L),
#  (71385L, 5L),
#  (65111L, 5L),
#  (5999L, 5L),
#  (68895L, 5L),
#  (69291L, 5L),
#  (1757L, 5L),
#  (3951L, 5L),
#  (1103L, 5L),
#  (5651L, 5L),
#  (1712L, 5L),
#  (66771L, 5L),
#  (70071L, 5L),
#  (7728L, 5L),
#  (5490L, 5L),
#  (949L, 5L),
#  (5870L, 5L),
#  (74023L, 5L),
#  (19076L, 5L),
#  (527L, 5L),
#  (919L, 5L),
#  (489L, 5L),
#  (36876L, 5L),
#  (71997L, 5L),
#  (36473L, 5L),
#  (5452L, 5L),
#  (38247L, 5L),
#  (39608L, 5L),
#  (60551L, 5L),
#  (74210L, 5L),
#  (874L, 5L),
#  (75888L, 5L),
#  (36911L, 5L),
#  (5074L, 5L),
#  (3485L, 5L),
#  (5907L, 5L),
#  (5077L, 5L),
#  (75063L, 5L),
#  (76906L, 5L),
#  (32579L, 5L),
#  (15055L, 5L),
#  (1381L, 5L),
#  (68079L, 5L),
#  (4952L, 5L),
#  (1249L, 5L),
#  (18102L, 5L),
#  (36387L, 5L),
#  (5025L, 5L),
#  (5974L, 5L),
#  (75350L, 5L),
#  (32625L, 5L),
#  (10931L, 5L),
#  (2837L, 5L),
#  (4850L, 5L),
#  (66297L, 5L),
#  (37658L, 5L),
#  (5630L, 5L),
#  (2632L, 5L),
#  (5961L, 5L),
#  (67176L, 5L),
#  (34865L, 5L),
#  (5504L, 5L),
#  (1289L, 5L),
#  (59009L, 5L),
#  (66808L, 5L),
#  (7214L, 5L),
#  (5459L, 5L),
#  (146L, 5L),
#  (4085L, 5L),
#  (71065L, 5L),
#  (59066L, 5L),
#  (37656L, 5L),
#  (79586L, 5L),
#  (3911L, 5L),
#  (34989L, 5L),
#  (5505L, 5L),
#  (5813L, 5L),
#  (580L, 5L),
#  (1102L, 5L),
#  (10030L, 5L),
#  (1081L, 5L),
#  (509L, 5L),
#  (66536L, 5L),
#  (63618L, 5L),
#  (61056L, 5L),
#  (3165L, 5L),
#  (5811L, 5L),
#  (68775L, 5L),
#  (67920L, 5L),
#  (59407L, 5L),
#  (78367L, 5L),
#  (5457L, 5L),
#  (60210L, 5L),
#  (62010L, 5L),
#  (1515L, 5L),
#  (61251L, 5L),
#  (5071L, 5L),
#  (1632L, 5L),
#  (4686L, 5L),
#  (3337L, 5L),
#  (33914L, 5L),
#  (75853L, 5L),
#  (9358L, 5L),
#  (5891L, 5L),
#  (3591L, 5L),
#  (2692L, 5L),
#  (64161L, 5L),
#  (64501L, 5L),
#  (4800L, 5L),
#  (1122L, 5L),
#  (74128L, 5L),
#  (66534L, 5L),
#  (67486L, 5L),
#  (64116L, 5L),
#  (6768L, 5L),
#  (1204L, 5L),
#  (69909L, 5L),
#  (34708L, 5L),
#  (61136L, 5L),
#  (67075L, 5L),
#  (5522L, 5L),
#  (5850L, 5L),
#  (7646L, 5L),
#  (18256L, 5L),
#  (74328L, 5L),
#  (11487L, 5L),
#  (68716L, 5L),
#  (2261L, 5L),
#  (5006L, 5L),
#  (1978L, 5L),
#  (39495L, 5L),
#  (65692L, 5L),
#  (33272L, 5L),
#  (1517L, 5L),
#  (70425L, 5L),
#  (64859L, 5L),
#  (76230L, 5L),
#  (4959L, 5L),
#  (5993L, 5L),
#  (5621L, 5L),
#  (69016L, 5L),
#  (57628L, 5L),
#  (2337L, 5L),
#  (3743L, 5L),
#  (69830L, 5L),
#  (65895L, 5L),
#  (5493L, 5L),
#  (2684L, 5L),
#  (65819L, 5L),
#  (13427L, 5L),
#  (2797L, 5L),
#  (1458L, 5L),
#  (5883L, 5L),
#  (74563L, 5L),
#  (13374L, 5L),
#  (79906L, 5L),
#  (36523L, 5L),
#  (951L, 5L),
#  (32925L, 5L),
#  (71640L, 5L),
#  (5919L, 5L),
#  (76441L, 5L),
#  (27949L, 5L),
#  (1339L, 5L),
#  (11416L, 5L),
#  (3902L, 5L),
#  (7641L, 5L),
#  (76371L, 5L),
#  (11835L, 5L),
#  (34201L, 5L),
#  (69181L, 5L),
#  (2427L, 5L),
#  (4584L, 5L),
#  (5485L, 5L),
#  (79905L, 5L),
#  (2326L, 5L),
#  (298L, 5L),
#  (69448L, 5L),
#  (71806L, 5L),
#  (2957L, 5L),
#  (14971L, 5L),
#  (5631L, 5L),
#  (5950L, 5L),
#  (1734L, 5L),
#  (40212L, 5L),
#  (70184L, 5L),
#  (6966L, 5L),
#  (7786L, 5L),
#  (3160L, 5L),
#  (60697L, 5L),
#  (2356L, 5L),
#  (62784L, 5L),
#  (75229L, 5L),
#  (5847L, 5L),
#  (2262L, 5L),
#  (74429L, 5L),
#  (74202L, 5L),
#  (33568L, 5L),
#  (920L, 5L),
#  (2280L, 5L),
#  (20291L, 5L),
#  (2268L, 5L),
#  (76233L, 5L),
#  (260L, 5L),
#  (71443L, 5L),
#  (994L, 5L),
#  (32698L, 5L),
#  (1896L, 5L),
#  (2863L, 5L),
#  (34046L, 5L),
#  (4685L, 5L),
#  (68189L, 5L),
#  (155L, 5L),
#  (70216L, 5L),
#  (69465L, 5L),
#  (75139L, 5L),
#  (275L, 5L),
#  (13838L, 5L),
#  (5635L, 5L),
#  (1747L, 5L),
#  (3738L, 5L),
#  (18047L, 5L),
#  (5953L, 5L),
#  (1882L, 5L),
#  (67617L, 5L),
#  (75055L, 5L),
#  (5828L, 5L),
#  (1144L, 5L),
#  (7664L, 5L),
#  (5623L, 5L),
#  (71909L, 5L),
#  (60400L, 5L),
#  (5650L, 5L),
#  (5912L, 5L),
#  (63169L, 5L),
#  (64101L, 5L),
#  (5524L, 5L),
#  (33077L, 5L),
#  (5893L, 5L),
#  (5844L, 5L),
#  (2861L, 5L),
#  (5629L, 5L),
#  (1833L, 5L),
#  (72153L, 5L),
#  (7772L, 5L),
#  (5645L, 5L),
#  (78653L, 5L),
#  (4449L, 5L),
#  (39481L, 5L),
#  (59520L, 5L),
#  (5812L, 5L),
#  (76698L, 5L),
#  (2358L, 5L),
#  (5802L, 5L),
#  (71286L, 5L),
#  (5841L, 5L),
#  (70824L, 5L),
#  (5488L, 5L),
#  (79587L, 5L),
#  (69237L, 5L),
#  (961L, 5L),
#  (6012L, 5L),
#  (2643L, 5L),
#  (2115L, 5L),
#  (78366L, 5L),
#  (70516L, 5L),
#  (39401L, 5L),
#  (7649L, 5L),
#  (70494L, 5L),
#  (9310L, 5L),
#  (2343L, 4L),
#  (65820L, 4L),
#  (27055L, 4L),
#  (7475L, 4L),
#  (2709L, 4L),
#  (3838L, 4L),
#  (64706L, 4L),
#  (39025L, 4L),
#  (65554L, 4L),
#  (59002L, 4L),
#  (3899L, 4L),
#  (64361L, 4L),
#  (15279L, 4L),
#  (23068L, 4L),
#  (2072L, 4L),
#  (63082L, 4L),
#  (442L, 4L),
#  (62775L, 4L),
#  (71910L, 4L),
#  (1584L, 4L),
#  (56L, 4L),
#  (36850L, 4L),
#  (67184L, 4L),
#  (65026L, 4L),
#  (16047L, 4L),
#  (66642L, 4L),
#  (2767L, 4L),
#  (69234L, 4L),
#  (3241L, 4L),
#  (73871L, 4L),
#  (70446L, 4L),
#  (59651L, 4L),
#  (5997L, 4L),
#  (2917L, 4L),
#  (32683L, 4L),
#  (66688L, 4L),
#  (19171L, 4L),
#  (3031L, 4L),
#  (66656L, 4L),
#  (70549L, 4L),
#  (68013L, 4L),
#  (315L, 4L),
#  (3323L, 4L),
#  (98L, 4L),
#  (68963L, 4L),
#  (68042L, 4L),
#  (10376L, 4L),
#  (3948L, 4L),
#  (19373L, 4L),
#  (17411L, 4L),
#  (1003L, 4L),
#  (39050L, 4L),
#  (60256L, 4L),
#  (75738L, 4L),
#  (36685L, 4L),
#  (35671L, 4L),
#  (32738L, 4L),
#  (62882L, 4L),
#  (67743L, 4L),
#  (18538L, 4L),
#  (34685L, 4L),
#  (65624L, 4L),
#  (19082L, 4L),
#  (8251L, 4L),
#  (3750L, 4L),
#  (11492L, 4L),
#  (6625L, 4L),
#  (76208L, 4L),
#  (65925L, 4L),
#  (38458L, 4L),
#  (59484L, 4L),
#  (62941L, 4L),
#  (5639L, 4L),
#  (63860L, 4L),
#  (37234L, 4L),
#  (5463L, 4L),
#  (38201L, 4L),
#  (60787L, 4L),
#  (7087L, 4L),
#  (3420L, 4L),
#  (7207L, 4L),
#  (37639L, 4L),
#  (65622L, 4L),
#  (9273L, 4L),
#  (68508L, 4L),
#  (69627L, 4L),
#  (65115L, 4L),
#  (72020L, 4L),
#  (72049L, 4L),
#  (4999L, 4L),
#  (3586L, 4L),
#  (66382L, 4L),
#  (65795L, 4L),
#  (69049L, 4L),
#  (70779L, 4L),
#  (5084L, 4L),
#  (68832L, 4L),
#  (2055L, 4L),
#  (70487L, 4L),
#  (38822L, 4L),
#  (65427L, 4L),
#  (59898L, 4L),
#  (68811L, 4L),
#  (59124L, 4L),
#  (5622L, 4L),
#  (65673L, 4L),
#  (63943L, 4L),
#  (69324L, 4L),
#  (9797L, 4L),
#  (69635L, 4L),
#  (34787L, 4L),
#  (33700L, 4L),
#  (64380L, 4L),
#  (33315L, 4L),
#  (69147L, 4L),
#  (27053L, 4L),
#  (7457L, 4L),
#  (37717L, 4L),
#  (39667L, 4L),
#  (60473L, 4L),
#  (3676L, 4L),
#  (1203L, 4L),
#  (59832L, 4L),
#  (33247L, 4L),
#  (5977L, 4L),
#  (40144L, 4L),
#  (4544L, 4L),
#  (935L, 4L),
#  (19172L, 4L),
#  (76117L, 4L),
#  (4978L, 4L),
#  (7643L, 4L),
#  (4703L, 4L),
#  (66717L, 4L),
#  (6962L, 4L),
#  (3942L, 4L),
#  (70661L, 4L),
#  (2454L, 4L),
#  (71962L, 4L),
#  (65826L, 4L),
#  (66276L, 4L),
#  (78656L, 4L),
#  (28468L, 4L),
#  (423L, 4L),
#  (279L, 4L),
#  (64092L, 4L),
#  (2433L, 4L),
#  (7779L, 4L),
#  (62140L, 4L),
#  (35221L, 4L),
#  (68955L, 4L),
#  (69064L, 4L),
#  (905L, 4L),
#  (69419L, 4L),
#  (36699L, 4L),
#  (40008L, 4L),
#  (320L, 4L),
#  (1352L, 4L),
#  (59372L, 4L),
#  (627L, 4L),
#  (71154L, 4L),
#  (3029L, 4L),
#  (200L, 4L),
#  (141L, 4L),
#  (60602L, 4L),
#  (67584L, 4L),
#  (71723L, 4L),
#  (2780L, 4L),
#  (65103L, 4L),
#  (68503L, 4L),
#  (65549L, 4L),
#  (74239L, 4L),
#  (95L, 4L),
#  (10227L, 4L),
#  (69621L, 4L),
#  (4953L, 4L),
#  (71980L, 4L),
#  (5952L, 4L),
#  (9232L, 4L),
#  (33709L, 4L),
#  (63256L, 4L),
#  (2315L, 4L),
#  (4837L, 4L),
#  (39420L, 4L),
#  (67875L, 4L),
#  (4702L, 4L),
#  (66173L, 4L),
#  (68410L, 4L),
#  (74432L, 4L),
#  (27737L, 4L),
#  (66684L, 4L),
#  (38752L, 4L),
#  (2077L, 4L),
#  (2173L, 4L),
#  (60555L, 4L),
#  (71664L, 4L),
#  (27680L, 4L),
#  (69813L, 4L),
#  (4817L, 4L),
#  (66894L, 4L),
#  (4754L, 4L),
#  (74436L, 4L),
#  (69666L, 4L),
#  (60963L, 4L),
#  (63757L, 4L),
#  (691L, 4L),
#  (2980L, 4L),
#  (10083L, 4L),
#  (5458L, 4L),
#  (4705L, 4L),
#  (6009L, 4L),
#  (71362L, 4L),
#  (72025L, 4L),
#  (58861L, 4L),
#  (558L, 4L),
#  (393L, 4L),
#  (2127L, 4L),
#  (8005L, 4L),
#  (25151L, 4L),
#  (63615L, 4L),
#  (11860L, 4L),
#  (60114L, 4L),
#  (67L, 4L),
#  (72120L, 4L),
#  (3237L, 4L),
#  (74999L, 4L),
#  (74374L, 4L),
#  (7744L, 4L),
#  (1362L, 4L),
#  (70321L, 4L),
#  (4708L, 4L),
#  (2610L, 4L),
#  (68699L, 4L),
#  (60254L, 4L),
#  (66336L, 4L),
#  (58850L, 4L),
#  (2615L, 4L),
#  (7394L, 4L),
#  (1154L, 4L),
#  (60936L, 4L),
#  (2690L, 4L),
#  (25161L, 4L),
#  (36451L, 4L),
#  (13226L, 4L),
#  (69317L, 4L),
#  (2973L, 4L),
#  (63576L, 4L),
#  (4780L, 4L),
#  (69397L, 4L),
#  (62550L, 4L),
#  (3623L, 4L),
#  (325L, 4L),
#  (2336L, 4L),
#  (3839L, 4L),
#  (5985L, 4L),
#  (20327L, 4L),
#  (68814L, 4L),
#  (17763L, 4L),
#  (60354L, 4L),
#  (15752L, 4L),
#  (68860L, 4L),
#  (66861L, 4L),
#  (9183L, 4L),
#  (69861L, 4L),
#  (62816L, 4L),
#  (63893L, 4L),
#  (505L, 4L),
#  (4716L, 4L),
#  (74399L, 4L),
#  (318L, 4L),
#  (39888L, 4L),
#  (3477L, 4L),
#  (66702L, 4L),
#  (65582L, 4L),
#  (5830L, 4L),
#  (24431L, 4L),
#  (64242L, 4L),
#  (64814L, 4L),
#  (59949L, 4L),
#  (60290L, 4L),
#  (70281L, 4L),
#  (68362L, 4L),
#  (79406L, 4L),
#  (37882L, 4L),
#  (63940L, 4L),
#  (62769L, 4L),
#  (68379L, 4L),
#  (5498L, 4L),
#  (9208L, 4L),
#  (3870L, 4L),
#  (76604L, 4L),
#  (36024L, 4L),
#  (63763L, 4L),
#  (69275L, 4L),
#  (10572L, 4L),
#  (26146L, 4L),
#  (68839L, 4L),
#  (2945L, 4L),
#  (8821L, 4L),
#  (4957L, 4L),
#  (75230L, 4L),
#  (1811L, 4L),
#  (12344L, 4L),
#  (35507L, 4L),
#  (1359L, 4L),
#  (642L, 4L),
#  (9745L, 4L),
#  (62532L, 4L),
#  (77894L, 4L),
#  (38565L, 4L),
#  (2094L, 4L),
#  (64319L, 4L),
#  (66592L, 4L),
#  (18815L, 4L),
#  (6025L, 4L),
#  (4555L, 4L),
#  (6016L, 4L),
#  (36178L, 4L),
#  (62921L, 4L),
#  (74312L, 4L),
#  (34505L, 4L),
#  (2325L, 4L),
#  (74133L, 4L),
#  (67167L, 4L),
#  (3267L, 4L),
#  (1710L, 4L),
#  (35591L, 4L),
#  (2216L, 4L),
#  (21909L, 4L),
#  (69957L, 4L),
#  (39862L, 4L),
#  (70603L, 4L),
#  (58576L, 4L),
#  (2601L, 4L),
#  (38875L, 4L),
#  (59638L, 4L),
#  (69976L, 4L),
#  (67911L, 4L),
#  (72159L, 4L),
#  (4610L, 4L),
#  (68944L, 4L),
#  (63413L, 4L),
#  (64231L, 4L),
#  (2517L, 4L),
#  (70562L, 4L),
#  (6348L, 4L),
#  (6654L, 4L),
#  (1243L, 4L),
#  (71477L, 4L),
#  (2193L, 4L),
#  (69012L, 4L),
#  (66919L, 4L),
#  (25048L, 4L),
#  (2420L, 4L),
#  (4530L, 4L),
#  (18767L, 4L),
#  (69863L, 4L),
#  (5011L, 4L),
#  (5460L, 4L),
#  (36673L, 4L),
#  (65479L, 4L),
#  (7211L, 4L),
#  (4559L, 4L),
#  (59397L, 4L),
#  (3550L, 4L),
#  (39031L, 4L),
#  (69044L, 4L),
#  (1511L, 4L),
#  (69135L, 4L),
#  (5083L, 4L),
#  (74981L, 4L),
#  (65271L, 4L),
#  (58673L, 4L),
#  (335L, 4L),
#  (4492L, 4L),
#  (70939L, 4L),
#  (69207L, 4L),
#  (4986L, 4L),
#  (67448L, 4L),
#  (38030L, 4L),
#  (5469L, 4L),
#  (3426L, 4L),
#  (3046L, 4L),
#  (4445L, 4L),
#  (38202L, 4L),
#  (63663L, 4L),
#  (29428L, 4L),
#  (62939L, 4L),
#  (34665L, 4L),
#  (7748L, 4L),
#  (69387L, 4L),
#  (69172L, 4L),
#  (2659L, 4L),
#  (6564L, 4L),
#  (77169L, 4L),
#  (37507L, 4L),
#  (856L, 4L),
#  (5662L, 4L),
#  (5618L, 4L),
#  (17736L, 4L),
#  (6660L, 4L),
#  (65695L, 4L),
#  (67895L, 4L),
#  (59316L, 4L),
#  (253L, 4L),
#  (31568L, 4L),
#  (2870L, 4L),
#  (27964L, 4L),
#  (64945L, 4L),
#  (66921L, 4L),
#  (7480L, 4L),
#  (64717L, 4L),
#  (5620L, 4L),
#  (1048L, 4L),
#  (63095L, 4L),
#  (1939L, 4L),
#  (811L, 4L),
#  (59141L, 4L),
#  (74994L, 4L),
#  (62688L, 4L),
#  (62814L, 4L),
#  (69125L, 4L),
#  (33198L, 4L),
#  (5646L, 4L),
#  (28836L, 4L),
#  (1674L, 4L),
#  (2035L, 4L),
#  (66896L, 4L),
#  (28318L, 4L),
#  (65369L, 4L),
#  (65485L, 4L),
#  (67187L, 4L),
#  (4706L, 4L),
#  (5496L, 4L),
#  (2346L, 4L),
#  (3651L, 4L),
#  (78370L, 4L),
#  (2902L, 4L),
#  (10875L, 4L),
#  (75452L, 4L),
#  (10438L, 4L),
#  (10470L, 4L),
#  (34649L, 4L),
#  (71320L, 4L),
#  (5150L, 4L),
#  (5503L, 4L),
#  (64549L, 4L),
#  (70713L, 4L),
#  (70110L, 4L),
#  (64466L, 4L),
#  (61436L, 4L),
#  (63624L, 4L),
#  (59599L, 4L),
#  (1768L, 4L),
#  (6948L, 4L),
#  (1544L, 4L),
#  (4607L, 4L),
#  (38073L, 4L),
#  (639L, 4L),
#  (5085L, 4L),
#  (2756L, 4L),
#  (60544L, 4L),
#  (1927L, 4L),
#  (69188L, 4L),
#  (68254L, 4L),
#  (1493L, 4L),
#  (62357L, 4L),
#  (76685L, 4L),
#  (66637L, 4L),
#  (27851L, 4L),
#  (18310L, 4L),
#  (208L, 4L),
#  (69938L, 4L),
#  (62176L, 4L),
#  (65679L, 4L),
#  (69127L, 4L),
#  (18369L, 4L),
#  (5617L, 4L),
#  (2369L, 4L),
#  (61736L, 4L),
#  (60898L, 4L),
#  (71803L, 4L),
#  (74481L, 4L),
#  (75836L, 4L),
#  (7546L, 4L),
#  (968L, 4L),
#  (6010L, 4L),
#  (76431L, 4L),
#  (39586L, 4L),
#  (60318L, 4L),
#  (58628L, 4L),
#  (5968L, 4L),
#  ...]

# %%
s = %sql select a.business_id, average_score, \
number_of_inspections, number_of_violations \
from (select business_id, avg(score) as average_score, count(*) as number_of_inspections from inspections \
group by business_id) as a \
join (select business_id, count(*) as number_of_violations from violations group by business_id) as b \
on a.business_id = b.business_id;
# Out:
# 4995 rows affected.

# %%
s = s.DataFrame()

# %%
s.head()
# Out:
#    business_id        average_score  number_of_inspections  \
# 0           10  93.0000000000000000                      2
# 1           19  94.6666666666666667                      3
# 2           24  97.0000000000000000                      4
# 3           31  99.0000000000000000                      2
# 4           45  88.6666666666666667                      3
#
#    number_of_violations
# 0                     5
# 1                     5
# 2                     5
# 3                     1
# 4                    12

# %%
s['average_score'] = s['average_score'].apply(float)

# %%
import seaborn as sns

# %%
sns.pairplot(s)

# %%
from pandas.tools.plotting import scatter_matrix

# %%
scatter_matrix(s, figsize=(6, 6));

# %% [markdown]
# ## 3 Zipcode analysis
#
# The town administration would like to know which zip code are the ones where they should focus the inspections.
#
# Use the information contained in the `businesses` table as well as the previous tables to answer the following questions using SQL:
#
# 1. Count the number of businesses per zipcode and sort them by descending order
# - Which are the top 5 zipcodes with the worst average score?
#     - restrict your analysis to the zipcodes with at least 50 businesses
#     - do a simple average of the inspections scores in the postal code
# - Which are the top 5 zipcodes with the highest number of violations per restaurant?
#     - restrict your  analysis to the zipcodes with at least 50 businesses

# %%
# %%sql
# select postal_code, count(business_id)
# from businesses
# group by postal_code
# order by count(business_id) desc limit 10;
# Out:
# 10 rows affected.
# [(u'94110', 559L),
#  (u'94103', 552L),
#  (u'94102', 447L),
#  (u'94107', 429L),
#  (u'94133', 425L),
#  (u'94109', 374L),
#  (u'94111', 280L),
#  (u'94122', 258L),
#  (u'94118', 244L),
#  (None, 240L)]

# %%
# %%sql
# select postal_code, avg(score)
# from businesses b join inspections i on b.business_id = i.business_id
# group by postal_code
# having count(b.business_id) > 50
# order by avg(score) asc limit 5;
# Out:
# 5 rows affected.
# [(u'94133', Decimal('87.4457142857142857')),
#  (u'94122', Decimal('87.6196319018404908')),
#  (u'94109', Decimal('89.1738241308793456')),
#  (u'94108', Decimal('89.8853974121996303')),
#  (u'94127', Decimal('90.2487046632124352'))]

# %%
# %%sql
# select postal_code, count(v.business_id)/count(distinct v.business_id) as violation_restaurant
# from businesses b join violations v on b.business_id = v.business_id
# group by postal_code
# having count(b.business_id) > 50
# order by violation_restaurant desc limit 5;
# Out:
# 5 rows affected.
# [(u'94133', 10L),
#  (u'94122', 10L),
#  (u'94114', 9L),
#  (u'94109', 9L),
#  (u'94127', 9L)]

# %% [markdown]
# ## Final recommendation
# Give a final recommendation on which 2 zipcodes should the administration focus and choose an appropriate plot to convince them visually.

# %% [markdown]
# ## Bonus: Neighborhood data
#
# Instead of looking at zipcodes we may be interested in using Neighborhood names.
#
# It's beyond the scope of this lab to do a proper introduction to Geocoding and Reverse Geocoding, but we will give some pointers for further exploration.
#
# ### 1. Google Geocoding API
# Have a look at:
# - https://developers.google.com/maps/documentation/geocoding/intro
# - https://maps.googleapis.com/maps/api/geocode/json?address=
# - https://maps.googleapis.com/maps/api/geocode/json?latlng=
#
# Through this API you can retrieve an address or a neighborhood from a lat-lon pair (reverse geocoding), or you can retrieve lat long and other information from an address (geocoding).
#
# 1. Try experimenting with and retrieving a few addresses
# - Note that google imposes limits on the number of free queries
# - How many missing lat-lon pairs do we have?

# %% [markdown]
# ### Bonus 2
# The pycurl library seems to be faster than requests in getting information from the google api.
#
# 1. See if you can extract the neighborhood from an address using the geocode api and a bit of json parsing
# - Note that you would surely hit the daily limit if you pulled each address' neighborhood from the api

# %% [markdown]
# ### Bonus 3
# We can find the neighborhood using the polygons associated to each of them.
# [Here](https://www.google.com/fusiontables/DataSource?docid=1zNwsvTwj-dH0QxuuDrKFsyfNklajd7WwEyaZ2U9M#rows:id=1) you can find these polygons (and we also copied them [locally](../../assets/datasets/sfneighborhoods.csv).
#
# [This article](http://streamhacker.com/2010/03/23/python-point-in-polygon-shapely/) describes how to use the shapely package to check if a point belongs to a polygon.
#
# - See if you can build a function that retrieves the neighborhood for a given address using the polygon data

# %% [markdown]
# ### Further exploration
#
# Postgres is actually GIS enabled, so we could do location based queries directly in the database.
#
# Have a look at http://postgis.refractions.net/ for more information.
