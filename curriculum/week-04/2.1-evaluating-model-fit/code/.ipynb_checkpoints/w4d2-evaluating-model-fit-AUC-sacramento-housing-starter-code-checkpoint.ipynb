# %% [markdown]
# Load required packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, auc
from sklearn.cross_validation import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score

plt.style.use('seaborn-white')
# %matplotlib inline

# %% [markdown]
# Some plotting functions to help you plot the ROC curve

# %%
# generic curve plotting function
def auc_plotting_function(rate1, rate2, rate1_name, rate2_name, curve_name):
    AUC = auc(rate1, rate2)
    # Plot of a ROC curve for class 1 (has_cancer)
    plt.figure(figsize=[11,9])
    plt.plot(rate1, rate2, label=curve_name + ' (area = %0.2f)' % AUC, linewidth=4)
    plt.plot([0, 1], [0, 1], 'k--', linewidth=4)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel(rate1_name, fontsize=18)
    plt.ylabel(rate2_name, fontsize=18)
    plt.title(curve_name + ' for house price > 200,000', fontsize=18)
    plt.legend(loc="lower right")
    plt.show()

# plot receiving operator characteristic curve
def plot_roc(y_true, y_score):
    fpr, tpr, _ = roc_curve(y_true, y_score)
    auc_plotting_function(fpr, tpr, 'False Positive Rate', 'True Positive Rate', 'ROC')

# %% [markdown]
# Load the Sacramento housing data

# %%
sac = pd.read_csv('../assets/datasets/Sacramentorealestatetransactions.csv')

# %%
print sac.head()
sac.dropna(inplace=True)
# Out:
#              street        city    zip state  beds  baths  sq__ft  \
# 0      3526 HIGH ST  SACRAMENTO  95838    CA     2      1     836
# 1       51 OMAHA CT  SACRAMENTO  95823    CA     3      1    1167
# 2    2796 BRANCH ST  SACRAMENTO  95815    CA     2      1     796
# 3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2      1     852
# 4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2      1     797
#
#           type                     sale_date  price   latitude   longitude
# 0  Residential  Wed May 21 00:00:00 EDT 2008  59222  38.631913 -121.434879
# 1  Residential  Wed May 21 00:00:00 EDT 2008  68212  38.478902 -121.431028
# 2  Residential  Wed May 21 00:00:00 EDT 2008  68880  38.618305 -121.443839
# 3  Residential  Wed May 21 00:00:00 EDT 2008  69307  38.616835 -121.439146
# 4  Residential  Wed May 21 00:00:00 EDT 2008  81900  38.519470 -121.435768

# %% [markdown]
# Create a binary variable where 1 indicates a house sold for over 200,000 and 0 indicates a house sold for equal to or less than 200,000.
#
# Subset the data to just contain the number of beds, baths, the sq ft, and the over 200k indicator variable.

# %%
sac['price']= sac['price'].map(lambda x: 0 if x <= 200000 else 1)

# %%
subset_sac = sac[['beds','baths','sq__ft','price']]
subset_sac
# Out:
#      beds  baths  sq__ft  price
# 0       2      1     836      0
# 1       3      1    1167      0
# 2       2      1     796      0
# 3       2      1     852      0
# 4       2      1     797      0
# 5       3      1    1122      0
# 6       3      2    1104      0
# 7       3      1    1177      0
# 8       2      2     941      0
# 9       3      2    1146      0
# 10      3      2     909      0
# 11      3      2    1289      0
# 12      1      1     871      0
# 13      3      1    1020      0
# 14      2      2    1022      0
# 15      2      2    1134      0
# 16      2      1     844      0
# 17      2      1     795      0
# 18      2      1     588      0
# 19      3      2    1356      0
# 20      3      2    1118      0
# 21      4      2    1329      0
# 22      4      2    1240      0
# 23      3      2    1601      0
# 24      3      2     901      0
# 25      3      2    1088      0
# 26      3      1     963      0
# 27      3      2    1119      0
# 28      4      2    1380      0
# 29      3      2    1248      0
# ..    ...    ...     ...    ...
# 955     3      2    1371      1
# 956     3      1    1310      1
# 957     3      2    1262      1
# 958     4      2    1740      1
# 959     3      2    1517      1
# 960     3      2    1450      1
# 961     3      2    1416      1
# 962     3      1     888      1
# 963     3      2    1882      1
# 964     3      2    1302      1
# 965     3      2    1418      1
# 966     3      2       0      1
# 967     4      2    1319      1
# 968     4      2    1770      1
# 969     4      2    1627      1
# 970     0      0       0      1
# 971     3      1    1040      1
# 972     3      1     960      1
# 973     3      2       0      1
# 974     3      1    1456      1
# 975     3      2    1450      1
# 976     3      2    1358      1
# 977     4      2    1329      1
# 978     4      2    1715      1
# 979     3      2    1262      1
# 980     4      3    2280      1
# 981     3      2    1477      1
# 982     3      2    1216      1
# 983     4      2    1685      1
# 984     3      2    1362      1
#
# [985 rows x 4 columns]

# %% [markdown]
# Split your data into training and testing sets. The predictors are the beds, baths, and sq ft. The feature is the over 200k class variable. Make the test size 33% (and optionally stratify by the over 200k class).

# %%
X = sac[['beds','baths','sq__ft']]
y = sac['price']

# %%
X.shape, y.shape
# Out:
# ((985, 3), (985,))

# %%
X_train, X_test, Y_train, Y_test  = train_test_split(X, y, test_size=.33, stratify = y, random_state = 77)

# %% [markdown]
# Fit a logistic regression on the training data.

# %%
logreg = LogisticRegression(random_state=77)
logreg.fit(X_train, Y_train)
Y_pred = logreg.predict(X_test)

# %% [markdown]
# Print out the confusion matrix

# %%
conmat = np.array(confusion_matrix(Y_test, Y_pred, labels=[1,0]))

confusion = pd.DataFrame(conmat, index=['over_200k', 'under_200k'],
                         columns=['predicted_over_200k','predicted_under_200k'])

print(confusion)
# Out:
#             predicted_over_200k  predicted_under_200k
# over_200k                   143                    35
# under_200k                   93                    55

# %% [markdown]
# Calculate the accuracy, precision, and recall. What can these three metrics tell you about your model?

# %%
acc = accuracy_score(Y_test, Y_pred)
acc
# Out:
# 0.6073619631901841

# %%
rec = recall_score(Y_test, Y_pred)
rec
# Out:
# 0.8033707865168539

# %%
prec = precision_score(Y_test, Y_pred)
prec
# Out:
# 0.60593220338983056

# %%
from sklearn.metrics import classification_report

cls_rep = classification_report(Y_test, Y_pred)
print(cls_rep)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.61      0.37      0.46       148
#           1       0.61      0.80      0.69       178
#
# avg / total       0.61      0.61      0.59       326

# %% [markdown]
# Say as a real estate agent, I prioritize minimizing false positives (predicting a house will sell for over 200k when it actually sells for under) because false positives make me lose money.
#
# Change the decision threshold to **lower the false positive rate** and then print out the new confusion matrix. What is the downside to lowering the false positive rate?

# %%
Y_pp = pd.DataFrame(logreg.predict_proba(X_test), columns=['under_200k_pp','over_200k_pp'])

print Y_pp.head()
# Out:
#    under_200k_pp  over_200k_pp
# 0       0.404851      0.595149
# 1       0.569481      0.430519
# 2       0.410048      0.589952
# 3       0.701877      0.298123
# 4       0.470359      0.529641

# %%
Y_pp['over_200k_high_thresh'] = [1 if x >= 0.70 else 0 for x in Y_pp.over_200k_pp.values]

# %%
Y_pp
# Out:
#      under_200k_pp  over_200k_pp  over_200k_high_thresh
# 0         0.404851      0.595149                      0
# 1         0.569481      0.430519                      0
# 2         0.410048      0.589952                      0
# 3         0.701877      0.298123                      0
# 4         0.470359      0.529641                      0
# 5         0.548661      0.451339                      0
# 6         0.397048      0.602952                      0
# 7         0.701877      0.298123                      0
# 8         0.414971      0.585029                      0
# 9         0.414772      0.585228                      0
# 10        0.577229      0.422771                      0
# 11        0.419709      0.580291                      0
# 12        0.701877      0.298123                      0
# 13        0.444163      0.555837                      0
# 14        0.439508      0.560492                      0
# 15        0.361688      0.638312                      0
# 16        0.445521      0.554479                      0
# 17        0.390647      0.609353                      0
# 18        0.265997      0.734003                      1
# 19        0.431125      0.568875                      0
# 20        0.408181      0.591819                      0
# 21        0.512772      0.487228                      0
# 22        0.434015      0.565985                      0
# 23        0.423076      0.576924                      0
# 24        0.517841      0.482159                      0
# 25        0.429331      0.570669                      0
# 26        0.247793      0.752207                      1
# 27        0.514497      0.485503                      0
# 28        0.401822      0.598178                      0
# 29        0.404558      0.595442                      0
# ..             ...           ...                    ...
# 296       0.429530      0.570470                      0
# 297       0.369786      0.630214                      0
# 298       0.252054      0.747946                      1
# 299       0.515004      0.484996                      0
# 300       0.390649      0.609351                      0
# 301       0.358322      0.641678                      0
# 302       0.701877      0.298123                      0
# 303       0.399286      0.600714                      0
# 304       0.418274      0.581726                      0
# 305       0.430527      0.569473                      0
# 306       0.701877      0.298123                      0
# 307       0.439508      0.560492                      0
# 308       0.326691      0.673309                      0
# 309       0.701877      0.298123                      0
# 310       0.429532      0.570468                      0
# 311       0.449335      0.550665                      0
# 312       0.406026      0.593974                      0
# 313       0.390553      0.609447                      0
# 314       0.179578      0.820422                      1
# 315       0.418127      0.581873                      0
# 316       0.422776      0.577224                      0
# 317       0.701877      0.298123                      0
# 318       0.215039      0.784961                      1
# 319       0.540200      0.459800                      0
# 320       0.420402      0.579598                      0
# 321       0.384963      0.615037                      0
# 322       0.530300      0.469700                      0
# 323       0.405143      0.594857                      0
# 324       0.170751      0.829249                      1
# 325       0.397245      0.602755                      0
#
# [326 rows x 3 columns]

# %%
conmat_high = np.array(confusion_matrix(Y_test, Y_pp.over_200k_high_thresh.values, labels=[1,0]))

confusion_high = pd.DataFrame(conmat_high, index=['over_200k', 'under_200k'],
                              columns=['predicted_over_200k','predicted_under_200k'])

print(confusion_high)
# Out:
#             predicted_over_200k  predicted_under_200k
# over_200k                    46                   132
# under_200k                    3                   145

# %% [markdown]
# Plot the ROC curve using the plotting function provided.

# %%
Y_score = logreg.decision_function(X_test)
plot_roc(Y_test, Y_score)

# %% [markdown]
# Bonus: when might precision and recall be more useful than the ROC?

# %% [markdown]
# Precision and recall are more useful when the proportion of the positive class is smaller, since they are sensitive to this.
