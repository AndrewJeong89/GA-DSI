# %% [markdown]
# # Getting started
#
# Once you've chosen your scenario, download the data from [the Iowa website](https://data.iowa.gov/Economy/Iowa-Liquor-Sales/m3tr-qhgy) in csv format. Start by loading the data with pandas. You may need to parse the date columns appropriately.

# %% [markdown]
# #### Scenario 2: Market research for new store locations
#
# A liquor store owner in Iowa is looking to expand to new locations and has hired you to investigate the market data for potential new locations. The business owner is interested in the details of the best model you can fit to the data so that his team can evaluate potential locations for a new storefront.
#
# **Goal for Scenario #2:** Your task is to:
#
# * Build models of total sales based on location, price per bottle, total bottles sold. You may find it useful to build models for each county, zip code, or city.
# * Provide a table of the best performing stores by location type of your choice (city, county, or zip code) and the predictions of your model(s).
# * Based on your models and the table of data, recommend some general locations to the business owner, taking into account model performance. Validate your model's performance and ability to predict future sales using cross-validation.
# * _Bonus_: Recommend targets for volume sold and price per bottle!
#
# ---

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pprint

from IPython.display import Image
from sklearn import linear_model
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

plt.style.use('fivethirtyeight')

# %%
## Load the data into a DataFrame
df = pd.read_csv("/Users/student/downloads/Iowa_Liquor_Sales.csv")

df.head()
# Out:
# //anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#          Date  Store Number         City Zip Code  County Number      County  \
# 0  03/31/2016          5029    DAVENPORT    52806           82.0       Scott
# 1  03/31/2016          5029    DAVENPORT    52806           82.0       Scott
# 2  03/31/2016          4959  CEDAR FALLS    50613            7.0  Black Hawk
# 3  03/31/2016          2190   DES MOINES    50314           77.0        Polk
# 4  03/31/2016          5240  WEST BRANCH    52358            NaN         NaN
#
#     Category       Category Name  Vendor Number  Item Number  \
# 0  1022100.0             TEQUILA            370        87152
# 1  1022100.0             TEQUILA            395        89197
# 2  1071100.0  AMERICAN COCKTAILS            380        63959
# 3  1031200.0      VODKA FLAVORED            205        40597
# 4  1081200.0      CREAM LIQUEURS            305        73055
#
#                         Item Description  Bottle Volume (ml)  \
# 0                           Avion Silver                 375
# 1  Jose Cuervo Especial Reposado Tequila                1000
# 2         Uv Blue Raspberry Lemonade Pet                1750
# 3                New Amsterdam Red Berry                 200
# 4                               Rumchata                 750
#
#   State Bottle Cost State Bottle Retail  Bottles Sold Sale (Dollars)  \
# 0             $9.99              $14.99            12        $179.88
# 1            $12.50              $18.75             2         $37.50
# 2             $5.97               $8.96             6         $53.76
# 3             $2.24               $3.36            48        $161.28
# 4            $12.50              $18.75             6        $112.50
#
#    Volume Sold (Liters)  Volume Sold (Gallons)
# 0                   4.5                   1.19
# 1                   2.0                   0.53
# 2                  10.5                   2.77
# 3                   9.6                   2.54
# 4                   4.5                   1.19

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2709552 entries, 0 to 2709551
# Data columns (total 18 columns):
# Date                     object
# Store Number             int64
# City                     object
# Zip Code                 object
# County Number            float64
# County                   object
# Category                 float64
# Category Name            object
# Vendor Number            int64
# Item Number              int64
# Item Description         object
# Bottle Volume (ml)       int64
# State Bottle Cost        object
# State Bottle Retail      object
# Bottles Sold             int64
# Sale (Dollars)           object
# Volume Sold (Liters)     float64
# Volume Sold (Gallons)    float64
# dtypes: float64(4), int64(5), object(9)
# memory usage: 372.1+ MB

# %% [markdown]
# ### Data Munging

# %%
df['Date'] = df['Date'].apply(pd.to_datetime)

# %%
# Function to convert money columns from string to float

def conv_money(x):
    x = x.split('.')
    return (float(x[0][1:]) + (float(x[1]) / 100))

# %%
# Converting columns with money value to float

df[['State Bottle Cost', 'State Bottle Retail', "Sale (Dollars)"]] = \
df[['State Bottle Cost', 'State Bottle Retail', "Sale (Dollars)"]].applymap(conv_money)

# %%
df['Item Description'] = df['Item Description'].apply(lambda x: x.strip())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2709552 entries, 0 to 2709551
# Data columns (total 18 columns):
# Date                     datetime64[ns]
# Store Number             int64
# City                     object
# Zip Code                 object
# County Number            float64
# County                   object
# Category                 float64
# Category Name            object
# Vendor Number            int64
# Item Number              int64
# Item Description         object
# Bottle Volume (ml)       int64
# State Bottle Cost        float64
# State Bottle Retail      float64
# Bottles Sold             int64
# Sale (Dollars)           float64
# Volume Sold (Liters)     float64
# Volume Sold (Gallons)    float64
# dtypes: datetime64[ns](1), float64(7), int64(5), object(5)
# memory usage: 372.1+ MB

# %% [markdown]
# ## Cleaning Zipcodes

# %%
## Checking to see if all zipcodes have length of 5

df[df['Zip Code'].apply(lambda x: len(str(x)) != 5)]
# Out:
# Empty DataFrame
# Columns: [Date, Store Number, City, Zip Code, County Number, County, Category, Category Name, Vendor Number, Item Number, Item Description, Bottle Volume (ml), State Bottle Cost, State Bottle Retail, Bottles Sold, Sale (Dollars), Volume Sold (Liters), Volume Sold (Gallons)]
# Index: []

# %%
# Since all has 5, change all to int types

df[df['Zip Code'].apply(lambda x: int(x))]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-05561b6a6522> in <module>()
#       1 # Since all has 5, change all to int types
#       2
# ----> 3 df[df['Zip Code'].apply(lambda x: int(x))]
#
# //anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    2218         else:
#    2219             values = self.asobject
# -> 2220             mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2221
#    2222         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/src/inference.pyx in pandas.lib.map_infer (pandas/lib.c:62658)()
#
# <ipython-input-17-05561b6a6522> in <lambda>(x)
#       1 # Since all has 5, change all to int types
#       2
# ----> 3 df[df['Zip Code'].apply(lambda x: int(x))]
#
# ValueError: invalid literal for int() with base 10: '712-2'

# %%
# Even all is length 5, 1 entry was '712-2'
# Googled this, turned out to be area code, change to 51529

df[df['Zip Code'].apply(lambda x: x == '712-2')]
# Out:
#               Date  Store Number    City Zip Code  County Number    County  \
# 28205   2016-03-28          4307  DUNLAP    712-2            NaN       NaN
# 
# 2705063        10628                      Canadian Club Whisky
# 2705100        68036             Bailey's Original Irish Cream
# 2705329        56206           Paramount Peach Flavored Brandy
# 2705388        48105                               Hennessy VS
# 2705423        11788                              Black Velvet
# 2705663        41989                             Uv Cake Vodka
# 2705700        44350                        Calico Jack Cherry
# 2705783        13638              Lord Calvert Canadian Whisky
# 2705801        54447         Paramount Apricot Flavored Brandy
# 2705884         4796                         Cutty Sark Scotch
# 2706179        41077                   Jeremiah Weed Sweet Tea
# 2706883        69947  Rumple Minze Peppermint Schnapps Liqueur
# 2708419        13038                   Canadian Reserve Whisky
# 2708650        24458                     Kessler Blend Whiskey
# 2708818        84636        Phillips Hot 100 Cinnamon Schnapps
# 2709163        11297               Crown Royal Canadian Whisky
# 2709466        19067                                  Jim Beam
#
#          Bottle Volume (ml)  State Bottle Cost  State Bottle Retail  \
# 28205                  1000               5.31                 7.97
# 28297                   375               3.45                 5.18
# 28362                   750              12.50                18.75
# 28366                   750              27.00                40.50
# 28387                   750              23.58                35.37
# 28407                   750               6.00                 9.00
# 28408                   750               5.26                 7.89
# 28409                   750               6.83                10.25
# 28410                  1000              14.99                22.49
# 28411                  1750               7.60                11.40
# 28412                  1000              15.50                23.25
# 28416                  1750              11.02                16.53
# 28419                   750              31.58                47.37
# 28420                   750               7.94                11.91
# 28426                  1000               6.63                 9.95
# 28430                   600              12.44                18.66
# 28432                   750               9.00                13.50
# 28434                   375               7.00                10.50
# 28438                   300               7.35                11.03
# 28439                   500               4.84                 7.26
# 28440                   500               6.63                 9.95
# 28443                   500               4.89                 7.34
# 29166                   500               4.84                 7.26
# 29741                   375               5.00                 7.50
# 29811                   300               7.35                11.03
# 30023                   375               5.00                 7.50
# 32699                   750              10.00                15.00
# 32765                  1750              18.00                27.00
# 32971                  1750              10.45                15.68
# 33729                  1000              10.49                15.74
# ...                     ...                ...                  ...
# 2700699                1750              19.99                29.99
# 2700743                 750              10.00                15.00
# 2700827                1000              18.49                27.74
# 2701040                1000              10.49                15.74
# 2701228                 750              10.00                15.00
# 2701928                1000               7.62                11.43
# 2702483                1000              17.90                26.85
# 2703082                 375               2.05                 3.08
# 2703162                 750               6.30                 9.45
# 2704128                1000               7.00                10.50
# 2704720                 375               5.00                 7.50
# 2704885                1750              18.00                27.00
# 2704904                1000               7.62                11.43
# 2705063                1750              15.75                23.63
# 2705100                 750              13.25                19.88
# 2705329                 750               5.48                 8.22
# 2705388                 375               9.75                14.63
# 2705423                1750              10.45                15.68
# 2705663                 750               6.50                 9.75
# 2705700                 750               6.30                 9.45
# 2705783                1750               9.97                14.96
# 2705801                1000               6.53                 9.80
# 2705884                 750              10.02                15.03
# 2706179                1000              10.50                15.75
# 2706883                1000              15.75                23.63
# 2708419                1750               9.00                13.50
# 2708650                1750              11.02                16.53
# 2708818                 750               7.45                11.18
# 2709163                1000              18.50                27.75
# 2709466                1000              12.08                18.12
#
#          Bottles Sold  Sale (Dollars)  Volume Sold (Liters)  \
# 28205               4           31.88                  4.00
# 28297               4           20.72                  1.50
# 28362               1           18.75                  0.75
# 28366               2           81.00                  1.50
# 28387               1           35.37                  0.75
# 28407               4           36.00                  3.00
# 28408               4           31.56                  3.00
# 28409               1           10.25                  0.75
# 28410              12          269.88                 12.00
# 28411               6           68.40                 10.50
# 28412               4           93.00                  4.00
# 28416              12          198.36                 21.00
# 28419               1           47.37                  0.75
# 28420               4           47.64                  3.00
# 28426              12          119.40                 12.00
# 28430               1           18.66                  0.60
# 28432               2           27.00                  1.50
# 28434               2           21.00                  0.75
# 28438               1           11.03                  0.30
# 28439               1            7.26                  0.50
# 28440               1            9.95                  0.50
# 28443               1            7.34                  0.50
# 29166               1            7.26                  0.50
# 29741               1            7.50                  0.38
# 29811               1           11.03                  0.30
# 30023               1            7.50                  0.38
# 32699               1           15.00                  0.75
# 32765               6          162.00                 10.50
# 32971               6           94.08                 10.50
# 33729               3           47.22                  3.00
# ...               ...             ...                   ...
# 2700699             6          179.94                 10.50
# 2700743             1           15.00                  0.75
# 2700827             2           55.48                  2.00
# 2701040            12          188.88                 12.00
# 2701228             6           90.00                  4.50
# 2701928            12          137.16                 12.00
# 2702483            12          322.20                 12.00
# 2703082            24           73.92                  9.00
# 2703162             2           18.90                  1.50
# 2704128             1           10.50                  1.00
# 2704720             4           30.00                  1.50
# 2704885             6          162.00                 10.50
# 2704904             3           34.29                  3.00
# 2705063             6          141.78                 10.50
# 2705100             2           39.76                  1.50
# 2705329             1            8.22                  0.75
# 2705388             1           14.63                  0.38
# 2705423             6           94.08                 10.50
# 2705663             1            9.75                  0.75
# 2705700            12          113.40                  9.00
# 2705783             2           29.92                  3.50
# 2705801             4           39.20                  4.00
# 2705884             1           15.03                  0.75
# 2706179             1           15.75                  1.00
# 2706883             3           70.89                  3.00
# 2708419             6           81.00                 10.50
# 2708650             6           99.18                 10.50
# 2708818             1           11.18                  0.75
# 2709163            12          333.00                 12.00
# 2709466            12          217.44                 12.00
#
#          Volume Sold (Gallons)
# 28205                     1.06
# 28297                     0.40
# 28362                     0.20
# 28366                     0.40
# 28387                     0.20
# 28407                     0.79
# 28408                     0.79
# 28409                     0.20
# 28410                     3.17
# 28411                     2.77
# 28412                     1.06
# 28416                     5.55
# 28419                     0.20
# 28420                     0.79
# 28426                     3.17
# 28430                     0.16
# 28432                     0.40
# 28434                     0.20
# 28438                     0.08
# 28439                     0.13
# 28440                     0.13
# 28443                     0.13
# 29166                     0.13
# 29741                     0.10
# 29811                     0.08
# 30023                     0.10
# 32699                     0.20
# 32765                     2.77
# 32971                     2.77
# 33729                     0.79
# ...                        ...
# 2700699                   2.77
# 2700743                   0.20
# 2700827                   0.53
# 2701040                   3.17
# 2701228                   1.19
# 2701928                   3.17
# 2702483                   3.17
# 2703082                   2.38
# 2703162                   0.40
# 2704128                   0.26
# 2704720                   0.40
# 2704885                   2.77
# 2704904                   0.79
# 2705063                   2.77
# 2705100                   0.40
# 2705329                   0.20
# 2705388                   0.10
# 2705423                   2.77
# 2705663                   0.20
# 2705700                   2.38
# 2705783                   0.92
# 2705801                   1.06
# 2705884                   0.20
# 2706179                   0.26
# 2706883                   0.79
# 2708419                   2.77
# 2708650                   2.77
# 2708818                   0.20
# 2709163                   3.17
# 2709466                   3.17
#
# [2000 rows x 18 columns]

# %%
# Changed erroneous zipcode

df.loc[df['Zip Code'] == '712-2', 'Zip Code'] = '51529'

# %%
# Changed zipcodes to int type

df['Zip Code'] = df['Zip Code'].apply(lambda x: int(x))

# %%
Image(filename='/Users/student/downloads/wrong_zip_des_moines.png')

# %%
# Correct Zip Code for Des Moines, Burlington

df.loc[df['Zip Code'] == 56201, 'Zip Code'] = 52601

# %% [markdown]
# ## Cleaning City Values

# %%
list(df['City'].unique())
# Out:
# ['DAVENPORT',
#  'CEDAR FALLS',
#  'DES MOINES',
#  'WEST BRANCH',
#  'WATERLOO',
#  'ANKENY',
#  'URBANDALE',
#  'MASON CITY',
#  'CORALVILLE',
#  'JEFFERSON',
#  'ELDRIDGE',
#  'NORTHWOOD',
#  'GRINNELL',
#  'JOHNSTON',
#  'CLEAR LAKE',
#  'DENISON',
#  'LAKE MILLS',
#  'MADRID',
#  'DEWITT',
#  'MOUNT VERNON',
#  'OSCEOLA',
#  'NORTH LIBERTY',
#  'WEST DES MOINES',
#  'TIPTON',
#  'CLINTON',
#  'ROCKWELL',
#  'LEON',
#  'Des Moines',
#  'PERRY',
#  'LE CLAIRE',
#  'NEW VIRGINIA',
#  'MONROE',
#  'LECLAIRE',
#  'WILLIAMSBURG',
#  'PRINCETON',
#  'LAMONI',
#  'CEDAR RAPIDS',
#  'TIFFIN',
#  'ST CHARLES',
#  'NORWALK',
#  'COLFAX',
#  'Northwood',
#  'CARROLL',
#  'MANNING',
#  'COON RAPIDS',
#  'MANLY',
#  'CAMANCHE',
#  'GRAND JUNCTION',
#  'AMES',
#  'IOWA CITY',
#  'STORM LAKE',
#  'BETTENDORF',
#  'NEVADA',
#  'SIOUX CITY',
#  'WINDSOR HEIGHTS',
#  'CENTERVILLE',
#  'OTTUMWA',
#  'BOONE',
#  'FORT ATKINSON',
#  'PLEASANT HILL',
#  'SERGEANT BLUFF',
#  'MORAVIA',
#  'FOREST CITY',
#  'OELWEIN',
#  'OTTUWMA',
#  'MARENGO',
#  'DECORAH',
#  'PELLA',
#  'MANSON',
#  'ALTOONA',
#  'ALBIA',
#  'MAPLETON',
#  'OSKALOOSA',
#  'GOWRIE',
#  'POSTVILLE',
#  'SCHLESWIG',
#  'ONAWA',
#  'BUFFALO CENTER',
#  'SUMNER',
#  'CARLISLE',
#  'ST LUCAS',
#  'KNOXVILLE',
#  'GARNER',
#  'WAUKON',
#  'FAIRFAX',
#  'ALGONA',
#  'LANSING',
#  'WESLEY',
#  'PLEASANTVILLE',
#  'BANCROFT',
#  'WEST UNION',
#  'SAC CITY',
#  'KINGSLEY',
#  'BUSSEY',
#  'DAYTON',
#  'SIOUX RAPIDS',
#  'HOLSTEIN',
#  'LAKE VIEW',
#  'CHARITON',
#  'LAKE CITY',
#  'DENVER',
#  'EDDYVILLE',
#  'WALL LAKE',
#  'HUXLEY',
#  'IDA GROVE',
#  'SLOAN',
#  'SEYMOUR',
#  'WALFORD',
#  'ROCKWELL CITY',
#  'SLATER',
#  'BRITT',
#  'MELCHER-DALLAS',
#  'OGDEN',
#  'TRIPOLI',
#  'SWEA CITY',
#  'BROOKLYN',
#  'FAYETTE',
#  'BLOOMFIELD',
#  'CENTRAL CITY',
#  'VINTON',
#  'SPENCER',
#  'OSAGE',
#  'DUBUQUE',
#  'COUNCIL BLUFFS',
#  'CLARINDA',
#  'CHARLES CITY',
#  'WEBSTER CITY',
#  'WAVERLY',
#  'AVOCA',
#  'ORANGE CITY',
#  'MARSHALLTOWN',
#  'CASCADE',
#  'BELMOND',
#  'CRESTON',
#  'SHELLSBURG',
#  'HARTLEY',
#  'WINTERSET',
#  'LE MARS',
#  'FORT DODGE',
#  'OAKLAND',
#  'TOLEDO',
#  'SHELDON',
#  'RED OAK',
#  'BEDFORD',
#  'HUMBOLDT',
#  'CRESCO',
#  'BELLE PLAINE',
#  'SPIRIT LAKE',
#  'STATE CENTER',
#  'WEST BEND',
#  'GLADBROOK',
#  'REMSEN',
#  'ROCK RAPIDS',
#  'MONTICELLO',
#  'EAGLE GROVE',
#  'DYERSVILLE',
#  'CHEROKEE',
#  'CLARKSVILLE',
#  'LA PORTE CITY',
#  'CLIVE',
#  'EVERLY',
#  'ESTHERVILLE',
#  'FLOYD',
#  'EMMETSBURG',
#  'GREENFIELD',
#  'GRIMES',
#  'LE GRAND',
#  'POLK CITY',
#  'STORY CITY',
#  'ARNOLDS PARK',
#  'DUMONT',
#  'GILMORE CITY',
#  'GLENWOOD',
#  'STRATFORD',
#  'PACIFIC JUNCTION',
#  'MARCUS',
#  'PRIMGHAR',
#  'SHENANDOAH',
#  'SIOUX CENTER',
#  'MOUNT AYR',
#  'CORNING',
#  'ELMA',
#  'TRAER',
#  'GRAETTINGER',
#  'CLARION',
#  'MILFORD',
#  'BEVINGTON',
#  'LAKE PARK',
#  'MELBOURNE',
#  'FONTANELLE',
#  'GRANGER',
#  'NASHUA',
#  'INWOOD',
#  'IRETON',
#  'HAWARDEN',
#  'ALDEN',
#  'PEOSTA',
#  'OKOBOJI',
#  'ST ANSGAR',
#  'CENTER POINT',
#  'SANBORN',
#  'SUTHERLAND',
#  'REINBECK',
#  'POCAHONTAS',
#  'LEMARS',
#  'NEW HAMPTON',
#  'ROCK VALLEY',
#  'LARCHWOOD',
#  'GREENE',
#  'GEORGE',
#  'LAWLER',
#  'NORA SPRINGS',
#  'DOWS',
#  'JEWELL',
#  'ALLISON',
#  'HUDSON',
#  'SIBLEY',
#  'PALO',
#  'ELLSWORTH',
#  'LAURENS',
#  'NEOLA',
#  'GOLDFIELD',
#  'FAIRFIELD',
#  'DURANT',
#  'MARION',
#  'WEST LIBERTY',
#  'BURLINGTON',
#  'MUSCATINE',
#  'BONDURANT',
#  'INDIANOLA',
#  'INDEPENDENCE',
#  'WAUKEE',
#  'ANITA',
#  'PARKERSBURG',
#  'NEWTON',
#  'CASEY',
#  'FORT MADISON',
#  'KEOKUK',
#  'SOLON',
#  'DUNLAP',
#  'MAQUOKETA',
#  'STANWOOD',
#  'MONONA',
#  'RAYMOND',
#  'WEST POINT',
#  'MONTROSE',
#  'RIVERSIDE',
#  'ADEL',
#  'MOUNT PLEASANT',
#  'WASHINGTON',
#  'ATLANTIC',
#  'WILTON',
#  'BALDWIN',
#  'MEDIAPOLIS',
#  'HARLAN',
#  'COLUMBUS JUNCTION',
#  'IOWA FALLS',
#  'MT PLEASANT',
#  'KELLOGG',
#  'ELDORA',
#  'MANCHESTER',
#  'GUTHRIE CENTER',
#  'GRUNDY CENTER',
#  'ANAMOSA',
#  'BLUE GRASS',
#  'LOGAN',
#  'BELLEVUE',
#  'SIGOURNEY',
#  'LATIMER',
#  'WOODBINE',
#  'CONRAD',
#  'WEST BURLINGTON',
#  'KEOSAUQUA',
#  'HAMPTON',
#  'JESUP',
#  'STUART',
#  'WELLMAN',
#  'HIAWATHA',
#  'MISSOURI VALLEY',
#  'SPRINGVILLE',
#  'EVANSDALE',
#  'MONTEZUMA',
#  'DE SOTO',
#  'CARTER LAKE',
#  'HOLY CROSS',
#  'ELKADER',
#  'MECHANICSVILLE',
#  'PANORA',
#  'STRAWBERRY POINT',
#  'ADAIR',
#  'EDGEWOOD',
#  'Cumming',
#  'GUTTENBERG',
#  'BUFFALO',
#  'EXIRA',
#  'MINDEN',
#  'AUDUBON',
#  'WINTHROP',
#  'WAPELLO',
#  'ACKLEY',
#  'ZWINGLE',
#  'SWISHER',
#  'GLIDDEN',
#  'GRAND MOUND',
#  'WOODWARD',
#  'SCRANTON',
#  'CORYDON',
#  'ANTHON',
#  'FAIRBANK',
#  'VICTOR',
#  'FONDA',
#  "ARNOLD'S PARK",
#  'LENOX',
#  'GILBERTVILLE',
#  'PAULLINA',
#  'MALVERN',
#  'TREYNOR',
#  'URBANA',
#  'RUTHVEN',
#  'Urbandale',
#  'ROLFE',
#  'DAKOTA CITY',
#  'DYSART',
#  'Inwood',
#  'BAXTER',
#  'HAMBURG',
#  'VILLISCA',
#  'RICEVILLE',
#  'WALKER',
#  'ARMSTRONG',
#  'AKRON',
#  'HOSPERS',
#  'AFTON',
#  'FREDERICKSBURG',
#  'LISBON',
#  'LOST NATION',
#  'MAXWELL',
#  'FARMINGTON',
#  'WELLSBURG',
#  'COLO',
#  'ELDON',
#  'WALNUT',
#  'ARLINGTON',
#  'HUBBARD',
#  'KEOTA',
#  'MARTENSDALE',
#  'SHEFFIELD',
#  'PRAIRIE CITY',
#  'HAZLETON',
#  'EARLY',
#  'HUMESTON',
#  'LOHRVILLE',
#  'CORWITH',
#  'FARLEY',
#  'EARLHAM',
#  'TABOR',
#  'VAN METER',
#  'ROBINS',
#  'MERRILL',
#  'NEW SHARON',
#  'DELHI',
#  'ELY',
#  'RUNNELLS',
#  'HARPERS FERRY',
#  'AURELIA',
#  'OTHO',
#  'Carroll',
#  'DELMAR',
#  'CAMBRIDGE',
#  'WASHBURN',
#  'DANVILLE',
#  'Davenport',
#  'CRESCENT',
#  'WHEATLAND',
#  'Dubuque',
#  'ALTA',
#  'DELAWARE',
#  'DONNELLSON',
#  'SULLY',
#  'LOVILIA',
#  'GUTTENBURG',
#  'SCHALLER',
#  'KELLOG',
#  'NORTH ENGLISH',
#  'GRISWOLD',
#  'MT VERNON']

# %%
# There are some 'City' entries which are in lower case while the majority is in Upper Case. 
# To prevent double counting, all "City" entries are changed to upper case

df['City'] = df['City'].apply(lambda x: x.upper())

# %% [markdown]
# ## Cleaning NaN County entries

# %%
# Create a new dataframe for rows with NaNs in any cells

df_nan = df[pd.isnull(df).any(axis = 1)]

# %%
df_nan.head()
# Out:
#           Date  Store Number         City  Zip Code  County Number County  \
# 4   2016-03-31          5240  WEST BRANCH     52358            NaN    NaN
# 114 2016-03-31          5240  WEST BRANCH     52358            NaN    NaN
# 209 2016-03-31          5240  WEST BRANCH     52358            NaN    NaN
# 271 2016-03-31          5240  WEST BRANCH     52358            NaN    NaN
# 288 2016-03-31          5240  WEST BRANCH     52358            NaN    NaN
#
#       Category       Category Name  Vendor Number  Item Number  \
# 4    1081200.0      CREAM LIQUEURS            305        73055
# 114  1011300.0  TENNESSEE WHISKIES             85        86670
# 209  1081400.0          TRIPLE SEC             65        82606
# 271  1081200.0      CREAM LIQUEURS            260        68034
# 288  1081600.0     WHISKEY LIQUEUR            421        64864
#
#                   Item Description  Bottle Volume (ml)  State Bottle Cost  \
# 4                         Rumchata                 750              12.50
# 114  Jack Daniel's Tennessee Honey                 750              15.07
# 209     Dekuyper Sour Apple Pucker                 750               6.30
# 271  Bailey's Original Irish Cream                 375               7.00
# 288       Fireball Cinnamon Whisky                 375               5.33
#
#      State Bottle Retail  Bottles Sold  Sale (Dollars)  Volume Sold (Liters)  \
# 4                  18.75             6          112.50                  4.50
# 114                22.61             3           67.83                  2.25
# 209                 9.45             3           28.35                  2.25
# 271                10.50             3           31.50                  1.12
# 288                 8.00             6           48.00                  2.25
#
#      Volume Sold (Gallons)
# 4                     1.19
# 114                   0.59
# 209                   0.59
# 271                   0.30
# 288                   0.59

# %%
# Printing columns that contain "NaN" and count the number of NaN entries per column

tbc_list = []

for col in df.columns:
    x = sum(pd.isnull(df[col]))
    if x != 0:
        tbc_list.append(col)
        print col, x
# Out:
# County Number 10913
# County 10913
# Category 779
# Category Name 6109

# %%
# Some counties and county numbers are not filled.
# Since "City" column does not contain NaN and Cities are a subset of counties,
# we try to see if there are similar cities with non-empty county values which we can then copy to the NaN county cells


# Create a set of Cities with NaN for county or county Number

city_nan_list = list(df_nan['City'].unique())

city_nan_list
# Out:
# ['WEST BRANCH',
#  'DES MOINES',
#  'ROCKWELL',
#  'CLINTON',
#  'NORWALK',
#  'MASON CITY',
#  'DENISON',
#  'CEDAR RAPIDS',
#  'DAVENPORT',
#  'SIOUX CITY',
#  'WESLEY',
#  'CORALVILLE',
#  'SEYMOUR',
#  'ALTOONA',
#  'NORTH LIBERTY',
#  'DUBUQUE',
#  'CLARINDA',
#  'BELMOND',
#  'CRESCO',
#  'WAVERLY',
#  'FORT DODGE',
#  'LARCHWOOD',
#  'DUNLAP',
#  'HARLAN',
#  'SIGOURNEY',
#  'HAMPTON',
#  'ANAMOSA',
#  'ACKLEY',
#  'WATERLOO',
#  'ANTHON',
#  'ATLANTIC',
#  'EVANSDALE',
#  'CEDAR FALLS',
#  'IOWA CITY',
#  'CHARITON',
#  'AMES',
#  'TABOR',
#  'AUDUBON',
#  'PLEASANTVILLE',
#  'RUNNELLS',
#  'WEST LIBERTY',
#  'OSCEOLA',
#  'WAUKEE',
#  'MUSCATINE',
#  'BURLINGTON',
#  'NEWTON',
#  'COUNCIL BLUFFS',
#  'WEST DES MOINES',
#  'INDIANOLA',
#  'MARION',
#  'INDEPENDENCE',
#  'MOUNT PLEASANT',
#  'WEST POINT',
#  'RIVERSIDE',
#  'MOUNT VERNON',
#  'KEOKUK',
#  'BETTENDORF',
#  'FAIRFIELD',
#  'IOWA FALLS',
#  'CARTER LAKE',
#  'LISBON',
#  'HIAWATHA',
#  'MAQUOKETA',
#  'COLUMBUS JUNCTION',
#  'MISSOURI VALLEY',
#  'WASHINGTON',
#  'WELLMAN',
#  'LATIMER',
#  'ANITA',
#  'BONDURANT',
#  'ELDORA',
#  'FORT MADISON',
#  'URBANDALE',
#  'JOHNSTON',
#  'ANKENY',
#  'ELDRIDGE',
#  'LAKE MILLS',
#  'CLEAR LAKE',
#  'TIPTON',
#  'LE CLAIRE',
#  'PERRY',
#  'CARROLL',
#  'LAMONI',
#  'MANNING',
#  'SAC CITY',
#  'OTTUMWA',
#  'STORM LAKE',
#  'OTTUWMA',
#  'WINDSOR HEIGHTS',
#  'BLOOMFIELD',
#  'KNOXVILLE',
#  'WEST UNION',
#  'PELLA',
#  'FOREST CITY',
#  'IDA GROVE',
#  'OELWEIN',
#  'WAUKON',
#  'OSKALOOSA',
#  'NEVADA',
#  'MARENGO',
#  'BOONE',
#  'SUMNER',
#  'CENTERVILLE',
#  'PLEASANT HILL',
#  'ALBIA',
#  'MANSON',
#  'DENVER',
#  'LANSING',
#  'TRIPOLI',
#  'DECORAH',
#  'HOLSTEIN',
#  'EMMETSBURG',
#  'WINTERSET',
#  'MARSHALLTOWN',
#  'LEMARS',
#  'SPIRIT LAKE',
#  'VINTON',
#  'ESTHERVILLE',
#  'SHELDON',
#  'GLADBROOK',
#  'CRESTON',
#  'CLIVE',
#  'CHARLES CITY',
#  'LE MARS',
#  'MONTICELLO',
#  'SIOUX CENTER',
#  'STATE CENTER',
#  'SIBLEY',
#  'ROCK RAPIDS',
#  'AVOCA',
#  'ADEL',
#  'LA PORTE CITY',
#  'MILFORD',
#  'WEBSTER CITY',
#  'CHEROKEE',
#  'SPENCER',
#  'GRIMES',
#  'ALDEN',
#  'POCAHONTAS',
#  'STORY CITY',
#  'PACIFIC JUNCTION',
#  'TRAER',
#  'HAWARDEN',
#  'TOLEDO',
#  'SHENANDOAH',
#  'LE GRAND',
#  'INWOOD',
#  'ARNOLDS PARK',
#  'WEST BURLINGTON',
#  'MT PLEASANT',
#  'WILTON',
#  'MANCHESTER',
#  'NEW SHARON',
#  'MONONA',
#  'CASEY',
#  'ELDON',
#  'BLUE GRASS',
#  'STRAWBERRY POINT',
#  'MONTEZUMA',
#  'KEOSAUQUA',
#  'WALNUT',
#  'GUTTENBERG',
#  'SOLON',
#  'GRINNELL',
#  'GLIDDEN',
#  'COLFAX',
#  'DEWITT',
#  'NORTHWOOD',
#  'JEFFERSON',
#  'LECLAIRE',
#  'CORYDON',
#  'GOWRIE',
#  'ONAWA',
#  'SERGEANT BLUFF',
#  'SCHLESWIG',
#  'ALGONA',
#  'BANCROFT',
#  'SLOAN',
#  'CARLISLE',
#  'LAKE VIEW',
#  'OSAGE',
#  'SWISHER',
#  'RED OAK',
#  'PAULLINA',
#  'DE SOTO',
#  'PRIMGHAR',
#  'EARLHAM',
#  'SHELLSBURG',
#  'DYERSVILLE',
#  'EAGLE GROVE',
#  'KELLOGG',
#  'WILLIAMSBURG',
#  'COON RAPIDS',
#  'MELCHER-DALLAS',
#  'FAIRFAX',
#  'GARNER',
#  'FAIRBANK',
#  'BEDFORD',
#  'BELLE PLAINE',
#  'ROCK VALLEY',
#  'HUMBOLDT',
#  'ELLSWORTH',
#  'GREENFIELD',
#  'JEWELL',
#  'CORNING',
#  'HOLY CROSS',
#  'JESUP',
#  'PANORA',
#  'WOODBINE',
#  'GUTHRIE CENTER',
#  'WHEATLAND',
#  'TIFFIN',
#  'CAMBRIDGE',
#  'HARTLEY',
#  'NORA SPRINGS',
#  'GRANGER',
#  'NEW HAMPTON',
#  'POLK CITY',
#  'ORANGE CITY',
#  'SUTHERLAND',
#  'GRUNDY CENTER',
#  'RAYMOND',
#  'ZWINGLE',
#  'HUBBARD',
#  'DURANT',
#  'STUART',
#  'ADAIR',
#  'ELKADER',
#  'MOUNT AYR',
#  'CASCADE',
#  'LAWLER',
#  'BELLEVUE']

# %%
# Creating a dictionary with "City" as key and collecting all possible corresponding "County" and "County Name"
# as values of the dictionary

nan_cty_dict = {}

for j in city_nan_list:
    c_set = {x for x in df[df['City']==j]['County'] if x > 0} # x > 0 to skip NaN values
    num_set = {x for x in df[df['City']==j]['County Number'] if x > 0}
    nan_cty_dict[j] = [list(c_set), list(num_set)]

nan_cty_dict
# Out:
# {'ACKLEY': [['Webster', 'Hardin'], [42.0, 94.0]],
#  'ADAIR': [['Adair'], [1.0]],
#  'ADEL': [['Dallas'], [25.0]],
#  'ALBIA': [['Monroe'], [68.0]],
#  'ALDEN': [['Hardin'], [42.0]],
#  'ALGONA': [['Kossuth'], [55.0]],
#  'ALTOONA': [['Polk'], [77.0]],
#  'AMES': [['Story'], [85.0]],
#  'ANAMOSA': [['Jones'], [53.0]],
#  'ANITA': [['Cass'], [15.0]],
#  'ANKENY': [['Polk'], [77.0]],
#  'ANTHON': [['Woodbury'], [97.0]],
#  'ARNOLDS PARK': [['Dickinson'], [30.0]],
#  'ATLANTIC': [['Cass'], [15.0]],
#  'AUDUBON': [['Audubon'], [5.0]],
#  'AVOCA': [['Pottawattamie'], [78.0]],
#  'BANCROFT': [['Kossuth'], [55.0]],
#  'BEDFORD': [['Taylor'], [87.0]],
#  'BELLE PLAINE': [['Benton'], [6.0]],
#  'BELLEVUE': [['Jackson'], [49.0]],
#  'BELMOND': [['Wright'], [99.0]],
#  'BETTENDORF': [['Iowa', 'Scott'], [48.0, 82.0]],
#  'BLOOMFIELD': [['Davis'], [26.0]],
#  'BLUE GRASS': [['Scott'], [82.0]],
#  'BONDURANT': [['Polk'], [77.0]],
#  'BOONE': [['Boone'], [8.0]],
#  'BURLINGTON': [['Des Moines'], [29.0]],
#  'CAMBRIDGE': [['Polk'], [77.0]],
#  'CARLISLE': [['Warren'], [91.0]],
#  'CARROLL': [['Carroll'], [14.0]],
#  'CARTER LAKE': [['Pottawattamie'], [78.0]],
#  'CASCADE': [['Dubuque'], [31.0]],
#  'CASEY': [['Guthrie'], [39.0]],
#  'CEDAR FALLS': [['Black Hawk'], [7.0]],
#  'CEDAR RAPIDS': [['Linn'], [57.0]],
#  'CENTERVILLE': [['Appanoose'], [4.0]],
#  'CHARITON': [['Lucas'], [59.0]],
#  'CHARLES CITY': [['Floyd'], [34.0]],
#  'CHEROKEE': [['Cherokee'], [18.0]],
#  'CLARINDA': [['Page'], [73.0]],
#  'CLEAR LAKE': [['Cerro Gordo'], [17.0]],
#  'CLINTON': [['Clinton'], [23.0]],
#  'CLIVE': [['Polk', 'Dallas'], [25.0, 77.0]],
#  'COLFAX': [['Jasper'], [50.0]],
#  'COLUMBUS JUNCTION': [['Louisa'], [58.0]],
#  'COON RAPIDS': [['Carroll'], [14.0]],
#  'CORALVILLE': [['Johnson'], [52.0]],
#  'CORNING': [['Clayton', 'Adams'], [2.0, 22.0]],
#  'CORYDON': [['Wayne'], [93.0]],
#  'COUNCIL BLUFFS': [['Pottawattamie'], [78.0]],
#  'CRESCO': [['Howard'], [45.0]],
#  'CRESTON': [['Union'], [88.0]],
#  'DAVENPORT': [['Scott'], [82.0]],
#  'DE SOTO': [['Dallas'], [25.0]],
#  'DECORAH': [['Winneshiek'], [96.0]],
#  'DENISON': [['Crawford'], [24.0]],
#  'DENVER': [['Bremer'], [9.0]],
#  'DES MOINES': [['Polk'], [77.0]],
#  'DEWITT': [['Clinton'], [23.0]],
#  'DUBUQUE': [['Dubuque'], [31.0]],
#  'DUNLAP': [['Harrison'], [43.0]],
#  'DURANT': [['Cedar'], [16.0]],
#  'DYERSVILLE': [['Dubuque'], [31.0]],
#  'EAGLE GROVE': [['Wright'], [99.0]],
#  'EARLHAM': [['Madison'], [61.0]],
#  'ELDON': [['Wapello'], [90.0]],
#  'ELDORA': [['Hardin'], [42.0]],
#  'ELDRIDGE': [['Scott'], [82.0]],
#  'ELKADER': [['Clayton'], [22.0]],
#  'ELLSWORTH': [['Hamilton'], [40.0]],
#  'EMMETSBURG': [['Palo Alto'], [74.0]],
#  'ESTHERVILLE': [['Emmet'], [32.0]],
#  'EVANSDALE': [['Black Hawk'], [7.0]],
#  'FAIRBANK': [['Buchanan'], [10.0]],
#  'FAIRFAX': [['Linn'], [57.0]],
#  'FAIRFIELD': [['Jefferson'], [51.0]],
#  'FOREST CITY': [['Winnebago'], [95.0]],
#  'FORT DODGE': [['Webster', 'Hardin'], [42.0, 94.0]],
#  'FORT MADISON': [['Lee'], [56.0]],
#  'GARNER': [['Hancock'], [41.0]],
#  'GLADBROOK': [['Iowa'], [48.0]],
#  'GLIDDEN': [['Carroll'], [14.0]],
#  'GOWRIE': [['Webster'], [94.0]],
#  'GRANGER': [['Dallas'], [25.0]],
#  'GREENFIELD': [['Adair'], [1.0]],
#  'GRIMES': [['Polk'], [77.0]],
#  'GRINNELL': [['Poweshiek'], [79.0]],
#  'GRUNDY CENTER': [['Grundy'], [38.0]],
#  'GUTHRIE CENTER': [['Guthrie'], [39.0]],
#  'GUTTENBERG': [['Clayton'], [22.0]],
#  'HAMPTON': [['Franklin'], [35.0]],
#  'HARLAN': [['Shelby'], [83.0]],
#  'HARTLEY': [["O'Brien"], [71.0]],
#  'HAWARDEN': [['Sioux'], [84.0]],
#  'HIAWATHA': [['Linn'], [57.0]],
#  'HOLSTEIN': [['Ida'], [47.0]],
#  'HOLY CROSS': [['Dubuque'], [31.0]],
#  'HUBBARD': [['Hardin'], [42.0]],
#  'HUMBOLDT': [['Humboldt'], [46.0]],
#  'IDA GROVE': [['Ida'], [47.0]],
#  'INDEPENDENCE': [['Buchanan'], [10.0]],
#  'INDIANOLA': [['Warren'], [91.0]],
#  'INWOOD': [['Lyon'], [60.0]],
#  'IOWA CITY': [['Johnson'], [52.0]],
#  'IOWA FALLS': [['Hardin'], [42.0]],
#  'JEFFERSON': [['Greene'], [37.0]],
#  'JESUP': [['Buchanan'], [10.0]],
#  'JEWELL': [['Hamilton'], [40.0]],
#  'JOHNSTON': [['Polk'], [77.0]],
#  'KELLOGG': [['Jasper'], [50.0]],
#  'KEOKUK': [['Lee'], [56.0]],
#  'KEOSAUQUA': [['Van Buren'], [89.0]],
#  'KNOXVILLE': [['Marion'], [63.0]],
#  'LA PORTE CITY': [['Black Hawk'], [7.0]],
#  'LAKE MILLS': [['Winnebago'], [95.0]],
#  'LAKE VIEW': [['Sac'], [81.0]],
#  'LAMONI': [['Decatur'], [27.0]],
#  'LANSING': [['Allamakee'], [3.0]],
#  'LARCHWOOD': [['Lyon'], [60.0]],
#  'LATIMER': [['Franklin'], [35.0]],
#  'LAWLER': [['Chickasaw'], [19.0]],
#  'LE CLAIRE': [['Scott'], [82.0]],
#  'LE GRAND': [['Marshall'], [64.0]],
#  'LE MARS': [['Plymouth'], [75.0]],
#  'LECLAIRE': [['Scott'], [82.0]],
#  'LEMARS': [['Plymouth'], [75.0]],
#  'LISBON': [['Linn'], [57.0]],
#  'MANCHESTER': [['Delaware'], [28.0]],
#  'MANNING': [['Carroll'], [14.0]],
#  'MANSON': [['Calhoun'], [13.0]],
#  'MAQUOKETA': [['Jackson'], [49.0]],
#  'MARENGO': [['Iowa'], [48.0]],
#  'MARION': [['Linn'], [57.0]],
#  'MARSHALLTOWN': [['Marshall'], [64.0]],
#  'MASON CITY': [['Cerro Gordo'], [17.0]],
#  'MELCHER-DALLAS': [['Marion'], [63.0]],
#  'MILFORD': [['Dickinson'], [30.0]],
#  'MISSOURI VALLEY': [['Harrison'], [43.0]],
#  'MONONA': [['Clayton'], [22.0]],
#  'MONTEZUMA': [['Poweshiek'], [79.0]],
#  'MONTICELLO': [['Jones'], [53.0]],
#  'MOUNT AYR': [['Ringgold'], [80.0]],
#  'MOUNT PLEASANT': [['Henry'], [44.0]],
#  'MOUNT VERNON': [['Linn'], [57.0]],
#  'MT PLEASANT': [['Henry'], [44.0]],
#  'MUSCATINE': [['Muscatine'], [70.0]],
#  'NEVADA': [['Story'], [85.0]],
#  'NEW HAMPTON': [['Chickasaw'], [19.0]],
#  'NEW SHARON': [['Mahaska'], [62.0]],
#  'NEWTON': [['Webster', 'Jasper'], [50.0, 94.0]],
#  'NORA SPRINGS': [['Floyd'], [34.0]],
#  'NORTH LIBERTY': [['Iowa', 'Johnson'], [48.0, 52.0]],
#  'NORTHWOOD': [['Worth'], [98.0]],
#  'NORWALK': [['Warren'], [91.0]],
#  'OELWEIN': [['Fayette'], [33.0]],
#  'ONAWA': [['Monona'], [67.0]],
#  'ORANGE CITY': [['Sioux'], [84.0]],
#  'OSAGE': [['Mitchell'], [66.0]],
#  'OSCEOLA': [['Clarke'], [20.0]],
#  'OSKALOOSA': [['Buchanan', 'Mahaska'], [10.0, 62.0]],
#  'OTTUMWA': [['Wapello'], [90.0]],
#  'OTTUWMA': [['Wapello'], [90.0]],
#  'PACIFIC JUNCTION': [['Mills'], [65.0]],
#  'PANORA': [['Guthrie'], [39.0]],
#  'PAULLINA': [["O'Brien"], [71.0]],
#  'PELLA': [['Marion'], [63.0]],
#  'PERRY': [['Boone', 'Dallas'], [8.0, 25.0]],
#  'PLEASANT HILL': [['Polk'], [77.0]],
#  'PLEASANTVILLE': [['Marion'], [63.0]],
#  'POCAHONTAS': [['Pocahontas'], [76.0]],
#  'POLK CITY': [['Polk'], [77.0]],
#  'PRIMGHAR': [["O'Brien"], [71.0]],
#  'RAYMOND': [['Black Hawk'], [7.0]],
#  'RED OAK': [['Montgomery'], [69.0]],
#  'RIVERSIDE': [['Washington'], [92.0]],
#  'ROCK RAPIDS': [['Lyon'], [60.0]],
#  'ROCK VALLEY': [['Sioux'], [84.0]],
#  'ROCKWELL': [['Cerro Gordo'], [17.0]],
#  'RUNNELLS': [[], []],
#  'SAC CITY': [['Sac'], [81.0]],
#  'SCHLESWIG': [['Crawford'], [24.0]],
#  'SERGEANT BLUFF': [['Woodbury'], [97.0]],
#  'SEYMOUR': [[], []],
#  'SHELDON': [["O'Brien"], [71.0]],
#  'SHELLSBURG': [['Benton'], [6.0]],
#  'SHENANDOAH': [['Page'], [73.0]],
#  'SIBLEY': [['Osceola'], [72.0]],
#  'SIGOURNEY': [['Keokuk'], [54.0]],
#  'SIOUX CENTER': [['Sioux'], [84.0]],
#  'SIOUX CITY': [['Woodbury'], [97.0]],
#  'SLOAN': [['Woodbury'], [97.0]],
#  'SOLON': [['Johnson'], [52.0]],
#  'SPENCER': [['Clay'], [21.0]],
#  'SPIRIT LAKE': [['Dickinson'], [30.0]],
#  'STATE CENTER': [['Marshall', 'Iowa'], [64.0, 48.0]],
#  'STORM LAKE': [['Buena Vista'], [11.0]],
#  'STORY CITY': [['Story'], [85.0]],
#  'STRAWBERRY POINT': [['Clayton'], [22.0]],
#  'STUART': [['Adair'], [1.0]],
#  'SUMNER': [['Bremer'], [9.0]],
#  'SUTHERLAND': [["O'Brien"], [71.0]],
#  'SWISHER': [['Johnson'], [52.0]],
#  'TABOR': [[], []],
#  'TIFFIN': [['Johnson'], [52.0]],
#  'TIPTON': [['Cedar'], [16.0]],
#  'TOLEDO': [['Tama'], [86.0]],
#  'TRAER': [['Tama'], [86.0]],
#  'TRIPOLI': [['Bremer'], [9.0]],
#  'URBANDALE': [['Polk'], [77.0]],
#  'VINTON': [['Benton'], [6.0]],
#  'WALNUT': [['Pottawattamie'], [78.0]],
#  'WASHINGTON': [['Washington'], [92.0]],
#  'WATERLOO': [['Black Hawk'], [7.0]],
#  'WAUKEE': [['Dallas'], [25.0]],
#  'WAUKON': [['Allamakee'], [3.0]],
#  'WAVERLY': [['Bremer'], [9.0]],
#  'WEBSTER CITY': [['Hamilton'], [40.0]],
#  'WELLMAN': [['Wapello'], [90.0]],
#  'WESLEY': [['Kossuth'], [55.0]],
#  'WEST BRANCH': [['Cedar'], [16.0]],
#  'WEST BURLINGTON': [['Des Moines'], [29.0]],
#  'WEST DES MOINES': [['Polk', 'Dallas'], [25.0, 77.0]],
#  'WEST LIBERTY': [['Muscatine'], [70.0]],
#  'WEST POINT': [['Lee'], [56.0]],
#  'WEST UNION': [['Fayette'], [33.0]],
#  'WHEATLAND': [['Clinton'], [23.0]],
#  'WILLIAMSBURG': [['Iowa'], [48.0]],
#  'WILTON': [['Muscatine'], [70.0]],
#  'WINDSOR HEIGHTS': [['Polk'], [77.0]],
#  'WINTERSET': [['Madison'], [61.0]],
#  'WOODBINE': [['Harrison'], [43.0]],
#  'ZWINGLE': [['Jackson'], [49.0]]}

# %%
## Replacing NaN county cells using corresponding city value as key

for cty in nan_cty_dict:
    try:
        df.loc[df['City'] == cty, 'County'] = nan_cty_dict[cty][0][0]
        df.loc[df['City'] == cty, "County Number"] = nan_cty_dict[cty][1][0]
    except:
        pass

# %%
# Recreate a new df to check remaining NaN row
df_nan = df[pd.isnull(df[['County','County Number']]).any(axis = 1)]

# %%
# Collect cities with NaN values
city_nan_list = list(df_nan['City'].unique())

city_nan_list
# Out:
# ['SEYMOUR', 'TABOR', 'RUNNELLS']

# %%
nan_cty_dict = {}

for j in city_nan_list:
    c_set = {x for x in df[df['City']==j]['County']} # x > 0 to skip NaN values
    num_set = {x for x in df[df['City']==j]['County Number']}
    nan_cty_dict[j] = [list(c_set), list(num_set)]

nan_cty_dict
# Out:
# {'RUNNELLS': [[nan],
#   [nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan]],
#  'SEYMOUR': [[nan],
#   [nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan]],
#  'TABOR': [[nan],
#   [nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan]]}

# %%
# Updating counties by hand

df.loc[df['City'] == 'TABOR', 'County'] = 'Fremont'
df.loc[df['City'] == 'RUNNELLS', 'County'] = 'Polk'
df.loc[df['City'] == 'SEYMOUR', 'County'] = 'Wayne'

# %%
# Recreate a new df to check remaining NaN row
df_nan = df[pd.isnull(df['County'])]

# %%
len(df_nan)
# Out:
# 0

# %% [markdown]
# #### Comments:
#
# Remaining 12 rows with empty counties were filled manually. Without a reference of how county numbers were developed, we left the empty county numbers empty. Analyses based on counties will be performed on 'County' instead of 'County Number'.

# %% [markdown]
# # ---------------------------------------------------------------

# %% [markdown]
# ## Cleaning Empty Category Name using Item Decription

# %%
df_nan = df[pd.isnull(df['Category Name'])]
print len(df_nan)
df_nan
# Out:
# 6109
#               Date  Store Number             City  Zip Code  County Number  \
# 3638    2016-03-31          2595          DENISON     51442           24.0
# 41883   2016-03-24          2515       MASON CITY     50401           17.0
# 43771   2016-03-24          4648         WATERLOO     50703            7.0
# 82854   2016-03-17          2106      CEDAR FALLS     50613            7.0
# 88787   2016-03-16          2512        IOWA CITY     52240           52.0
# 98331   2016-03-16          4129             AMES     50010           85.0
# 119563  2016-03-14          4829       DES MOINES     50314           77.0
# 155299  2016-03-07          4806     WEST LIBERTY     52776           70.0
# 174624  2016-03-02          3869       CORALVILLE     52241           52.0
# 185782  2016-03-01          2665           WAUKEE     50263           25.0
# 193373  2016-02-29          4184        MUSCATINE     52761           70.0
# 193405  2016-02-29          2591         ATLANTIC     50022           15.0
# 193406  2016-02-29          4794       BURLINGTON     52601           29.0
# 193430  2016-02-29          3805        DAVENPORT     52084           82.0
# 193445  2016-02-29          4604           NEWTON     50208           50.0
# 193487  2016-02-29          5226        DAVENPORT     52802           82.0
# 193513  2016-02-29          4962        DAVENPORT     52803           82.0
# 193516  2016-02-29          2647     CEDAR RAPIDS     52411           57.0
# 193525  2016-02-29          4897       BURLINGTON     52601           29.0
# 193533  2016-02-29          4892        DAVENPORT     52802           82.0
# 193618  2016-02-29          2460          HAMPTON     50441           35.0
# 193837  2016-02-29          3563        MUSCATINE     52761           70.0
# 193930  2016-02-29          4604           NEWTON     50208           50.0
# 193940  2016-02-29          4312   COUNCIL BLUFFS     51501           78.0
# 193944  2016-02-29          4696  WEST DES MOINES     50266           25.0
# 193968  2016-02-29          2527       DES MOINES     50315           77.0
# 193994  2016-02-29          2643         WATERLOO     50701            7.0
# 194026  2016-02-29          2506       BURLINGTON     52601           29.0
# 194028  2016-02-29          4604           NEWTON     50208           50.0
# 194041  2016-02-29          5142     CEDAR RAPIDS     52303           57.0
# ...            ...           ...              ...       ...            ...
# 2616509 2015-01-20          4805       FORT DODGE     50501           42.0
# 2621381 2015-01-16          2512        IOWA CITY     52240           52.0
# 2622175 2015-01-16          2448        INDIANOLA     50125           91.0
# 2626564 2015-01-16          2633       DES MOINES     50320           77.0
# 2631869 2015-01-15          2633       DES MOINES     50320           77.0
# 2639646 2015-01-14          3762  WINDSOR HEIGHTS     50322           77.0
# 2664708                   0.20
# 2664858                   1.19
# 2666829                   0.20
# 2671666                   1.19
# 2672059                   0.40
# 2672143                   1.19
# 2674067                   0.20
# 2674160                   0.20
# 2675728                   0.20
# 2693329                   0.79
# 2693877                   0.20
# 2696796                   0.20
# 2698396                   0.79
# 2699676                   0.40
# 2704872                   4.76
# 2704979                   0.40
# 2705446                   0.20
# 2706189                   0.99
#
# [6109 rows x 18 columns]

# %%
# Create a list of "Item Description" with NaN in rows
item_nan_list = list(df_nan['Item Description'].unique())

item_nan_list
# Out:
# ['Rondiaz Coconut Rum',
#  'Del Maguey San Luis Del Rio',
#  'Twenty Grand Gold',
#  'Pearl Caramel',
#  'St. George Absinthe Verte',
#  "St. Brendan's Irish Cream Liqueur",
#  'Patron Reposado',
#  "Hussong's Reposado Tequila 100% Agave",
#  'Giffard Creme de Pamplemousse Rose Pink Grapefruit Liqueur',
#  'Svedka Vodka',
#  'Stolichnaya Premium Vodka 80 Prf',
#  'Hennessy Vs Cognac',
#  'Captain Morgan Pineapple',
#  'Hennessy VS',
#  'Blue Chair Bay Coconut',
#  'Grand Marnier Cordon Rouge',
#  'Il Tramonto Limoncello',
#  'Licor 43',
#  'American Born Moonshine Apple Pie',
#  'Hennessy Vs Cognac 100ml',
#  'Grand Marnier Raspberry Peach',
#  'Belvedere Vodka',
#  'Disaronno Amaretto',
#  'Ole Smoky Apple Pie Moonshine',
#  'Belvedere Intense Unfiltered',
#  'Rondiaz Rum Spiced',
#  "Tim Smith's Climax Moonshine",
#  'Kraken Black Mini',
#  'Ricura Mini',
#  'Domaine de Canton',
#  'Hennessy Black',
#  'Letherbee Gin',
#  'Hennessy VSOP Privilege',
#  'Svedka',
#  'Exotico Blanco',
#  '1800 Silver',
#  'Blue Chair Bay Coconut Spiced',
#  'Olmeca Altos Reposado',
#  'Galliano Liqueur',
#  "Gosling's Black Seal",
#  '1800 Reposado',
#  "Dr. McGillicuddy's Peach Mini",
#  'American Born Moonshine Original',
#  'Tres Generaciones Anejo',
#  'Three Olives Cake Flavored Vodka',
#  'Remy Martin VSOP',
#  'Casa Noble Anejo',
#  "D'usse VSOP",
#  'Ole Smoky Cherry Moonshine',
#  "Dr. McGillicuddy's Apple Pie Mini",
#  'Sauza Cien Anos Reposado',
#  'Courvoisier Vsop Cognac',
#  'Captain Morgan Grapefruit',
#  'DeLeon Reposado',
#  "Dr. McGillicuddy's Peach",
#  'Peligroso Silver',
#  'Hornitos Spiced Honey',
#  'Passoa Liqueur',
#  'Peligroso Cinnamon',
#  'Berentzen Apple',
#  'Leblon Cachaca',
#  'Maraska Slivovitz',
#  'Blue Chair Bay Banana',
#  'Peligroso Anejo',
#  'Stolichnaya Ohranj Vodka',
#  'Captain Morgan Coconut',
#  'Casa Noble Reposado',
#  'Captain Morgan Coconut Mini',
#  'Exotico Reposado',
#  'Captain Morgan Pineapple Mini',
#  'American Born Moonshine Dixie',
#  'Captain Morgan Grapefruit Mini',
#  'Artisan Grain Original Moonshine',
#  'Absolut Hibiskus',
#  'Bird Dog Peppermint Moonshine',
#  'DeLeon Platinum',
#  'High Stick Vodka',
#  "Dr. McGillicuddy's Mentholmint",
#  'Alize Blue',
#  'La Collection Santa Claus',
#  'Alize Gold',
#  'Kahlua Peppermint Mocha',
#  'Jack Daniels TN Honey & Jack Daniels TN Fire 750mls w/2Gls',
#  'Svedka Raspberry Vodka',
#  'Peligroso Reposado',
#  'Yeni Raki',
#  'Kahlua Mocha',
#  'Rondiaz Rum Spiced Black Cherry Mini',
#  'Stolichnaya Russian Vodka 80 Prf',
#  'The Kings Ginger',
#  'Rothman & Winter Orchard Peach',
#  'Ciroc Pineapple',
#  'Westland American Single Malt',
#  'Westland Peated Single Malt',
#  'Westland Sherry Wood Single Malt',
#  'Svedka Strawberry Lemonade Vodka',
#  'Rondiaz Mini',
#  'Christian Drouin Calvados Selcetion',
#  'Anchor Old Tom Gin',
#  'Karlssons Gold Vodka',
#  'Hudson New York Corn',
#  'Stolichnaya Premium Vodka 80 Proof (lv)',
#  'Tiramisu Italian Liqueur',
#  'Terry Centenario',
#  'Courvoisier Gold',
#  'Calico Tropical Punch Jack Rum',
#  'Absolut w/Ginger Beer',
#  'Cruzan Passion Fruit',
#  'The Bitter Truth Apricot Liqueur',
#  'The Bitter Truth Violet Liqueur',
#  'Absolut Black 100',
#  'Grand Marnier Cuvee 1880 HA',
#  'Crystal Head Aurora Vodka',
#  'Herradura Gold Reposado 6pak',
#  'Templeton Rye w/Flask',
#  'Chambord Liqueur w/2 Glasses',
#  'The Bitter Truth Pimento Dram',
#  'Gentleman Jack w/2 Glasses',
#  'Knob Creek w/ Crystal Decanter',
#  'Southern Comfort w/Shot Glass & Lanyard',
#  'Disaronno Amaretto Cavalli Mignon 3-50ml Pack',
#  'Woodford Reserve MC 1838 White Corn',
#  'Pinnacle Candy Cane Trial Pack',
#  'Wild Turkey American Honey Shot Tap',
#  'Gamle Ode Celebration Aquavit',
#  'Gamle Ode Holiday',
#  'Van Gogh Chocolate Vodka',
#  'Van Gogh Rich Dark Chocolate Vodka',
#  'Van Gogh Coconut',
#  'Evan Williams Egg Nog',
#  'Grey Goose w/2 Martini Glasses',
#  'Bombay Sapphire w/Glass',
#  'Bacardi Oakheart',
#  'Cruzan Banana Rum',
#  "Whaler's Original Dark Rum",
#  'Parkers Heritage Collection Malt Whiskey HA',
#  'Chivas Regal 18YR Tin HA',
#  'Ciroc Ten HA',
#  'Cocoyac Excellence',
#  'Ultimat Vodka',
#  'Glenfiddich 1963 Replica HA']

# %%
item_dict = {}

for j in item_nan_list:
    c_set = {x for x in df[df['Item Description']==j]['Category Name'] if x > 0}
    item_dict[j] = list(c_set)

item_dict
# Out:
# {'1800 Reposado': ['TEQUILA'],
#  '1800 Silver': ['TEQUILA'],
#  'Absolut Black 100': [],
#  'Absolut Hibiskus': ['IMPORTED VODKA - MISC'],
#  'Absolut w/Ginger Beer': [],
#  'Alize Blue': [],
#  'Alize Gold': [],
#  'American Born Moonshine Apple Pie': ['DISTILLED SPIRITS SPECIALTY'],
#  'American Born Moonshine Dixie': ['DISTILLED SPIRITS SPECIALTY'],
#  'American Born Moonshine Original': ['DISTILLED SPIRITS SPECIALTY'],
#  'Anchor Old Tom Gin': [],
#  'Artisan Grain Original Moonshine': ['AMERICAN ALCOHOL',
#   'DISTILLED SPIRITS SPECIALTY'],
#  'Bacardi Oakheart': ['SPICED RUM'],
#  'Belvedere Intense Unfiltered': ['IMPORTED VODKA'],
#  'Belvedere Vodka': ['IMPORTED VODKA'],
#  'Berentzen Apple': ['MISC. IMPORTED CORDIALS & LIQUEURS'],
#  'Bird Dog Peppermint Moonshine': ['DISTILLED SPIRITS SPECIALTY'],
#  'Blue Chair Bay Banana': ['BARBADOS RUM', 'FLAVORED RUM'],
#  'Blue Chair Bay Coconut': ['BARBADOS RUM', 'FLAVORED RUM'],
#  'Blue Chair Bay Coconut Spiced': ['BARBADOS RUM', 'FLAVORED RUM'],
#  'Bombay Sapphire w/Glass': [],
#  'Calico Tropical Punch Jack Rum': [],
#  'Captain Morgan Coconut': ['FLAVORED RUM'],
#  'Captain Morgan Coconut Mini': ['FLAVORED RUM'],
#  'Captain Morgan Grapefruit': ['FLAVORED RUM'],
#  'Captain Morgan Grapefruit Mini': ['FLAVORED RUM'],
#  'Captain Morgan Pineapple': ['FLAVORED RUM'],
#  'Captain Morgan Pineapple Mini': ['FLAVORED RUM'],
#  'Casa Noble Anejo': ['TEQUILA'],
#  'Casa Noble Reposado': ['TEQUILA'],
#  'Chambord Liqueur w/2 Glasses': ['DECANTERS & SPECIALTY PACKAGES'],
#  'Chivas Regal 18YR Tin HA': [],
#  'Christian Drouin Calvados Selcetion': [],
#  'Ciroc Pineapple': ['IMPORTED VODKA - MISC'],
#  'Ciroc Ten HA': [],
#  'Cocoyac Excellence': [],
#  'Courvoisier Gold': [],
#  'Courvoisier Vsop Cognac': ['IMPORTED GRAPE BRANDIES'],
#  'Cruzan Banana Rum': ['FLAVORED RUM'],
#  'Cruzan Passion Fruit': ['FLAVORED RUM'],
#  'Crystal Head Aurora Vodka': ['DECANTERS & SPECIALTY PACKAGES'],
#  "D'usse VSOP": ['IMPORTED GRAPE BRANDIES',
#   'MISC. IMPORTED CORDIALS & LIQUEURS'],
#  'DeLeon Platinum': ['TEQUILA'],
#  'DeLeon Reposado': ['TEQUILA'],
#  'Del Maguey San Luis Del Rio': [],
#  'Disaronno Amaretto': ['MISC. IMPORTED CORDIALS & LIQUEURS',
#   'IMPORTED AMARETTO'],
#  'Disaronno Amaretto Cavalli Mignon 3-50ml Pack': ['DECANTERS & SPECIALTY PACKAGES'],
#  'Domaine de Canton': ['MISC. IMPORTED CORDIALS & LIQUEURS'],
#  "Dr. McGillicuddy's Apple Pie Mini": ['IMPORTED SCHNAPPS',
#   'MISC. IMPORTED CORDIALS & LIQUEURS'],
#  "Dr. McGillicuddy's Mentholmint": [],
#  "Dr. McGillicuddy's Peach": ['IMPORTED SCHNAPPS'],
#  "Dr. McGillicuddy's Peach Mini": ['IMPORTED SCHNAPPS'],
#  'Evan Williams Egg Nog': [],
#  'Exotico Blanco': ['TEQUILA'],
#  'Exotico Reposado': ['TEQUILA'],
#  'Galliano Liqueur': ['MISC. IMPORTED CORDIALS & LIQUEURS'],
#  'Gamle Ode Celebration Aquavit': [],
#  'Gamle Ode Holiday': [],
#  'Gentleman Jack w/2 Glasses': ['DECANTERS & SPECIALTY PACKAGES'],
#  'Giffard Creme de Pamplemousse Rose Pink Grapefruit Liqueur': [],
#  'Glenfiddich 1963 Replica HA': [],
#  "Gosling's Black Seal": ['FLAVORED RUM'],
#  'Grand Marnier Cordon Rouge': ['MISC. IMPORTED CORDIALS & LIQUEURS'],
#  'Grand Marnier Cuvee 1880 HA': [],
#  'Grand Marnier Raspberry Peach': ['MISC. IMPORTED CORDIALS & LIQUEURS'],
#  'Grey Goose w/2 Martini Glasses': ['DECANTERS & SPECIALTY PACKAGES'],
#  'Hennessy Black': ['IMPORTED GRAPE BRANDIES'],
#  'Hennessy VS': ['IMPORTED GRAPE BRANDIES'],
#  'Hennessy VSOP Privilege': ['IMPORTED GRAPE BRANDIES',
#   'MISC. IMPORTED CORDIALS & LIQUEURS'],
#  'Hennessy Vs Cognac': ['IMPORTED GRAPE BRANDIES'],
#  'Hennessy Vs Cognac 100ml': ['IMPORTED GRAPE BRANDIES'],
#  'Herradura Gold Reposado 6pak': ['TEQUILA'],
#  'High Stick Vodka': [],
#  'Hornitos Spiced Honey': ['TEQUILA'],
#  'Hudson New York Corn': [],
#  "Hussong's Reposado Tequila 100% Agave": [],
#  'Il Tramonto Limoncello': ['MISC. IMPORTED CORDIALS & LIQUEURS'],
#  'Jack Daniels TN Honey & Jack Daniels TN Fire 750mls w/2Gls': [],
#  'Kahlua Mocha': [],
#  'Kahlua Peppermint Mocha': ['DECANTERS & SPECIALTY PACKAGES',
#   'COFFEE LIQUEURS'],
#  'Karlssons Gold Vodka': [],
#  'Knob Creek w/ Crystal Decanter': [],
#  'Kraken Black Mini': [],
#  'La Collection Santa Claus': ['IMPORTED VODKA'],
#  'Leblon Cachaca': ['DISTILLED SPIRITS SPECIALTY'],
#  'Letherbee Gin': ['AMERICAN DRY GINS'],
#  'Licor 43': ['MISC. IMPORTED CORDIALS & LIQUEURS'],
#  'Maraska Slivovitz': ['IMPORTED GRAPE BRANDIES', 'MISCELLANEOUS  BRANDIES'],
#  'Ole Smoky Apple Pie Moonshine': ['DISTILLED SPIRITS SPECIALTY'],
#  'Ole Smoky Cherry Moonshine': ['DISTILLED SPIRITS SPECIALTY'],
#  'Olmeca Altos Reposado': ['TEQUILA'],
#  'Parkers Heritage Collection Malt Whiskey HA': [],
#  'Passoa Liqueur': ['MISC. IMPORTED CORDIALS & LIQUEURS'],
#  'Patron Reposado': ['TEQUILA'],
#  'Pearl Caramel': [],
#  'Peligroso Anejo': ['TEQUILA'],
#  'Peligroso Cinnamon': ['TEQUILA'],
#  'Peligroso Reposado': ['TEQUILA'],
#  'Peligroso Silver': ['TEQUILA'],
#  'Pinnacle Candy Cane Trial Pack': [],
#  'Remy Martin VSOP': ['IMPORTED GRAPE BRANDIES'],
#  'Ricura Mini': ['MISC. IMPORTED CORDIALS & LIQUEURS',
#   'MISC. AMERICAN CORDIALS & LIQUEURS'],
#  'Rondiaz Coconut Rum': [],
#  'Rondiaz Mini': ['SPICED RUM'],
#  'Rondiaz Rum Spiced': ['SPICED RUM'],
#  'Rondiaz Rum Spiced Black Cherry Mini': ['SPICED RUM'],
#  'Rothman & Winter Orchard Peach': [],
#  'Sauza Cien Anos Reposado': ['TEQUILA'],
#  'Southern Comfort w/Shot Glass & Lanyard': ['DECANTERS & SPECIALTY PACKAGES'],
#  "St. Brendan's Irish Cream Liqueur": ['CREAM LIQUEURS'],
#  'St. George Absinthe Verte': [],
#  'Stolichnaya Ohranj Vodka': ['IMPORTED VODKA - MISC'],
#  'Stolichnaya Premium Vodka 80 Prf': ['IMPORTED VODKA'],
#  'Stolichnaya Premium Vodka 80 Proof (lv)': ['IMPORTED VODKA'],
#  'Stolichnaya Russian Vodka 80 Prf': ['IMPORTED VODKA'],
#  'Svedka': ['IMPORTED VODKA'],
#  'Svedka Raspberry Vodka': ['IMPORTED VODKA - MISC'],
#  'Svedka Strawberry Lemonade Vodka': [],
#  'Svedka Vodka': ['IMPORTED VODKA'],
#  'Templeton Rye w/Flask': ['DECANTERS & SPECIALTY PACKAGES'],
#  'Terry Centenario': [],
#  'The Bitter Truth Apricot Liqueur': [],
#  'The Bitter Truth Pimento Dram': [],
#  'The Bitter Truth Violet Liqueur': [],
#  'The Kings Ginger': [],
#  'Three Olives Cake Flavored Vodka': ['IMPORTED VODKA - MISC'],
#  "Tim Smith's Climax Moonshine": ['DISTILLED SPIRITS SPECIALTY'],
#  'Tiramisu Italian Liqueur': [],
#  'Tres Generaciones Anejo': ['TEQUILA'],
#  'Twenty Grand Gold': [],
#  'Ultimat Vodka': [],
#  'Van Gogh Chocolate Vodka': [],
#  'Van Gogh Coconut': [],
#  'Van Gogh Rich Dark Chocolate Vodka': [],
#  'Westland American Single Malt': [],
#  'Westland Peated Single Malt': [],
#  'Westland Sherry Wood Single Malt': [],
#  "Whaler's Original Dark Rum": [],
#  'Wild Turkey American Honey Shot Tap': [],
#  'Woodford Reserve MC 1838 White Corn': [],
#  'Yeni Raki': ['MISC. IMPORTED CORDIALS & LIQUEURS']}

# %%
for drink in item_dict:
    try:
        df.loc[df['Item Description'] == drink, 'Category Name'] = item_dict[drink][0]
    except:
        pass

# %%
df_nan = df[pd.isnull(df['Category Name'])]
print len(df_nan)
df_nan
# Out:
# 539
#               Date  Store Number             City  Zip Code  County Number  \
# 3638    2016-03-31          2595          DENISON     51442           24.0
# 41883   2016-03-24          2515       MASON CITY     50401           17.0
# 43771   2016-03-24          4648         WATERLOO     50703            7.0
# 82854   2016-03-17          2106      CEDAR FALLS     50613            7.0
# 88787   2016-03-16          2512        IOWA CITY     52240           52.0
# 98331   2016-03-16          4129             AMES     50010           85.0
# 174624  2016-03-02          3869       CORALVILLE     52241           52.0
# 185782  2016-03-01          2665           WAUKEE     50263           25.0
# 195605  2016-02-29          2506       BURLINGTON     52601           29.0
# 200785  2016-02-29          2538         WATERLOO     50702            7.0
# 202362  2016-02-29          4604           NEWTON     50208           50.0
# 268515  2016-02-16          2666           ANKENY     50023           77.0
# 284717  2016-02-11          4839        NORTHWOOD     50459           98.0
# 293753  2016-02-10          4509             AMES     50010           85.0
# 301364  2016-02-10          4509             AMES     50010           85.0
# 317261  2016-02-08          4604           NEWTON     50208           50.0
# 361250  2016-02-01          2648  WEST DES MOINES     50265           25.0
# 361257  2016-02-01          2633       DES MOINES     50320           77.0
# 368164  2016-01-28          2633       DES MOINES     50320           77.0
# 376090  2016-01-27          2285        IOWA CITY     52240           52.0
# 376421  2016-01-27          4129             AMES     50010           85.0
# 376422  2016-01-27          4129             AMES     50010           85.0
# 376425  2016-01-27          4129             AMES     50010           85.0
# 376431  2016-01-27          4509             AMES     50010           85.0
# 376438  2016-01-27          3773     CEDAR RAPIDS     52401           57.0
# 376494  2016-01-27          3773     CEDAR RAPIDS     52401           57.0
# 399208  2016-01-25          3773     CEDAR RAPIDS     52401           57.0
# 399218  2016-01-25          3773     CEDAR RAPIDS     52401           57.0
# 399223  2016-01-25          3773     CEDAR RAPIDS     52401           57.0
# 399224  2016-01-25          3773     CEDAR RAPIDS     52401           57.0
# ...            ...           ...              ...       ...            ...
# 1595841 2015-07-13          2190       DES MOINES     50314           77.0
# 1597479 2015-07-13          2506       BURLINGTON     52601           29.0
# 1599086                   0.79
# 1635999                   1.19
# 1644425                   0.20
# 1672447                   0.20
# 1673464                   2.38
# 1682192                   1.19
# 1690035                   0.40
# 1699336                   0.59
# 1700135                   1.19
# 1700428                   0.59
# 1706868                   0.40
# 1709194                   1.19
# 1713333                   1.19
# 1718587                   2.38
# 1721831                   1.19
# 1722629                   1.19
# 1727483                   1.19
# 1727744                   0.20
# 1729184                   0.40
# 1779504                   0.79
# 1859971                   1.19
# 1917305                   0.20
# 2121006                   2.38
# 2164056                   2.38
# 2193307                   2.38
# 2515121                   2.38
#
# [539 rows x 18 columns]

# %%
df_nan['Item Description'].unique()
# Out:
# array(['Rondiaz Coconut Rum', 'Del Maguey San Luis Del Rio',
#        'Twenty Grand Gold', 'Pearl Caramel', 'St. George Absinthe Verte',
#        "Hussong's Reposado Tequila 100% Agave",
#        'Giffard Creme de Pamplemousse Rose Pink Grapefruit Liqueur',
#        'Kraken Black Mini', 'High Stick Vodka',
#        "Dr. McGillicuddy's Mentholmint", 'Alize Blue', 'Alize Gold',
#        'Jack Daniels TN Honey & Jack Daniels TN Fire 750mls w/2Gls',
#        'Kahlua Mocha', 'The Kings Ginger',
#        'Rothman & Winter Orchard Peach', 'Westland American Single Malt',
#        'Westland Peated Single Malt', 'Westland Sherry Wood Single Malt',
#        'Svedka Strawberry Lemonade Vodka',
#        'Christian Drouin Calvados Selcetion', 'Anchor Old Tom Gin',
#        'Karlssons Gold Vodka', 'Hudson New York Corn',
#        'Tiramisu Italian Liqueur', 'Terry Centenario', 'Courvoisier Gold',
#        'Calico Tropical Punch Jack Rum', 'Absolut w/Ginger Beer',
#        'The Bitter Truth Apricot Liqueur',
#        'The Bitter Truth Violet Liqueur', 'Absolut Black 100',
#        'Grand Marnier Cuvee 1880 HA', 'The Bitter Truth Pimento Dram',
#        'Knob Creek w/ Crystal Decanter',
#        'Woodford Reserve MC 1838 White Corn',
#        'Pinnacle Candy Cane Trial Pack',
#        'Wild Turkey American Honey Shot Tap',
#        'Gamle Ode Celebration Aquavit', 'Gamle Ode Holiday',
#        'Van Gogh Chocolate Vodka', 'Van Gogh Rich Dark Chocolate Vodka',
#        'Van Gogh Coconut', 'Evan Williams Egg Nog',
#        'Bombay Sapphire w/Glass', "Whaler's Original Dark Rum",
#        'Parkers Heritage Collection Malt Whiskey HA',
#        'Chivas Regal 18YR Tin HA', 'Ciroc Ten HA', 'Cocoyac Excellence',
#        'Ultimat Vodka', 'Glenfiddich 1963 Replica HA'], dtype=object)

# %%
package = ['Jack Daniels TN Honey & Jack Daniels TN Fire 750mls w/2Gls', 'Bombay Sapphire w/Glass',\
           'Evan Williams Egg Nog', 'Pinnacle Candy Cane Trial Pack', 'Wild Turkey American Honey Shot Tap',\
           'Knob Creek w/ Crystal Decanter']

for i in package:
    df.loc[df['Item Description'] == i,'Category Name'] = 'DECANTERS & SPECIALTY PACKAGES'

# %%
df.loc[df['Item Description'] == 'Woodford Reserve MC 1838 White Corn',\
       'Category Name'] = 'CORN WHISKIES'

df.loc[df['Item Description'] == 'Hudson New York Corn',\
       'Category Name'] = 'CORN WHISKIES'

# %%
lique = ['Rothman & Winter Orchard Peach', 'Giffard Creme de Pamplemousse Rose Pink Grapefruit Liqueur',\
        'Pearl Caramel', 'Tiramisu Italian Liqueur', 'The Bitter Truth Apricot Liqueur',\
       'The Bitter Truth Violet Liqueur', 'Kahlua Mocha', "Dr. McGillicuddy's Mentholmint", 'Alize Blue',\
         'The Kings Ginger', 'Courvoisier Gold', 'Grand Marnier Cuvee 1880 HA', 'Cocoyac Excellence'\
        ]

for i in lique:
    df.loc[df['Item Description'] == i,'Category Name'] ='MISC. IMPORTED CORDIALS & LIQUEURS'

# %%
scotch = ['Westland American Single Malt',
       'Westland Peated Single Malt', 'Westland Sherry Wood Single Malt'\
          'Glenfiddich 1963 Replica HA']

for s in scotch:
    df.loc[df['Item Description'] == s, 'Category Name'] ='SINGLE MALT SCOTCH'

# %%
df.loc[df['Item Description'] == 'Parkers Heritage Collection Malt Whiskey HA',\
       'Category Name'] = "STRAIGHT BOURBON WHISKIES"

df.loc[df['Item Description'] == 'Chivas Regal 18YR Tin HA',\
       'Category Name'] = 'BLENDED WHISKIES'

# %%
vod = ['High Stick Vodka', 'Ciroc Ten HA', 'Ultimat Vodka', 'Karlssons Gold Vodka']

for i in vod:
    df.loc[df['Item Description'] == i,'Category Name'] = 'IMPORTED VODKA'

df.loc[df['Item Description'] == 'Absolut Black 100', 'Category Name'] = '100 PROOF VODKA'

fvod = ['Van Gogh Rich Dark Chocolate Vodka',\
        'Absolut w/Ginger Beer',\
       'Van Gogh Chocolate Vodka',\
       'Svedka Strawberry Lemonade Vodka',\
       'Van Gogh Coconut', 'Alize Gold']

for f in fvod:
    df.loc[df['Item Description'] == f, 'Category Name'] = 'VODKA FLAVORED'
    
    
df.loc[df['Item Description'] == 'Twenty Grand Gold',\
       'Category Name'] = 'VODKA 80 PROOF'

# %%
teq = ['Del Maguey San Luis Del Rio', "Hussong's Reposado Tequila 100% Agave"]

for t in teq:
    df.loc[df['Item Description'] == t, 'Category Name'] = 'TEQUILA'

# %%
df.loc[df['Item Description'] == 'Kraken Black Mini', 'Category Name'] = 'SPICED RUM'

df.loc[df['Item Description'] == 'The Bitter Truth Pimento Dram', 'Category Name'] = 'JAMAICA RUM'



rum = ['Rondiaz Coconut Rum', 'Calico Tropical Punch Jack Rum' "Whaler's Original Dark Rum"]

for r in rum:
    df.loc[df['Item Description'] == r, 'Category Name'] = 'FLAVORED RUM'

# %%
df.loc[df['Item Description'] == 'St. George Absinthe Verte', 'Category Name'] = 'DISTILLED SPIRITS SPECIALTY'

# %%
brandy = ['Christian Drouin Calvados Selcetion',\
          'Terry Centenario']

for b in brandy:
    df.loc[df['Item Description'] == b, 'Category Name'] = 'IMPORTED GRAPE BRANDIES'

# %%
df.loc[df['Item Description'] == 'Anchor Old Tom Gin', 'Category Name'] = 'AMERICAN DRY GINS'

# %%
df.loc[df['Item Description'] == 'Gamle Ode Celebration Aquavit', 'Category Name'] = 'MISCELLANEOUS SCHNAPPS'

df.loc[df['Item Description'] == 'Gamle Ode Holiday', 'Category Name'] = 'MISCELLANEOUS SCHNAPPS'

# %% [markdown]
# #### Comments:
#
# There are still cells in 'Category' with NaN values, however, since we will only be using "Category Name" for analyses, NaNs in 'Category' were not cleaned.

# %% [markdown]
# ## Creating new features

# %% [markdown]
#
# Osceola              23603   3.153699e+05        5.267933e+04
# Audubon              18819   2.140491e+05        3.239987e+04
# Decatur              18002   2.192651e+05        3.316570e+04
# Keokuk               16871   1.857841e+05        4.492004e+04
# Van Buren            16229   2.199142e+05        3.525572e+04
# Ringgold             12769   1.731132e+05        2.629768e+04
# Taylor               12147   1.423536e+05        4.048634e+04
# Wayne                10755   1.352292e+05        2.436677e+04
# Davis                 9429   1.170033e+05        2.630054e+04
# Mahaska               3704   4.022648e+04        4.991250e+03
# Fremont               3355   3.284335e+04        3.164890e+03
#
# [98 rows x 3 columns]

# %%
df['City'].value_counts()
# Out:
# DES MOINES         238778
# CEDAR RAPIDS       186121
# DAVENPORT          116681
# WATERLOO            84677
# COUNCIL BLUFFS      80938
# IOWA CITY           80356
# SIOUX CITY          79855
# AMES                75893
# WEST DES MOINES     71791
# DUBUQUE             69058
# CEDAR FALLS         57277
# ANKENY              47778
# MASON CITY          42335
# BETTENDORF          36786
# CORALVILLE          36138
# MUSCATINE           33678
# BURLINGTON          31043
# CLINTON             30980
# FORT DODGE          29428
# WINDSOR HEIGHTS     27679
# MARSHALLTOWN        26773
# NEWTON              25597
# STORM LAKE          25461
# URBANDALE           24614
# MARION              24091
# OTTUMWA             22471
# ALTOONA             21400
# JOHNSTON            21290
# CLEAR LAKE          20901
# SPENCER             19194
#                     ...
# AFTON                 175
# OTHO                  175
# VAN METER             167
# BUSSEY                165
# MINDEN                162
# STANWOOD              159
# WELLSBURG             159
# GOLDFIELD             154
# DONNELLSON            149
# MARTENSDALE           142
# MERRILL               134
# ALTA                  132
# LATIMER               130
# LOVILIA               129
# SCHALLER              129
# DELHI                 120
# SULLY                 115
# DANVILLE              112
# AURELIA                99
# EVERLY                 98
# FONDA                  92
# SEYMOUR                84
# LOHRVILLE              73
# CUMMING                71
# GILBERTVILLE           60
# MELBOURNE              57
# RUNNELLS               47
# TABOR                  47
# GRISWOLD               46
# ROBINS                 44
# Name: City, dtype: int64

# %% [markdown]
# #### Scenario 2: Market research for new store locations
#
# A liquor store owner in Iowa is looking to expand to new locations and has hired you to investigate the market data for potential new locations. The business owner is interested in the details of the best model you can fit to the data so that his team can evaluate potential locations for a new storefront.
#
# **Goal for Scenario #2:** Your task is to:
#
# * Build models of total sales based on location, price per bottle, total bottles sold. You may find it useful to build models for each county, zip code, or city.
# * Provide a table of the best performing stores by location type of your choice (city, county, or zip code) and the predictions of your model(s).
# * Based on your models and the table of data, recommend some general locations to the business owner, taking into account model performance. Validate your model's performance and ability to predict future sales using cross-validation.
# * _Bonus_: Recommend targets for volume sold and price per bottle!
#
# ---

# %%
# Creating a new df for 2015 and 2016 separately
df_15 = df[df['Sale Year'] == 2015]
df_16 = df[df['Sale Year'] == 2016]

# %%
# Pivoting data frame based on county

county_15 = pd.pivot_table(df, index = ['County'], \
               values = ['State Bottle Retail', 'Bottles Sold', 'Sale (Dollars)', 'Store Number'],\
              aggfunc = [np.sum, np.mean, pd.Series.nunique]\
              ).sort_values([('sum', 'Sale (Dollars)')], ascending = False)

county_15.reset_index(inplace=True)
county_15.head()
# Out:
#        County          sum                                                  \
#               Bottles Sold Sale (Dollars) State Bottle Retail Store Number
# 0        Polk      5975963   8.215784e+07        7.615469e+06   1774152313
# 1        Linn      2434575   3.098818e+07        3.365035e+06    819857648
# 2     Johnson      1429065   2.032823e+07        1.914118e+06    408795855
# 3  Black Hawk      1739236   1.991899e+07        2.137939e+06    559157605
# 4       Scott      1648316   1.896129e+07        1.850304e+06    493782676
#
#           mean                                                      nunique  \
#   Bottles Sold Sale (Dollars) State Bottle Retail Store Number Bottles Sold
# 0    12.061274     165.818990           15.370284  3580.767867          184
# 1    10.468859     133.251539           14.469910  3525.450639          152
# 2    11.720853     166.727329           15.699143  3352.846873          116
# 3    11.494825     131.647056           14.129901  3695.541519          132
# 4    12.244941     140.858842           13.745458  3668.192108          131
#
#
#   Sale (Dollars) State Bottle Retail Store Number
# 0         8018.0              1367.0          210
# 1         6019.0              1032.0          104
# 2         5260.0              1020.0           47
# 3         5277.0               966.0           73
# 4         5306.0               888.0           57

# %%
# Extracting relevant columns into a new df

county_15_new = pd.concat([county_15['County'], \
                          county_15[('sum', 'Sale (Dollars)')], \
                          county_15[('sum', 'Bottles Sold')], \
                          county_15[('mean', 'State Bottle Retail')], \
                          county_15[('nunique', 'Store Number')] \
                          ], \
                          axis = 1)

county_15_new.columns = ['County', 'Sum Sale','Sum Bottles Sold', "Avg Bottle Price","Number of stores"]

county_15_new['Avg Bottle Price'] = county_15_new['Avg Bottle Price'].apply(lambda x: round(x, 2))

county_15_new.sort_values(['Sum Sale'], ascending = False, inplace=True)

county_15_new.head(10)
# Out:
#           County      Sum Sale  Sum Bottles Sold  Avg Bottle Price  \
# 0           Polk  8.215784e+07           5975963             15.37
# 1           Linn  3.098818e+07           2434575             14.47
# 2        Johnson  2.032823e+07           1429065             15.70
# 3     Black Hawk  1.991899e+07           1739236             14.13
# 4          Scott  1.896129e+07           1648316             13.75
# 5       Woodbury  1.250641e+07            950205             14.97
# 6  Pottawattamie  1.242305e+07            951506             14.17
# 7        Dubuque  1.072651e+07            783894             15.00
# 8          Story  1.059031e+07            770265             15.30
# 9           Iowa  8.719431e+06            605387             16.18
#
#    Number of stores
# 0               210
# 1               104
# 2                47
# 3                73
# 4                57
# 5                39
# 6                53
# 7                41
# 8                38
# 9                26

# %%
# Plotting total sale of each county for top 15 counties in descending sale

ax = county_15_new.head(10).plot(x = 'County', kind = "bar", y = 'Sum Sale', figsize = (15,8))

ax.set_title('Total Sales in top 10 Counties in 2015 IOWA')
ax.set_xlabel('County')
ax.set_yticklabels(['$1,000,000', '$2,000,000', '$3,000,000',\
                    '$4,000,000', '$5,000,000', '$6,000,000', \
                    '$7,000,000', '$8,000,000', '$9,000,000'], fontsize = 12);

# %% [markdown]
# #### Comments:
#
# In 2015, Polk had, by far, the highest sales in all counties in IOWA, over 2 times the next highest county, Linn.

# %%
# Pivoting based on store number

st = pd.pivot_table(df_15, index = ['Store Number', 'County'],\
                       values = ['Bottles Sold',\
                                 'Sale (Dollars)',\
                                 'State Bottle Retail' \
                                ],\
                       aggfunc = [np.sum, np.mean]\
                      ).sort_values([('sum', 'Sale (Dollars)')], ascending = False)

st.reset_index(inplace=True)

st.head()
# Out:
#   Store Number   County          sum                                     \
#                         Bottles Sold Sale (Dollars) State Bottle Retail
# 0         2633     Polk       595205     9839393.08           359200.19
# 1         4829     Polk       520100     8742779.31           344628.84
# 2         2512  Johnson       282804     4155665.47           232070.24
# 3         3385     Linn       245312     3947176.01            88458.66
# 4         3420     Polk       192664     3422351.55            59013.99
#
#           mean
#   Bottles Sold Sale (Dollars) State Bottle Retail
# 0    30.510816     504.377336           18.412969
# 1    28.558094     480.055969           18.923174
# 2    19.813914     291.155711           16.259388
# 3    50.033041     805.053235           18.041742
# 4    61.850401    1098.668234           18.945101

# %%
# Extracting relevant columns into a new df

st_n = pd.concat([st['Store Number'], \
               st['County'], \
               st[('sum', 'Sale (Dollars)')], \
               st[('sum', 'Bottles Sold')], \
               st[('mean', 'State Bottle Retail')], \
               ], \
              axis = 1)

st_n.columns = ['Store Number', 'County','Sum Sale', 'Sum Bottles Sold', "Avg Bottle Price"]

st_n['Avg Bottle Price'] = st_n['Avg Bottle Price'].apply(lambda x: round(x, 2))

st_n.sort_values(['Sum Sale'], ascending = False, inplace=True)

st_n.head(10)
# Out:
#    Store Number   County    Sum Sale  Sum Bottles Sold  Avg Bottle Price
# 0          2633     Polk  9839393.08            595205             18.41
# 1          4829     Polk  8742779.31            520100             18.92
# 2          2512  Johnson  4155665.47            282804             16.26
# 3          3385     Linn  3947176.01            245312             18.04
# 4          3420     Polk  3422351.55            192664             18.95
# 5          3952     Iowa  3045758.76            177414             20.12
# 6          3814     Polk  2899984.38            117462             26.07
# 7          2670  Johnson  2402265.82            156560             16.34
# 8          3354    Scott  2385085.09            139726             18.21
# 9          3773     Linn  2297121.49            131936             20.31

# %%
import seaborn as sns
sns.pairplot(st_n)

# %%
# Zooming into the highly skewed distribution of sale

ax = st_n['Sum Sale'].hist(bins = 2000, figsize = (15,8))
ax.set_xlim([0,1000000]);

# %%
ax = st_n['Sum Sale'].hist(bins = 2000, figsize = (15,8))
ax.set_xlim([0,250000]);

# %%
# Plotting number of bottles sold vs sale for each store in IOWA in 2015

ax = st_n.plot(kind = 'scatter', x = 'Sum Bottles Sold', y = 'Sum Sale',\
                  s = 200, alpha = 0.3, figsize = (15,8))
ax.set_title('Number of bottles sold vs sale for each liquor store in 2015 IOWA ', y = 1.01);

# %%
# View of outliers

st_n[st_n['Sum Bottles Sold'] >= 100000]
# Out:
#     Store Number         County    Sum Sale  Sum Bottles Sold  \
# 0           2633           Polk  9839393.08            595205
# 1           4829           Polk  8742779.31            520100
# 2           2512        Johnson  4155665.47            282804
# 3           3385           Linn  3947176.01            245312
# 4           3420           Polk  3422351.55            192664
# 5           3952           Iowa  3045758.76            177414
# 6           3814           Polk  2899984.38            117462
# 7           2670        Johnson  2402265.82            156560
# 8           3354          Scott  2385085.09            139726
# 9           3773           Linn  2297121.49            131936
# 10          5102           Linn  1955345.43            138434
# 11          3447       Woodbury  1948203.20            109582
# 12          2625          Scott  1922777.34            126255
# 13          4167        Dubuque  1850973.32            126982
# 14          3494     Black Hawk  1755333.32            109737
# 15          3524          Story  1676609.93            103009
# 17          2593        Carroll  1638188.36            105787
# 19          2629  Pottawattamie  1626385.05            106424
# 20          2614          Scott  1611044.22            109065
# 21          3820       Woodbury  1594081.40            104532
# 24          2616        Clinton  1578331.78            115636
# 31          2501          Story  1379036.74            102174
# 43          2190           Polk  1228571.74            107522
# 60          2627           Polk   948926.70            126075
#
#     Avg Bottle Price
# 0              18.41
# 1              18.92
# 2              16.26
# 3              18.04
# 4              18.95
# 5              20.12
# 6              26.07
# 7              16.34
# 8              18.21
# 9              20.31
# 10             18.28
# 11             17.96
# 12             15.53
# 13             16.38
# 14             17.11
# 15             18.16
# 17             14.92
# 19             16.38
# 20             15.38
# 21             16.58
# 24             15.42
# 31             15.60
# 43             17.86
# 60             12.52

# %% [markdown]
# #### Comments:
#
# As suspected, all these outliers came from the Top 10 counties for sale. In particular, Polk had 2 of the extreme outliers with sale of over $8,000,000.

# %% [markdown]
# ## Using Median instead of mean due to presence of strong outliers

# %%
# Pivoting based on county

st_piv = pd.pivot_table(st_n, index = ['County'], \
                        aggfunc = [sum, np.median, pd.Series.nunique]\
                        ).sort_values(\
                                      [('median', 'Sum Sale')], ascending = False\
                                     )
st_piv.reset_index(inplace=True)
st_piv.head(15)
# Out:
#          County              sum                                             \
#                 Avg Bottle Price Store Number Sum Bottles Sold     Sum Sale
# 0    Winneshiek            74.36        21303            92729   1284923.04
# 1         Jones            57.85        14120            78395   1015238.25
# 2       Kossuth           109.40        25489           124337   1769012.89
# 3        Monona            40.48        12501            42020    519700.46
# 4         Lucas            28.88         7271            31177    415069.06
# 5   Cerro Gordo           277.61        79865           448722   5751979.57
# 6      Buchanan           209.93        61367           176650   2230322.15
# 7         Union            82.13        24852            70322    968807.50
# 8         Scott           726.01       243571          1336659  15424992.24
# 9        Howard            45.01        11355            49092    710520.03
# 10          Ida            61.48        17457            38825    547270.83
# 11       Bremer           127.66        38218           131767   1794322.78
# 12      Osceola            28.88         9480            19448    259985.23
# 13       Marion           150.89        42750           146471   1974697.44
# 14    Jefferson            54.31        15821            65354    863813.42
#
#              median                                            \
#    Avg Bottle Price Store Number Sum Bottles Sold    Sum Sale
# 0            15.550       4183.0          21382.0  282036.820
# 1            14.160       3690.5          19753.5  265864.930
# 2            15.480       3842.0          13883.0  232513.300
# 3            13.930       3932.0          15276.0  222135.340
# 4            14.440       3635.5          15588.5  207534.530
# 5            13.810       4352.0          14207.0  180305.020
# 6            14.430       4090.0          11903.0  157986.760
# 7            13.990       4411.0          11006.5  149868.450
# 8            13.170       4644.0          17778.0  148977.850
# 9            14.700       4233.0          10339.0  145839.060
# 10           15.685       4328.0          10826.0  140079.055
# 11           13.580       4203.0          10116.0  134666.940
# 12           14.440       4740.0           9724.0  129992.615
# 13           14.650       3949.0           8580.0  129844.130
# 14           13.570       4261.0          10708.5  125400.635
#
#             nunique
#    Avg Bottle Price Store Number Sum Bottles Sold Sum Sale
# 0               5.0            5                5      5.0
# 1               4.0            4                4      4.0
# 2               7.0            7                7      7.0
# 3               3.0            3                3      3.0
# 4               2.0            2                2      2.0
# 5              20.0           20               20     20.0
# 6              15.0           15               15     15.0
# 7               6.0            6                6      6.0
# 8              51.0           55               55     55.0
# 9               3.0            3                3      3.0
# 10              4.0            4                4      4.0
# 11              8.0            9                9      9.0
# 12              2.0            2                2      2.0
# 13             11.0           11               11     11.0
# 14              4.0            4                4      4.0

# %%
# Selecting required columns to view county performance based on median

median_county = pd.concat([st_piv['County'], \
                           st_piv[('sum', 'Sum Sale')], \
                           st_piv[('sum', 'Sum Bottles Sold')], \
                           st_piv[('median', 'Sum Sale')], \
                           st_piv[('median', 'Sum Bottles Sold')], \
                           st_piv[('median', 'Avg Bottle Price')], \
                           st_piv[('nunique', 'Store Number')], \
                          ], \
                          axis = 1)

# Renaming the columns

median_county.columns = ['County','Sum Sale', \
                         'Sum Bottles Sold', \
                         'Median Sale', \
                         "Median Bottles Sold", \
                         "Median Bottle Price", \
                         'No. of stores']

median_county.sort_values(['Median Sale'], ascending = False, inplace=True)

median_county.head(10)
# Out:
#         County     Sum Sale  Sum Bottles Sold  Median Sale  \
# 0   Winneshiek   1284923.04             92729    282036.82
# 1        Jones   1015238.25             78395    265864.93
# 2      Kossuth   1769012.89            124337    232513.30
# 3       Monona    519700.46             42020    222135.34
# 4        Lucas    415069.06             31177    207534.53
# 5  Cerro Gordo   5751979.57            448722    180305.02
# 6     Buchanan   2230322.15            176650    157986.76
# 7        Union    968807.50             70322    149868.45
# 8        Scott  15424992.24           1336659    148977.85
# 9       Howard    710520.03             49092    145839.06
#
#    Median Bottles Sold  Median Bottle Price  No. of stores
# 0              21382.0                15.55              5
# 1              19753.5                14.16              4
# 2              13883.0                15.48              7
# 3              15276.0                13.93              3
# 4              15588.5                14.44              2
# 5              14207.0                13.81             20
# 6              11903.0                14.43             15
# 7              11006.5                13.99              6
# 8              17778.0                13.17             55
# 9              10339.0                14.70              3

# %%
ax = median_county.head(10).plot(x = 'County', kind = "bar", \
                                 y = 'Median Sale', figsize = (15,8))

ax.set_title('Yearly Median Sale per store in top 10 Counties in 2015 IOWA', y = 1.05)
ax.set_xlabel('County')
ax.set_yticklabels(['$5,000', '$10,000', '$15,000',\
                    '$20,000', '$25,000', '$30,000', \
                    '$35,000', '$40,000', '$45,000'], fontsize = 12);

# %%
# Display new performance positions of previous top 3 counties

median_county[(median_county['County'] == 'Polk')|\
              (median_county['County'] == 'Linn')|\
              (median_county['County'] == 'Scott')]
# Out:
#    County     Sum Sale  Sum Bottles Sold  Median Sale  Median Bottles Sold  \
# 8   Scott  15424992.24           1336659   148977.850              17778.0
# 50   Polk  66835930.46           4831410    72630.725               7461.5
# 52   Linn  24989946.22           1960733    71209.610               6579.0
#
#     Median Bottle Price  No. of stores
# 8                 13.17             55
# 50                13.76            208
# 52                12.98            101

# %% [markdown]
# #### Comments:
#
# Due to the presence of outliers, using mean would distort the data significantly. We see that using median as a metric shows a completely different list of counties.
#
# Interesting to note that from overwhelmingly high positions, Polk, Linn and Scott, are not even in the top 20 counties in median yearly sale (52nd, 55th and 18th position respectively).

# %% [markdown]
# ## Modelling (with outliers)

# %% [markdown]
# ### County : Winneshiek (Top Median sale)

# %%
# Filtering the df for data from first 3 months of 2015

dfm = df_15[((df_15['Sale Month'] == 1)|(df_15['Sale Month'] == 2)|(df_15['Sale Month'] == 3))\
        & (df_15['County'] == "Winneshiek")]

# %%
dfm.head()
# Out:
#               Date  Store Number           City  Zip Code  County Number  \
# 2241460 2015-03-25          4183        DECORAH     52101           96.0
# 2241570 2015-03-25          4762  FORT ATKINSON     52144           96.0
# 2241572 2015-03-25          4818        DECORAH     52101           96.0
# 2241602 2015-03-25          3721        DECORAH     52101           96.0
# 2241606 2015-03-25          4762  FORT ATKINSON     52144           96.0
#
#              County   Category      Category Name  Vendor Number  Item Number  \
# 2241460  Winneshiek  1012100.0  CANADIAN WHISKIES             65        15247
# 2241570  Winneshiek  1041100.0  AMERICAN DRY GINS            434        31654
# 2241572  Winneshiek  1012100.0  CANADIAN WHISKIES             65        15247
# 2241602  Winneshiek  1031200.0     VODKA FLAVORED            380        41701
# 2241606  Winneshiek  1041100.0  AMERICAN DRY GINS            434        31658
#
#          Item Description  Bottle Volume (ml)  State Bottle Cost  \
# 2241460  Windsor Canadian                1000               6.81
# 2241570     Paramount Gin                 375               1.99
# 2241572  Windsor Canadian                1000               6.81
# 2241602   Uv Orange Vodka                 750               6.50
# 2241606     Paramount Gin                1750               7.11
#
#          State Bottle Retail  Bottles Sold  Sale (Dollars)  \
# 2241460                10.22             1           10.22
# 2241570                 2.99             3            8.97
# 2241572                10.22            12          122.64
# 2241602                 9.75            12          117.00
# 2241606                10.67             2           21.34
#
#          Volume Sold (Liters)  Volume Sold (Gallons)  Sale Year  Sale Month
# 2241460                  1.00                   0.26       2015           3
# 2241570                  1.12                   0.30       2015           3
# 2241572                 12.00                   3.17       2015           3
# 2241602                  9.00                   2.38       2015           3
# 2241606                  3.50                   0.92       2015           3

# %%
dfm_piv = pd.pivot_table(dfm, index = ['Store Number'], \
                        aggfunc = sum\
                        ).sort_values(\
                                      [('Sale (Dollars)')], ascending = False\
                                     )
dfm_piv.reset_index(inplace=True)

dfm_piv.head()
# Out:
#    Store Number  Bottle Volume (ml)  Bottles Sold     Category  County Number  \
# 0          3721              782250          6774  672069881.0        61824.0
# 1          4183              532875          4493  541255468.0        49728.0
# 2          3819              611100          4344  606786878.0        55680.0
# 3          4818              192850          2450  213368865.0        19776.0
# 4          4762              434875          1743  379812724.0        34848.0
#
#    Item Number  Sale (Dollars)  Sale Month  Sale Year  State Bottle Cost  \
# 0     28701014        97350.48        1302    1297660            6583.31
# 1     24587159        62630.69        1069    1043770            5120.44
# 2     26243445        57013.70        1160    1168700            5802.35
# 3      7540075        26349.60         413     415090            1818.02
# 4     16391426        25498.43         712     731445            3521.80
#
#    State Bottle Retail  Vendor Number  Volume Sold (Gallons)  \
# 0              9893.79         156750                1984.05
# 1              7689.00         136572                1243.70
# 2              8715.58         152306                1225.80
# 3              2728.89          43929                 514.94
# 4              5290.25          90447                 547.54
#
#    Volume Sold (Liters)  Zip Code
# 0               7510.50  33553044
# 1               4708.13  26988318
# 2               4640.56  30218580
# 3               1948.87  10732806
# 4               2075.93  18928272

# %%
dfmm = pd.concat([dfm_piv[('Bottles Sold')], \
                           dfm_piv[('Bottle Volume (ml)')], \
                           dfm_piv[('State Bottle Cost')], \
                           dfm_piv[('State Bottle Retail')], \
                          ], \
                          axis = 1)

# Renaming the columns

dfmm.columns = ['Sum Bottles Sold', \
                         'Sum volume sold (ml)', \
                         "Sum Bottle Cost", \
                         "Sum Bottle Price"
                        ]

# %%
# Filtering the df for data from first 3 months of 2015

dft = df_15[((df_15['Sale Month'] != 1)|(df_15['Sale Month'] != 2)|(df_15['Sale Month'] != 3))\
        & (df_15['County'] == "Winneshiek")]

# %%
dft_piv = pd.pivot_table(dft, index = ['Store Number'], \
                        aggfunc = sum\
                        ).sort_values(\
                                      [('Sale (Dollars)')], ascending = False\
                                     )
dft_piv.reset_index(inplace=True)


dftt = pd.concat([dft_piv[('Bottles Sold')], \
                           dft_piv[('Bottle Volume (ml)')], \
                           dft_piv[('State Bottle Cost')], \
                           dft_piv[('State Bottle Retail')], \
                          ], \
                          axis = 1)

# Renaming the columns

dftt.columns = ['Sum Bottles Sold', \
                         'Sum volume sold (ml)', \
                         "Sum Bottle Cost", \
                         "Sum Bottle Price"
                        ]

# %% [markdown]
# ### Using pure linear regression

# %%
X = dfmm
y = dfm_piv['Sale (Dollars)']

lm = linear_model.LinearRegression()
lm.fit(X,y)

pred = lm.predict(dftt)
print "r2 = ", r2_score(dft_piv['Sale (Dollars)'], pred)
print "MSE =", mean_squared_error(dft_piv['Sale (Dollars)'], pred)
# Out:
# r2 =  0.848440310365
# MSE = 2888859335.5

# %% [markdown]
# ## Using RidgeCV

# %%
al = [0.00000001,0.00001,0.0001, 0.001, 0.01, 0.1, 0.2, 0.3, 0.5, 0.7, 1.0, 5.0, 10.0, 20.0]

rcv = linear_model.RidgeCV(alphas = al, cv = 5)
rcv.fit(X,y)

pred_rcv = rcv.predict(dftt)

print "Coefficients =", rcv.coef_
print "Chosen alpha =", rcv.alpha_
print "r2 = ", r2_score(dft_piv['Sale (Dollars)'], pred_rcv)
print "MSE =", mean_squared_error(dft_piv['Sale (Dollars)'], pred_rcv)
print "RMSE =", round(np.sqrt(mean_squared_error(dft_piv['Sale (Dollars)'], pred_rcv)), 2)
# Out:
# Coefficients = [  1.46712517e+01   1.86421981e-01   3.91772055e+03  -2.61990946e+03]
# Chosen alpha = 1e-08
# r2 =  0.848440313248
# MSE = 2888859280.54
# RMSE = 53748.11

# %%
fig, axes = plt.subplots(1,2, figsize=(16,8))

axes[0].scatter(pred, dft_piv['Sale (Dollars)'], c='red', s = 200)
axes[0].plot(axes[0].get_xlim(), axes[0].get_ylim(), ls="--", c='b')

axes[1].scatter(pred_rcv, dft_piv['Sale (Dollars)'], c='k', s = 200)
axes[1].plot(axes[1].get_xlim(), axes[1].get_ylim(), ls="--", c='b')


axes[0].set_title('Linear Model')
axes[0].set_ylabel('Actual')
axes[0].set_xlabel('Predicted')

axes[1].set_title('RidgeCV Model')
axes[1].set_ylabel('Actual')
axes[1].set_xlabel('Predicted');

# %% [markdown]
# ### Using the models to predict 2016 performance

# %%
# Filtering the df for data from first 3 months of 2016

dfn = df_16[df_16['County'] == "Winneshiek"]

# %%
dfn_piv = pd.pivot_table(dfn, index = ['Store Number'], \
                        aggfunc = sum\
                        ).sort_values(\
                                      [('Sale (Dollars)')], ascending = False\
                                     )
dfn_piv.reset_index(inplace=True)

dfnn = pd.concat([dfn_piv[('Bottles Sold')], \
                           dfn_piv[('Bottle Volume (ml)')], \
                           dfn_piv[('State Bottle Cost')], \
                           dfn_piv[('State Bottle Retail')], \
                          ], \
                          axis = 1)

# Renaming the columns

dfnn.columns = ['Sum Bottles Sold', \
                         'Sum volume sold (ml)', \
                         "Sum Bottle Cost", \
                         "Sum Bottle Price"
                        ]

# %%
pred16 = lm.predict(dfnn)
print "r2 = ", r2_score(dfn_piv['Sale (Dollars)'], pred16)
print "MSE =", mean_squared_error(dfn_piv['Sale (Dollars)'], pred16)
# Out:
# r2 =  0.668760666084
# MSE = 291144977.831

# %%
pred_rcv16 = rcv.predict(dfnn)

print "Coefficients =", rcv.coef_
print "Chosen alpha =", rcv.alpha_
print "r2 = ", r2_score(dfn_piv['Sale (Dollars)'], pred_rcv16)
print "MSE =", mean_squared_error(dfn_piv['Sale (Dollars)'], pred_rcv16)
print "RMSE =", round(np.sqrt(mean_squared_error(dfn_piv['Sale (Dollars)'], pred_rcv16)), 2)
# Out:
# Coefficients = [  1.46712517e+01   1.86421981e-01   3.91772055e+03  -2.61990946e+03]
# Chosen alpha = 1e-08
# r2 =  0.668760675616
# MSE = 291144969.452
# RMSE = 17062.97

# %%
fig, axes = plt.subplots(1,2, figsize=(16,8))

axes[0].scatter(pred16, dfn_piv['Sale (Dollars)'], c='red', s = 200)
axes[0].plot(axes[0].get_xlim(), axes[0].get_ylim(), ls="--", c='b')

axes[1].scatter(pred_rcv16, dfn_piv['Sale (Dollars)'], c='k', s = 200)
axes[1].plot(axes[1].get_xlim(), axes[1].get_ylim(), ls="--", c='b')


axes[0].set_title('Linear Model')
axes[0].set_ylabel('Actual')
axes[0].set_xlabel('Predicted')

axes[1].set_title('RidgeCV Model')
axes[1].set_ylabel('Actual')
axes[1].set_xlabel('Predicted');

# %% [markdown]
# ### County : Polk (Top sum sale)

# %%
# Filtering the df for data from first 3 months of 2015

dfp = df_15[((df_15['Sale Month'] != 1)|(df_15['Sale Month'] != 2)|(df_15['Sale Month'] != 3))\
        & (df_15['County'] == "Polk")]

# %%
dfp_piv = pd.pivot_table(dfp, index = ['Store Number'], \
                        aggfunc = sum\
                        ).sort_values(\
                                      [('Sale (Dollars)')], ascending = False\
                                     )
dfp_piv.reset_index(inplace=True)


dfpp = pd.concat([dfp_piv[('Bottles Sold')], \
                           dfp_piv[('Bottle Volume (ml)')], \
                           dfp_piv[('State Bottle Cost')], \
                           dfp_piv[('State Bottle Retail')], \
                          ], \
                          axis = 1)

# Renaming the columns

dfpp.columns = ['Sum Bottles Sold', \
                         'Sum volume sold (ml)', \
                         "Sum Bottle Cost", \
                         "Sum Bottle Price"
                        ]

# %% [markdown]
# ### Using pure linear regression

# %%
X = dfpp
y = dfp_piv['Sale (Dollars)']

lm = linear_model.LinearRegression()
lm.fit(X,y)

pred = lm.predict(dfpp)
print "r2 = ", r2_score(dfp_piv['Sale (Dollars)'], pred)
print "MSE =", mean_squared_error(dfp_piv['Sale (Dollars)'], pred)
print "RMSE =", round(np.sqrt(mean_squared_error(dfp_piv['Sale (Dollars)'], pred)),2)
# Out:
# r2 =  0.982849349671
# MSE = 16674334069.4
# RMSE = 129129.14

# %% [markdown]
# ## Using RidgeCV

# %%
al = [0.00000001,0.00001,0.0001, 0.001, 0.01, 0.1, 0.2, 0.3, 0.5, 0.7, 1.0, 5.0, 10.0, 20.0]

rcv = linear_model.RidgeCV(alphas = al, cv = 5)
rcv.fit(X,y)

pred_rcv = rcv.predict(dfpp)

print "Coefficients =", rcv.coef_
print "Chosen alpha =", rcv.alpha_
print "r2 = ", r2_score(dfp_piv['Sale (Dollars)'], pred_rcv)
print "MSE =", mean_squared_error(dfp_piv['Sale (Dollars)'], pred_rcv)
print "RMSE =", round(np.sqrt(mean_squared_error(dfp_piv['Sale (Dollars)'], pred_rcv)), 2)
# Out:
# Coefficients = [  1.77392450e+01  -1.50496146e-01  -2.50885381e+03   1.67698310e+03]
# Chosen alpha = 1e-08
# r2 =  0.982849349671
# MSE = 16674334069.4
# RMSE = 129129.14

# %%
fig, axes = plt.subplots(1,2, figsize=(16,8))

axes[0].scatter(pred, dfp_piv['Sale (Dollars)'], c='red', s = 200)
axes[0].plot(axes[0].get_xlim(), axes[0].get_ylim(), ls="--", c='b')

axes[1].scatter(pred_rcv, dfp_piv['Sale (Dollars)'], c='k', s = 200)
axes[1].plot(axes[1].get_xlim(), axes[1].get_ylim(), ls="--", c='b')


axes[0].set_title('Linear Model')
axes[0].set_ylabel('Actual')
axes[0].set_xlabel('Predicted')

axes[1].set_title('RidgeCV Model')
axes[1].set_ylabel('Actual')
axes[1].set_xlabel('Predicted');

# %% [markdown]
# ## Removing outliers from Polk

# %%
dfp_piv.head()
# Out:
#    Store Number  Bottle Volume (ml)  Bottles Sold      Category  \
# 0          2633            17915350        595205  2.039188e+10
# 1          4829            16611550        520100  1.902321e+10
# 2          3420             3426550        192664  3.252340e+09
# 3          3814             1340300        117462  1.279281e+09
# 4          2619             9005656         97529  1.075558e+10
#
#    County Number  Item Number  Sale (Dollars)  Sale Month  Sale Year  \
# 0      1502116.0   1189731353      9839393.08      129019   39308620
# 1      1402324.0    977680675      8742779.31      117587   36697180
# 2       239855.0    140029024      3422351.55       21051    6276725
# 3        30875.0     66513098      2899984.38        8707    2488525
# 4       257025.0    528406416      1646447.23       71188   20716215
#
#    State Bottle Cost  State Bottle Retail  Vendor Number  \
# 0          239277.90            359200.19        5038264
# 1          229628.70            344628.84        4702056
# 2           39313.55             59013.99         817837
# 3           21456.12             32197.18         320924
# 4          114226.96            171512.57        2659141
#
#    Volume Sold (Gallons)  Volume Sold (Liters)   Zip Code
# 0              153987.10             582860.61  981642560
# 1              132710.00             502306.92  916318568
# 2               62709.10             237374.50  156718765
# 3               38549.90             145925.55   62078510
# 4               25579.71              96837.82  516784746

# %%
dfp_piv = pd.pivot_table(dfp, index = ['Store Number'], \
                        aggfunc = sum\
                        ).sort_values(\
                                      [('Sale (Dollars)')], ascending = False\
                                     )
dfp_piv.reset_index(inplace=True)

dfp_piv = dfp_piv[dfp_piv['Sale (Dollars)'] <= 2000000]

dfpp = pd.concat([dfp_piv[('Bottles Sold')], \
                           dfp_piv[('Bottle Volume (ml)')], \
                           dfp_piv[('State Bottle Cost')], \
                           dfp_piv[('State Bottle Retail')], \
                          ], \
                          axis = 1)

# Renaming the columns

dfpp.columns = ['Sum Bottles Sold', \
                         'Sum volume sold (ml)', \
                         "Sum Bottle Cost", \
                         "Sum Bottle Price"
                        ]

# %%
X = dfpp
y = dfp_piv['Sale (Dollars)']

lm = linear_model.LinearRegression()
lm.fit(X,y)

pred = lm.predict(dfpp)
print "r2 = ", r2_score(dfp_piv['Sale (Dollars)'], pred)
print "MSE =", mean_squared_error(dfp_piv['Sale (Dollars)'], pred)
print "RMSE =", round(np.sqrt(mean_squared_error(dfp_piv['Sale (Dollars)'], pred)),2)
# Out:
# r2 =  0.938684157323
# MSE = 6524845437.39
# RMSE = 80776.52

# %%
al = [0.00000001,0.00001,0.0001, 0.001, 0.01, 0.1, 0.2, 0.3, 0.5, 0.7, 1.0, 5.0, 10.0, 20.0]

rcv = linear_model.RidgeCV(alphas = al, cv = 5)
rcv.fit(X,y)

pred_rcv = rcv.predict(dfpp)

print "Coefficients =", rcv.coef_
print "Chosen alpha =", rcv.alpha_
print "r2 = ", r2_score(dfp_piv['Sale (Dollars)'], pred_rcv)
print "MSE =", mean_squared_error(dfp_piv['Sale (Dollars)'], pred_rcv)
print "RMSE =", round(np.sqrt(mean_squared_error(dfp_piv['Sale (Dollars)'], pred_rcv)), 2)
# Out:
# Coefficients = [  1.06494860e+01  -8.43558292e-02  -3.88391001e+03   2.59250960e+03]
# Chosen alpha = 1e-08
# r2 =  0.938684157323
# MSE = 6524845437.39
# RMSE = 80776.52

# %%
fig, axes = plt.subplots(1,2, figsize=(16,8))

axes[0].scatter(pred, dfp_piv['Sale (Dollars)'], c='red', s = 200)
axes[0].plot(axes[0].get_xlim(), axes[0].get_ylim(), ls="--", c='b')

axes[1].scatter(pred_rcv, dfp_piv['Sale (Dollars)'], c='k', s = 200)
axes[1].plot(axes[1].get_xlim(), axes[1].get_ylim(), ls="--", c='b')


axes[0].set_title('Linear Model')
axes[0].set_ylabel('Actual')
axes[0].set_xlabel('Predicted')

axes[1].set_title('RidgeCV Model')
axes[1].set_ylabel('Actual')
axes[1].set_xlabel('Predicted');

# %% [markdown]
# # Explore the data
#
# Perform some exploratory statistical analysis and make some plots, such as histograms of transaction totals, bottles sold, etc.

# %% [markdown]
# ## Record your findings
#
# Be sure to write out anything observations from your exploratory analysis.

# %% [markdown]
# # Mine the data
# Now you are ready to compute the variables you will use for your regression from the data. For example, you may want to
# compute total sales per store from Jan to March of 2015, mean price per bottle, etc. Refer to the readme for more ideas appropriate to your scenario.
#
# Pandas is your friend for this task. Take a look at the operations [here](http://pandas.pydata.org/pandas-docs/stable/groupby.html) for ideas on how to make the best use of pandas and feel free to search for blog and Stack Overflow posts to help you group data by certain variables and compute sums, means, etc. You may find it useful to create a new data frame to house this summary data.

# %% [markdown]
# # Refine the data
# Look for any statistical relationships, correlations, or other relevant properties of the dataset.

# %% [markdown]
# # Build your models
#
# Using scikit-learn or statsmodels, build the necessary models for your scenario. Evaluate model fit.

# %% [markdown]
# ## Plot your results
#
# Again make sure that you record any valuable information. For example, in the tax scenario, did you find the sales from the first three months of the year to be a good predictor of the total sales for the year? Plot the predictions versus the true values and discuss the successes and limitations of your models

# %% [markdown]
# # Present the Results
#
# Present your conclusions and results. If you have more than one interesting model feel free to include more than one along with a discussion. Use your work in this notebook to prepare your write-up.
