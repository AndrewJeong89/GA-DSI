# %% [markdown]
# # Getting started
#
# Once you've chosen your scenario, download the data from [the Iowa website](https://data.iowa.gov/Economy/Iowa-Liquor-Sales/m3tr-qhgy) in csv format. Start by loading the data with pandas. You may need to parse the date columns appropriately.

# %% [markdown]
# #### Scenario 2: Market research for new store locations
#
# A liquor store owner in Iowa is looking to expand to new locations and has hired you to investigate the market data for potential new locations. The business owner is interested in the details of the best model you can fit to the data so that his team can evaluate potential locations for a new storefront.
#
# **Goal for Scenario #2:** Your task is to:
#
# * Build models of total sales based on location, price per bottle, total bottles sold. You may find it useful to build models for each county, zip code, or city.
# * Provide a table of the best performing stores by location type of your choice (city, county, or zip code) and the predictions of your model(s).
# * Based on your models and the table of data, recommend some general locations to the business owner, taking into account model performance. Validate your model's performance and ability to predict future sales using cross-validation.
# * _Bonus_: Recommend targets for volume sold and price per bottle!
#
# ---

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import pprint

# %%
## Load the data into a DataFrame
df = pd.read_csv("Iowa_Liquor_sales_sample_10pct.csv")

## Transform the dates if needed, e.g.
# df["Date"] = pd.to_datetime(df["Date"], format="%m-%d-%y")

df.head()
# Out:
#          Date  Store Number         City Zip Code  County Number      County  \
# 0  11/04/2015          3717       SUMNER    50674            9.0      Bremer
# 1  03/02/2016          2614    DAVENPORT    52807           82.0       Scott
# 2  02/11/2016          2106  CEDAR FALLS    50613            7.0  Black Hawk
# 3  02/03/2016          2501         AMES    50010           85.0       Story
# 4  08/18/2015          3654      BELMOND    50421           99.0      Wright
#
#     Category              Category Name  Vendor Number  Item Number  \
# 0  1051100.0           APRICOT BRANDIES             55        54436
# 1  1011100.0           BLENDED WHISKIES            395        27605
# 2  1011200.0  STRAIGHT BOURBON WHISKIES             65        19067
# 3  1071100.0         AMERICAN COCKTAILS            395        59154
# 4  1031080.0             VODKA 80 PROOF            297        35918
#
#             Item Description  Bottle Volume (ml) State Bottle Cost  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270955 entries, 0 to 270954
# Data columns (total 18 columns):
# Date                     270955 non-null object
# Store Number             270955 non-null int64
# City                     270955 non-null object
# Zip Code                 270955 non-null object
# County Number            269878 non-null float64
# County                   269878 non-null object
# Category                 270887 non-null float64
# Category Name            270323 non-null object
# Vendor Number            270955 non-null int64
# Item Number              270955 non-null int64
# Item Description         270955 non-null object
# Bottle Volume (ml)       270955 non-null int64
# State Bottle Cost        270955 non-null object
# State Bottle Retail      270955 non-null object
# Bottles Sold             270955 non-null int64
# Sale (Dollars)           270955 non-null object
# Volume Sold (Liters)     270955 non-null float64
# ...

# %% [markdown]
# ### Data Munging

# %%
df_s = df.iloc[:20,:]

# %%
df_s['Date'] = df_s['Date'].apply(pd.to_datetime)
df_s.dtypes
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# Date                     datetime64[ns]
# Store Number                    float64
# City                             object
# Zip Code                         object
# County Number                   float64
# County                           object
# Category                        float64
# Category Name                    object
# Vendor Number                   float64
# Item Number                     float64
# Item Description                 object
# Bottle Volume (ml)              float64
# State Bottle Cost                object
# State Bottle Retail              object
# ...

# %%
a = df_s.sample(frac = 0.1, random_state=10)
a
# Out:
#          Date  Store Number          City Zip Code  County Number   County  \
# 14 2016-01-04        2670.0    CORALVILLE    52241           52.0  Johnson
# 5  2015-04-20        2569.0  CEDAR RAPIDS    52402           57.0     Linn
#
#      Category      Category Name  Vendor Number  Item Number  \
# 14  1031200.0     VODKA FLAVORED          380.0      41705.0
# 5   1041100.0  AMERICAN DRY GINS          205.0      31473.0
#
#          Item Description  Bottle Volume (ml) State Bottle Cost  \
# 14  Uv Red (cherry) Vodka              1000.0             $7.50
# 5       New Amsterdam Gin              1750.0            $13.32
#
#    State Bottle Retail  Bottles Sold Sale (Dollars)  Volume Sold (Liters)  \
# 14              $11.25          12.0        $135.00                  12.0
# 5               $19.98           6.0        $119.88                  10.5
#
#     Volume Sold (Gallons)
# 14                   3.17
# 5                    2.77

# %%
df_s = df.sample(frac = 0.01, random_state = 10)
df_s.head()
# Out:
#               Date  Store Number            City Zip Code  County Number  \
# 69839   11/03/2015          4743  COUNCIL BLUFFS    51503           78.0
# 101499  01/26/2016          4687    CEDAR RAPIDS    52402           57.0
# 209564  01/27/2015          2604          LEMARS    51031           75.0
# 78618   01/16/2015          3162       MUSCATINE    52761           70.0
# 199699  02/24/2016          4478      DES MOINES    50315           77.0
#
#                County   Category                       Category Name  \
# 69839   Pottawattamie  1062310.0                          SPICED RUM
# 101499           Linn  1011100.0                    BLENDED WHISKIES
# 209564       Plymouth  1022100.0                             TEQUILA
# 78618       Muscatine  1081900.0  MISC. AMERICAN CORDIALS & LIQUEURS
# 199699           Polk  1012100.0                   CANADIAN WHISKIES
#
#         Vendor Number  Item Number              Item Description  \
# ...

# %%
df_s['Date'] = df_s['Date'].apply(pd.to_datetime)

# %%
df_sub = df_s.iloc[:,9:]

# %%
df_sub.head()
# Out:
#         Item Number              Item Description  Bottle Volume (ml)  \
# 69839         43334     Captain Morgan Spiced Rum                 375
# 101499        25606   Seagrams 7 Crown Bl Whiskey                 750
# 209564        88290         Patron Silver Tequila                 200
# 78618         75211                 Kinky Liqueur                 750
# 199699        10555  Black Velvet Toasted Caramel                 375
#
#        State Bottle Cost State Bottle Retail  Bottles Sold Sale (Dollars)  \
# 69839              $5.00               $7.50             2         $15.00
# 101499             $7.00              $10.50             6         $63.00
# 209564             $8.50              $12.75             1         $12.75
# 78618             $10.00              $15.00             2         $30.00
# 199699             $3.07               $4.61             5         $23.05
#
#         Volume Sold (Liters)  Volume Sold (Gallons)
# ...

# %%
df_sub.dtypes
# Out:
# Item Number                int64
# Item Description          object
# Bottle Volume (ml)         int64
# State Bottle Cost         object
# State Bottle Retail       object
# Bottles Sold               int64
# Sale (Dollars)            object
# Volume Sold (Liters)     float64
# Volume Sold (Gallons)    float64
# dtype: object

# %%
df_sub['Item Number'].hist(bins = 500)

# %%
df_sub[df_sub['Item Number'] > 800000]
# Out:
#         Item Number                      Item Description  Bottle Volume (ml)  \
# 241021       903969        Talisker Distillers Edition HA                 750
# 210844       922099          Wild Turkey Master's Keep HA                 750
# 262863       916002                       Hakushu 12YR HA                 750
# 183377       917946          Elmer T Lee Single Barrel HA                 750
# 262300       995507                 Macallan Rare Cask HA                 750
# 92702        914000  Aberfeldy 12 Year Single Malt Scotch                 750
#
#        State Bottle Cost State Bottle Retail  Bottles Sold Sale (Dollars)  \
# 241021            $38.00              $57.00             1         $57.00
# 210844            $75.00             $112.50             6        $675.00
# 262863            $44.62              $66.93            12        $803.16
# 183377            $15.00              $22.50             4         $90.00
# ...

# %% [markdown]
# There is nothing wrong with the "Item Number" column. Only peculiar thing was that 6 of the entries were of values over 800,000, which was assumed to be a numbering norm.

# %%
df_sub['Bottle Volume (ml)'].hist(bins = 200)

# %% [markdown]
# Most common bottle type is 750ml. 1750ml is second most popular.

# %%
df_sub[pd.isnull(df_sub).any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Item Number, Item Description, Bottle Volume (ml), State Bottle Cost, State Bottle Retail, Bottles Sold, Sale (Dollars), Volume Sold (Liters), Volume Sold (Gallons)]
# Index: []

# %%
a = 'abc'
b = a[1:]
print b
# Out:
# bc

# %%
a = "$150.38  "

# %%
a = a.strip()
print a
# Out:
# $150.38

# %%
# Function to convert money columns from string to float

def conv_money(x):
    x = x.split('.')
    return (float(x[0][1:]) + (float(x[1]) / 100))

# %%
# Converting columns with money value to float

df_sub[['State Bottle Cost', 'State Bottle Retail', "Sale (Dollars)"]] = \
df_sub[['State Bottle Cost', 'State Bottle Retail', "Sale (Dollars)"]].applymap(conv_money)

# %%
df_sub.head()
# Out:
#         Item Number              Item Description  Bottle Volume (ml)  \
# 69839         43334     Captain Morgan Spiced Rum                 375
# 101499        25606   Seagrams 7 Crown Bl Whiskey                 750
# 209564        88290         Patron Silver Tequila                 200
# 78618         75211                 Kinky Liqueur                 750
# 199699        10555  Black Velvet Toasted Caramel                 375
#
#        State Bottle Cost State Bottle Retail  Bottles Sold Sale (Dollars)  \
# 69839              $5.00               $7.50             2         $15.00
# 101499             $7.00              $10.50             6         $63.00
# 209564             $8.50              $12.75             1         $12.75
# 78618             $10.00              $15.00             2         $30.00
# 199699             $3.07               $4.61             5         $23.05
#
#         Volume Sold (Liters)  Volume Sold (Gallons)
# ...

# %%
clean_a(df_sub.iloc[0,1])
# Out:
# 'Captain Morgan Spiced Rum'

# %%
df_sub['Item Description'] = df_sub['Item Description'].apply(lambda x: x.strip())
df_sub.head()
# Out:
#         Item Number              Item Description  Bottle Volume (ml)  \
# 69839         43334     Captain Morgan Spiced Rum                 375
# 101499        25606   Seagrams 7 Crown Bl Whiskey                 750
# 209564        88290         Patron Silver Tequila                 200
# 78618         75211                 Kinky Liqueur                 750
# 199699        10555  Black Velvet Toasted Caramel                 375
#
#        State Bottle Cost State Bottle Retail  Bottles Sold Sale (Dollars)  \
# 69839              $5.00               $7.50             2         $15.00
# 101499             $7.00              $10.50             6         $63.00
# 209564             $8.50              $12.75             1         $12.75
# 78618             $10.00              $15.00             2         $30.00
# 199699             $3.07               $4.61             5         $23.05
#
#         Volume Sold (Liters)  Volume Sold (Gallons)
# ...

# %%
def type_check(x):
    return type(x) != str

# %%
mask = df_s['Category Name'].apply(type_check)
mask.head()
# Out:
# 69839     False
# 101499    False
# 209564    False
# 78618     False
# 199699    False
# Name: Category Name, dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270955 entries, 0 to 270954
# Data columns (total 18 columns):
# Date                     270955 non-null object
# Store Number             270955 non-null int64
# City                     270955 non-null object
# Zip Code                 270955 non-null object
# County Number            269878 non-null float64
# County                   269878 non-null object
# Category                 270887 non-null float64
# Category Name            270323 non-null object
# Vendor Number            270955 non-null int64
# Item Number              270955 non-null int64
# Item Description         270955 non-null object
# Bottle Volume (ml)       270955 non-null int64
# State Bottle Cost        270955 non-null object
# State Bottle Retail      270955 non-null object
# Bottles Sold             270955 non-null int64
# Sale (Dollars)           270955 non-null object
# Volume Sold (Liters)     270955 non-null float64
# ...

# %%
# Create a new dataframe for rows with NaNs in County or County Number

df_nan = df[pd.isnull(df).any(axis = 1)]

# %%
sum(pd.isnull(df['City']))
# Out:
# 0

# %%
df_nan
# Out:
#               Date  Store Number          City Zip Code  County Number  \
# 135     01/20/2016          5222  CEDAR RAPIDS    52402            NaN
# 198     03/02/2016          3820    SIOUX CITY    51103            NaN
# 272     03/21/2016          4222     EVANSDALE    50707            NaN
# 290     03/21/2016          5236       ANAMOSA    52205            NaN
# 321     02/23/2016          4203       WAVERLY    50677            NaN
# 863     01/11/2016          2460       HAMPTON    50441            NaN
# 896     02/05/2015          4829    DES MOINES    50314           77.0
# 901     02/25/2016          4647      WATERLOO    50707            7.0
# 964     05/19/2015          4247       BELMOND    50421            NaN
# 982     03/30/2016          5222  CEDAR RAPIDS    52402            NaN
# 1024    03/23/2016          3820    SIOUX CITY    51103            NaN
# 1514    02/18/2016          2515    MASON CITY    50401           17.0
# ...

# %%
df[df['Zip Code'].apply(lambda x: len(x) != 5)]
# Out:
# Empty DataFrame
# Columns: [Date, Store Number, City, Zip Code, County Number, County, Category, Category Name, Vendor Number, Item Number, Item Description, Bottle Volume (ml), State Bottle Cost, State Bottle Retail, Bottles Sold, Sale (Dollars), Volume Sold (Liters), Volume Sold (Gallons)]
# Index: []

# %%
df[df['Zip Code'].apply(lambda x: int(x))]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-320-8eafadc4a83d> in <module>()
# ----> 1 df[df['Zip Code'].apply(lambda x: int(x))]
#
# //anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    2218         else:
#    2219             values = self.asobject
# -> 2220             mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2221
#    2222         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/src/inference.pyx in pandas.lib.map_infer (pandas/lib.c:62658)()
#
# <ipython-input-320-8eafadc4a83d> in <lambda>(x)
# ----> 1 df[df['Zip Code'].apply(lambda x: int(x))]
#
# ValueError: invalid literal for int() with base 10: '712-2'

# %%
df[df['Zip Code'].apply(lambda x: x == '712-2')]
# Out:
#               Date  Store Number    City Zip Code  County Number    County  \
# 114     01/16/2015          4307  DUNLAP    712-2           43.0  Harrison
# 2695    01/05/2015          4307  DUNLAP    712-2           43.0  Harrison
# 4129    10/19/2015          4307  DUNLAP    712-2           43.0  Harrison
# 5506    01/05/2015          4307  DUNLAP    712-2           43.0  Harrison
# 5512    11/20/2015          4307  DUNLAP    712-2           43.0  Harrison
# 8186    03/14/2016          4307  DUNLAP    712-2            NaN  Harrison
# 8642    11/02/2015          4307  DUNLAP    712-2           43.0  Harrison
# 9347    03/21/2016          4307  DUNLAP    712-2            NaN  Harrison
# 16502   12/26/2015          4307  DUNLAP    712-2           43.0  Harrison
# 16928   11/09/2015          4307  DUNLAP    712-2           43.0  Harrison
# 19076   08/31/2015          4307  DUNLAP    712-2           43.0  Harrison
# ...

# %%
df.loc[df['Zip Code'] == '712-2', 'Zip Code'] = '51529'
#df.loc[df['City'] == cty, 'County'] = county_dict[cty][0][0]

# %%
for x in df['Zip Code']:
    try:
        int(x)
    except:
        print x

#

# %%
df['Zip Code'] = df['Zip Code'].apply(lambda x: int(x))

# %%
df.dtypes
# Out:
# Date                      object
# Store Number               int64
# City                      object
# Zip Code                   int64
# County Number            float64
# County                    object
# Category                 float64
# Category Name             object
# Vendor Number              int64
# Item Number                int64
# Item Description          object
# Bottle Volume (ml)         int64
# State Bottle Cost         object
# State Bottle Retail       object
# Bottles Sold               int64
# Sale (Dollars)            object
# Volume Sold (Liters)     float64
# Volume Sold (Gallons)    float64
# dtype: object

# %%
tbc_list = []

for col in df.columns:
    x = sum(pd.isnull(df[col]))
    if x != 0:
        tbc_list.append(col)
        print col, x
# Out:
# County Number 1077
# County 1077
# Category 68
# Category Name 632

# %%
tbc_list
# Out:
# ['County Number', 'County', 'Category', 'Category Name']

# %%
# Create a set of Cities with NaN for county or county Number

city_nan_list = list({x for x in df_nan['City']})

city_nan_list
# Out:
# ['NORWALK',
#  'LEMARS',
#  'GRINNELL',
#  'DUNLAP',
#  'COUNCIL BLUFFS',
#  'SIGOURNEY',
#  'PELLA',
#  'DAVENPORT',
#  'SIBLEY',
#  'CARLISLE',
#  'HAMPTON',
#  'NEVADA',
#  'TIPTON',
#  'DUBUQUE',
#  'ELDRIDGE',
#  'WEST DES MOINES',
#  'ROCKWELL',
#  'MONTICELLO',
#  'CLIVE',
#  'LECLAIRE',
#  'FORT MADISON',
#  'MISSOURI VALLEY',
#  'DENISON',
#  'LAMONI',
#  'LARCHWOOD',
#  'OELWEIN',
#  'MOUNT PLEASANT',
#  'CLEAR LAKE',
#  'WEBSTER CITY',
#  'ALTOONA',
#  'WINDSOR HEIGHTS',
#  'TOLEDO',
#  'KEOKUK',
#  'MUSCATINE',
#  'GRIMES',
#  'CLARINDA',
#  'ANAMOSA',
#  'SWISHER',
#  'SPIRIT LAKE',
#  'ATLANTIC',
#  'BOONE',
#  'MOUNT VERNON',
#  'STORM LAKE',
#  'CARROLL',
#  'DENVER',
#  'CORALVILLE',
#  'GUTHRIE CENTER',
#  'ANKENY',
#  'WASHINGTON',
#  'WESLEY',
#  'DES MOINES',
#  'ACKLEY',
#  'RIVERSIDE',
#  'CHARLES CITY',
#  'CLINTON',
#  'TABOR',
#  'NORTHWOOD',
#  'HARLAN',
#  'GUTTENBERG',
#  'MARSHALLTOWN',
#  'JOHNSTON',
#  'INDIANOLA',
#  'INDEPENDENCE',
#  'IOWA FALLS',
# ...

# %%
nan_cty_dict = {}

for j in city_nan_list:
    c_set = {x for x in df[df['City']==j]['County'] if x > 0}
    num_set = {x for x in df[df['City']==j]['County Number'] if x > 0}
    nan_cty_dict[j] = [list(c_set), list(num_set)]

nan_cty_dict
# Out:
# {'ACKLEY': [['Webster', 'Hardin'], [42.0, 94.0]],
#  'ALBIA': [['Monroe'], [68.0]],
#  'ALTOONA': [['Polk'], [77.0]],
#  'AMES': [['Story'], [85.0]],
#  'ANAMOSA': [['Jones'], [53.0]],
#  'ANITA': [['Cass'], [15.0]],
#  'ANKENY': [['Polk'], [77.0]],
#  'ARNOLDS PARK': [['Dickinson'], [30.0]],
#  'ATLANTIC': [['Cass'], [15.0]],
#  'AUDUBON': [['Audubon'], [5.0]],
#  'BELMOND': [['Wright'], [99.0]],
#  'BETTENDORF': [['Iowa', 'Scott'], [48.0, 82.0]],
#  'BOONE': [['Boone'], [8.0]],
#  'BURLINGTON': [['Des Moines'], [29.0]],
#  'CARLISLE': [['Warren'], [91.0]],
#  'CARROLL': [['Carroll'], [14.0]],
#  'CEDAR FALLS': [['Black Hawk'], [7.0]],
#  'CEDAR RAPIDS': [['Linn'], [57.0]],
#  'CENTERVILLE': [['Appanoose'], [4.0]],
#  'CHARITON': [['Lucas'], [59.0]],
#  'CHARLES CITY': [['Floyd'], [34.0]],
#  'CHEROKEE': [['Cherokee'], [18.0]],
#  'CLARINDA': [['Page'], [73.0]],
#  'CLEAR LAKE': [['Cerro Gordo'], [17.0]],
#  'CLINTON': [['Clinton'], [23.0]],
# ...

# %%
def replace_cty(city):
    try:
        return nan_cty_dict[city][0][0]
    except:
        return nan_cty_dict[city][0]

# %%
nan_cty_dict['RUNNELLS'][0]
# Out:
# []

# %%
for city in nan_cty_dict:
    df[df['City']== city]['County'] = df[df['City']== city]['County'].apply(replace_cty(city))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-300-c76ab513107a> in <module>()
#       1 for city in nan_cty_dict:
# ----> 2     df[df['City']== city]['County'] = df[df['City']== city]['County'].apply(replace_cty(city))
#
# //anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    2218         else:
#    2219             values = self.asobject
# -> 2220             mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2221
#    2222         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/src/inference.pyx in pandas.lib.map_infer (pandas/lib.c:62658)()
#
# TypeError: 'str' object is not callable

# %%
# Create a dictionary of City : [[All different values in "County"], [All different values of "County Number"]]

#Set empty dictionary
# Ackley is in both Hardin, Franklin

county_dict = {}

for k in county_nan_set:
    c_set = {x for x in df_s[df_s['City']==k]['County']}
    num_set = {x for x in df_s[df_s['City']==k]['County Number']}
    county_dict[k] = [list(c_set), list(num_set)]

county_dict
# Out:
# {'ACKLEY': [[nan], [nan]],
#  'ALTOONA': [['Polk'], [77.0]],
#  'ANAMOSA': [['Jones'], [53.0]],
#  'ATLANTIC': [['Cass'], [15.0]],
#  'AUDUBON': [['Audubon'], [5.0]],
#  'BELMOND': [[nan, 'Wright'], [nan, 99.0]],
#  'CEDAR RAPIDS': [[nan, 'Linn'], [nan, 57.0, nan]],
#  'CHARITON': [['Lucas'], [59.0]],
#  'CLARINDA': [['Page'], [73.0]],
#  'CLINTON': [['Clinton'], [23.0]],
#  'CORALVILLE': [['Johnson'], [52.0]],
#  'CRESCO': [[nan, 'Howard'], [nan, 45.0]],
#  'DAVENPORT': [[nan, 'Scott'], [nan, 82.0]],
#  'DES MOINES': [['Polk'], [77.0]],
#  'DUBUQUE': [['Dubuque'], [31.0]],
#  'DUNLAP': [['Harrison'], [43.0]],
#  'EVANSDALE': [['Black Hawk'], [7.0]],
#  'FORT DODGE': [['Webster', 'Hardin'], [42.0, 94.0]],
#  'HAMPTON': [['Franklin'], [35.0]],
#  'HARLAN': [['Shelby'], [83.0]],
#  'LARCHWOOD': [['Lyon'], [60.0]],
#  'MASON CITY': [[nan, 'Cerro Gordo'], [nan, 17.0, nan]],
#  'NORTH LIBERTY': [['Johnson'], [52.0]],
#  'NORWALK': [['Warren'], [91.0]],
#  'OSCEOLA': [['Clarke'], [20.0]],
# ...

# %%
for cty in county_dict:
    if type(county_dict[cty][0][0]) ==

# %%
for cty in county_dict:
    try:
        df.loc[df['City'] == cty, 'County'] = county_dict[cty][0][0]
    except:
        pass

# %%
df_nan_n = df[pd.isnull(df).any(axis = 1)]

# %%
df_nan_n
# Out:
#               Date  Store Number          City Zip Code  County Number County  \
# 1       03/02/2016          2614     DAVENPORT    52807           82.0    NaN
# 4       08/18/2015          3654       BELMOND    50421           99.0    NaN
# 5       04/20/2015          2569  CEDAR RAPIDS    52402           57.0    NaN
# 12      01/22/2015          3858     DAVENPORT    52806           82.0    NaN
# 19      03/04/2015          2614     DAVENPORT    52807           82.0    NaN
# 20      01/16/2015          2590  CEDAR RAPIDS    52402           57.0    NaN
# 23      11/12/2015          4376    MASON CITY    50401           17.0    NaN
# 24      03/14/2016          2618  CEDAR RAPIDS    52402           57.0    NaN
# 38      01/27/2016          2637     DAVENPORT    52804           82.0    NaN
# 46      08/06/2015          3713    MASON CITY    50401           17.0    NaN
# 52      01/28/2015          2623    SIOUX CITY    51104           97.0    NaN
# ...

# %%
df_nan_n['Store Number'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d90c6fe21b55> in <module>()
# ----> 1 df_nan_n['Store Number'].unique()
#
# NameError: name 'df_nan_n' is not defined

# %%
for k in county_dict:
    if len(county_dict[k][0]) == 1 and len(county_dict[k][1]) == 1 and type(county_dict[k][0][0]) != type(1.0):
        df[df['City'] == k]['County'] = county_dict[k][0][0]
        df[df['City'] == k]['County Number'] = county_dict[k][1][0]
        print k, county_dict[k][0][0], county_dict[k][1][0]
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# CLARINDA Page 73.0
# NORWALK Warren 91.0
# ANAMOSA Jones 53.0
# CHARITON Lucas 59.0
# NORTH LIBERTY Johnson 52.0
# DUNLAP Harrison 43.0
# SIGOURNEY Keokuk 54.0
# ATLANTIC Cass 15.0
# EVANSDALE Black Hawk 7.0
# AUDUBON Audubon 5.0
# HAMPTON Franklin 35.0
# WATERLOO Black Hawk 7.0
# ...

# %%
for k in county_dict:
    print df[df['City'] == k][['County', 'City', 'County Number']]
    print"========================="
# Out:
#        County      City  County Number
# 888      Page  CLARINDA           73.0
# 948      Page  CLARINDA           73.0
# 1381     Page  CLARINDA           73.0
# 1602     Page  CLARINDA           73.0
# 1670     Page  CLARINDA           73.0
# 2278     Page  CLARINDA           73.0
# 2474     Page  CLARINDA           73.0
# 2549      NaN  CLARINDA            NaN
# 2678      NaN  CLARINDA            NaN
# 3479     Page  CLARINDA           73.0
# 3598     Page  CLARINDA           73.0
# 4176     Page  CLARINDA           73.0
# 4829     Page  CLARINDA           73.0
# 5099     Page  CLARINDA           73.0
# 6727     Page  CLARINDA           73.0
# 6944     Page  CLARINDA           73.0
# 7916     Page  CLARINDA           73.0
# 8191     Page  CLARINDA           73.0
# 8337     Page  CLARINDA           73.0
# 8575     Page  CLARINDA           73.0
# 8640     Page  CLARINDA           73.0
# 9191     Page  CLARINDA           73.0
# 9666     Page  CLARINDA           73.0
# ...

# %%
def correct_county(city):
    for c in county_dict[city]:
        if type(c) != type(1.):
            return c

# %%
df_s['County'] = df_s['County'].apply(correct_county)

# %%
df_s[mask][['City', 'County', "Category Name"]]
# Out:
#                 City County                       Category Name
# 218125    SIOUX CITY    NaN                   CANADIAN WHISKIES
# 39809     MASON CITY    NaN                     COFFEE LIQUEURS
# 98989         CRESCO    NaN                             TEQUILA
# 247042        ACKLEY    NaN  MISC. AMERICAN CORDIALS & LIQUEURS
# 41806        BELMOND    NaN                          SPICED RUM
# 258214  CEDAR RAPIDS    NaN                  TENNESSEE WHISKIES
# 18948      DAVENPORT    NaN                     SCOTCH WHISKIES
# 130914    MASON CITY    NaN                          SPICED RUM
# 133494  CEDAR RAPIDS    NaN             AMERICAN GRAPE BRANDIES

# %%
df_s[mask][['City', 'County', "Category Name"]]
# Out:
#                 City      County Category Name
# 264895          AMES       Story           NaN
# 213313     DAVENPORT       Scott           NaN
# 23180     DES MOINES        Polk           NaN
# 104215  MARSHALLTOWN    Marshall           NaN
# 248313        NEWTON      Jasper           NaN
# 97520    CEDAR FALLS  Black Hawk           NaN

# %%
df_s[['City', 'County', "Category Name"]] = df_s[['City', 'County', "Category Name"]].applymap(lambda x: x.strip())

# %% [markdown]
# # Explore the data
#
# Perform some exploratory statistical analysis and make some plots, such as histograms of transaction totals, bottles sold, etc.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Record your findings
#
# Be sure to write out anything observations from your exploratory analysis.

# %% [markdown]
# # Mine the data
# Now you are ready to compute the variables you will use for your regression from the data. For example, you may want to
# compute total sales per store from Jan to March of 2015, mean price per bottle, etc. Refer to the readme for more ideas appropriate to your scenario.
#
# Pandas is your friend for this task. Take a look at the operations [here](http://pandas.pydata.org/pandas-docs/stable/groupby.html) for ideas on how to make the best use of pandas and feel free to search for blog and Stack Overflow posts to help you group data by certain variables and compute sums, means, etc. You may find it useful to create a new data frame to house this summary data.

# %% [markdown]
# # Refine the data
# Look for any statistical relationships, correlations, or other relevant properties of the dataset.

# %% [markdown]
# # Build your models
#
# Using scikit-learn or statsmodels, build the necessary models for your scenario. Evaluate model fit.

# %%
from sklearn import linear_model

# %% [markdown]
# ## Plot your results
#
# Again make sure that you record any valuable information. For example, in the tax scenario, did you find the sales from the first three months of the year to be a good predictor of the total sales for the year? Plot the predictions versus the true values and discuss the successes and limitations of your models

# %% [markdown]
# # Present the Results
#
# Present your conclusions and results. If you have more than one interesting model feel free to include more than one along with a discussion. Use your work in this notebook to prepare your write-up.
